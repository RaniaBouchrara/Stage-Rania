# %% [markdown]
# <a href="https://colab.research.google.com/github/RaniaBouchrara/Stage-Rania/blob/master/Lorenz_d%C3%A9terministe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Simulation de dynamiques (séries temporelles) Lorenz_63 déterministe

# %%
import numpy as np

def Lorenz_63(S,t,Pra,r,b,gamma):
    """ Lorenz-63 dynamical model. """
    x_1 = Pra*(S[1]-S[0])-(4/(2*gamma))*S[0];
    x_2 = S[0]*(r-S[2])-S[1]-(4/(2*gamma))*S[1];
    x_3 = S[0]*S[1] - b*S[2]-(8/(2*gamma))*S[2];
    dS  = np.array([x_1,x_2,x_3]);
    return dS

# %%
from scipy.integrate import odeint
from scipy.integrate import ode
def generate_data(GD):
    """ Generate the true state, noisy observations and catalog of numerical simulations. """

    # initialization
    class xt:
        values = [];
        time = [];
    class yo:
        values = [];
        time = [];
    class catalog:
        analogs = [];
        successors = [];
        source = [];
        time = [];
    
    # test on parameters
    if GD.dt_states>GD.dt_obs:
        print('Error: GD.dt_obs must be bigger than GD.dt_states');
    if (np.mod(GD.dt_obs,GD.dt_states)!=0):
        print('Error: GD.dt_obs must be a multiple of GD.dt_states');

    # use this to generate the same data for different simulations
    np.random.seed(1);

    # 5 time steps (to be in the attractor space)  
    x0 = np.array([8.0,0.0,30.0]);
    S = odeint(Lorenz_63,x0,np.arange(0,5+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    x0 = S[S.shape[0]-1,:];

    # generate true state (xt)
    S = odeint(Lorenz_63,x0,np.arange(0.01,GD.nb_loop_test+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    T_test = S.shape[0];      
    t_xt = np.arange(0,T_test,GD.dt_states);       
    xt.time = t_xt*GD.dt_integration;
    xt.values = S[t_xt,:];
        
    # generate  partial/noisy observations (yo)
    eps = np.random.multivariate_normal(np.zeros(3),GD.sigma2_obs*np.eye(3,3),T_test);
    yo_tmp = S[t_xt,:]+eps[t_xt,:];
    t_yo = np.arange(0,T_test,GD.dt_obs);
    i_t_obs = np.where((np.in1d(t_xt,t_yo))==True)[0];
    yo.values = xt.values*np.nan;
    yo.values[np.ix_(i_t_obs,GD.var_obs)] = yo_tmp[np.ix_(i_t_obs,GD.var_obs)];
    yo.time = xt.time;
       

    #generate catalog
    S =  odeint(Lorenz_63,S[S.shape[0]-1,:],np.arange(0.01,GD.nb_loop_train+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    T_train = S.shape[0];
    eta = np.random.multivariate_normal(np.zeros(3),GD.sigma2_catalog*np.eye(3,3),T_train);
    catalog_tmp = S+eta;
    catalog.analogs = catalog_tmp[0:-GD.dt_states,:];
    catalog.successors = catalog_tmp[GD.dt_states:,:]
    catalog.source = GD.parameters;
  # reinitialize random generator number    
    np.random.seed()

    return catalog, xt, yo;

# %%
import sys
import matplotlib.pyplot as plt
import torch
from mpl_toolkits.mplot3d import Axes3D

# %%
### GENERATE SIMULATED DATA (LORENZ-63 MODEL)
class GD:
    model = 'Lorenz_63'
    class parameters:
        Pra = 10.0
        r = 28.0
        b = 8.0/3
        gamma=10.0
    dt_integration = 0.01 # integration time
    dt_states = 1 # number of integeration times between consecutive states (for xt and catalog)
    dt_obs = 8# number of integration times between consecutive observations (for yo)
    var_obs = np.array([0,1]) # indices of the observed variables
    nb_loop_train = 110.01 # size of the catalog
    nb_loop_test = 100 # size of the true state and noisy observations
    sigma2_catalog = 0.0 # variance of the model error to generate the catalog
    sigma2_obs = 0.0 # variance of the observation error to generate observation
    
# run the data generation
catalog, xt, yo = generate_data(GD)

# %%
plt.plot(catalog.analogs)
# Out:
# [<matplotlib.lines.Line2D at 0x7f2d859b9710>,
#  <matplotlib.lines.Line2D at 0x7f2d859b9828>,
#  <matplotlib.lines.Line2D at 0x7f2d859b9978>]

# %%
#training data
batch_size = 50
X_train = np.reshape(catalog.analogs,(int(catalog.analogs.shape[0]/batch_size),batch_size,catalog.analogs.shape[1]))
Grad_t  = np.gradient(X_train)[1]/GD.dt_integration
Y_train = np.reshape(catalog.successors,(int(catalog.analogs.shape[0]/batch_size),batch_size,catalog.analogs.shape[1]))

# %%
plt.plot(X_train[0,:,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f2d854fec88>,
#  <matplotlib.lines.Line2D at 0x7f2d854feda0>,
#  <matplotlib.lines.Line2D at 0x7f2d854feef0>]

# %%
params = {}#NN parameters
params['transition_layers']=1
params['bi_linear_layers']=3
params['dim_hidden_linear'] = 3
params['dim_input']=3
params['dim_output']=3
params['dim_observations'] = 3
params['dim_hidden']=3
params['ntrain']=[1000,200]
params['dt_integration'] = GD.dt_integration
pretrained = False
path = ''# to be defined
file_name = '' # to be defined

# %%
np.random.seed(0)
torch.manual_seed(0)
class FC_net(torch.nn.Module):
        def __init__(self, params):
            super(FC_net, self).__init__()
            self.linearCell   = torch.nn.Linear(params['dim_input'], params['dim_hidden_linear']) 
            self.BlinearCell1 = torch.nn.ModuleList([torch.nn.Linear(params['dim_input'], 1) for i in range(params['bi_linear_layers'])])
            self.BlinearCell2 = torch.nn.ModuleList([torch.nn.Linear(params['dim_input'], 1) for i in range(params['bi_linear_layers'])])
            augmented_size    = params['bi_linear_layers'] + params['dim_hidden_linear']
            self.transLayers = torch.nn.ModuleList([torch.nn.Linear(augmented_size, params['dim_input'])])
            self.transLayers.extend([torch.nn.Linear(params['dim_input'],params['dim_input']) for i in range(1, params['transition_layers'])])
            self.outputLayer  = torch.nn.Linear(params['dim_input'], params['dim_input']) 
        def forward(self, inp, dt):
            """
            In the forward function we accept a Tensor of input data and we must return
            a Tensor of output data. We can use Modules defined in the constructor as
            well as arbitrary operators on Tensors.
            """
            aug_inp = inp
            BP_outp = (torch.zeros((aug_inp.size()[0],params['bi_linear_layers'])))
            L_outp   = self.linearCell(aug_inp)
            for i in range((params['bi_linear_layers'])):
                BP_outp[:,i]=self.BlinearCell1[i](aug_inp)[:,0]*self.BlinearCell2[i](aug_inp)[:,0]
            aug_vect = torch.cat((L_outp, BP_outp), dim=1)
            for i in range((params['transition_layers'])):
                aug_vect = (self.transLayers[i](aug_vect))
            grad = self.outputLayer(aug_vect)
            return grad
model  = FC_net(params)

# %%
class INT_net(torch.nn.Module):
        def __init__(self, params):
            super(INT_net, self).__init__()
#            self.add_module('Dyn_net',FC_net(params))
            self.Dyn_net = model
        def forward(self, inp, dt):
            """
            In the forward function we accept a Tensor of input data and we must return
            a Tensor of output data. We can use Modules defined in the constructor as
            well as arbitrary operators on Tensors.
            """
            k1 = self.Dyn_net(inp,dt)
            inp_k2      = inp + 0.5*params['dt_integration']*k1
            k2     = self.Dyn_net(inp_k2,dt)
            inp_k3      = inp + 0.5*params['dt_integration']*k2       
            k3     = self.Dyn_net(inp_k3,dt)
            inp_k4      = inp + params['dt_integration']*k3          
            k4     = self.Dyn_net(inp_k4,dt)            
            pred = inp +dt*(k1+2*k2+2*k3+k4)/6    
            return pred, k1

# %%
dt = params['dt_integration']
aug_vect = []
x = torch.from_numpy(X_train).float()
y = torch.from_numpy(Y_train).float()
z = torch.from_numpy(Grad_t).float()

modelRINN = INT_net(params)
criterion = torch.nn.MSELoss(reduction='elementwise_mean')
optimizer = torch.optim.Adam(modelRINN.parameters(),lr = 0.001)

if pretrained :
    modelRINN.load_state_dict(torch.load(path + file_name))

# %%
print ('Learning Dynamical model')        
for t in range(params['ntrain'][0]):
    for b in range(x.shape[0]):
        # Forward pass: Compute predicted y by passing x to the model
        pred, grad = modelRINN(x[b,:,:],params['dt_integration'])
        # Compute and print loss
        loss = criterion(grad, z[b,:,:])
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Save models
        #torch.save(modelRINN.state_dict(), path + file_name)
    print(t,loss)
# Out:
# Learning Dynamical model
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:13: UserWarning: reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.
#   warnings.warn("reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.")
# 0 tensor(2167.7939, grad_fn=<MseLossBackward>)
# 1 tensor(1198.2391, grad_fn=<MseLossBackward>)
# 2 tensor(1420.5104, grad_fn=<MseLossBackward>)
# 3 tensor(1438.4559, grad_fn=<MseLossBackward>)
# 4 tensor(1158.2848, grad_fn=<MseLossBackward>)
# 5 tensor(952.7786, grad_fn=<MseLossBackward>)
# 6 tensor(770.1275, grad_fn=<MseLossBackward>)
# 7 tensor(600.9072, grad_fn=<MseLossBackward>)
# 8 tensor(450.3810, grad_fn=<MseLossBackward>)
# 9 tensor(325.1045, grad_fn=<MseLossBackward>)
# 10 tensor(228.3890, grad_fn=<MseLossBackward>)
# 11 tensor(159.1411, grad_fn=<MseLossBackward>)
# 12 tensor(112.8520, grad_fn=<MseLossBackward>)
# 13 tensor(83.5495, grad_fn=<MseLossBackward>)
# 14 tensor(65.5145, grad_fn=<MseLossBackward>)
# 15 tensor(54.1657, grad_fn=<MseLossBackward>)
# 16 tensor(46.2266, grad_fn=<MseLossBackward>)
# 17 tensor(39.5270, grad_fn=<MseLossBackward>)
# 18 tensor(32.7767, grad_fn=<MseLossBackward>)
# 19 tensor(25.7187, grad_fn=<MseLossBackward>)
# 20 tensor(19.9789, grad_fn=<MseLossBackward>)
# 21 tensor(18.8498, grad_fn=<MseLossBackward>)
# 22 tensor(23.2044, grad_fn=<MseLossBackward>)
# 23 tensor(29.5225, grad_fn=<MseLossBackward>)
# 24 tensor(34.2647, grad_fn=<MseLossBackward>)
# 25 tensor(36.5095, grad_fn=<MseLossBackward>)
# 26 tensor(36.9779, grad_fn=<MseLossBackward>)
# 27 tensor(36.5770, grad_fn=<MseLossBackward>)
# 28 tensor(35.8778, grad_fn=<MseLossBackward>)
# 29 tensor(35.1496, grad_fn=<MseLossBackward>)
# 30 tensor(34.4949, grad_fn=<MseLossBackward>)
# 31 tensor(33.9395, grad_fn=<MseLossBackward>)
# 32 tensor(33.4799, grad_fn=<MseLossBackward>)
# 33 tensor(33.1026, grad_fn=<MseLossBackward>)
# 34 tensor(32.7936, grad_fn=<MseLossBackward>)
# 35 tensor(32.5392, grad_fn=<MseLossBackward>)
# 36 tensor(32.3284, grad_fn=<MseLossBackward>)
# 37 tensor(32.1522, grad_fn=<MseLossBackward>)
# 38 tensor(32.0037, grad_fn=<MseLossBackward>)
# 39 tensor(31.8771, grad_fn=<MseLossBackward>)
# 40 tensor(31.7677, grad_fn=<MseLossBackward>)
# 41 tensor(31.6721, grad_fn=<MseLossBackward>)
# 42 tensor(31.5876, grad_fn=<MseLossBackward>)
# 43 tensor(31.5116, grad_fn=<MseLossBackward>)
# 44 tensor(31.4429, grad_fn=<MseLossBackward>)
# 45 tensor(31.3796, grad_fn=<MseLossBackward>)
# 46 tensor(31.3205, grad_fn=<MseLossBackward>)
# 47 tensor(31.2650, grad_fn=<MseLossBackward>)
# 48 tensor(31.2118, grad_fn=<MseLossBackward>)
# 49 tensor(31.1606, grad_fn=<MseLossBackward>)
# 50 tensor(31.1106, grad_fn=<MseLossBackward>)
# 51 tensor(31.0616, grad_fn=<MseLossBackward>)
# 52 tensor(31.0131, grad_fn=<MseLossBackward>)
# 53 tensor(30.9646, grad_fn=<MseLossBackward>)
# 54 tensor(30.9161, grad_fn=<MseLossBackward>)
# 55 tensor(30.8669, grad_fn=<MseLossBackward>)
# 56 tensor(30.8176, grad_fn=<MseLossBackward>)
# 57 tensor(30.7672, grad_fn=<MseLossBackward>)
# 58 tensor(30.7159, grad_fn=<MseLossBackward>)
# 59 tensor(30.6636, grad_fn=<MseLossBackward>)
# 60 tensor(30.6101, grad_fn=<MseLossBackward>)
# 61 tensor(30.5553, grad_fn=<MseLossBackward>)
# 62 tensor(30.4991, grad_fn=<MseLossBackward>)
# 63 tensor(30.4417, grad_fn=<MseLossBackward>)
# 64 tensor(30.3827, grad_fn=<MseLossBackward>)
# 65 tensor(30.3223, grad_fn=<MseLossBackward>)
# 66 tensor(30.2605, grad_fn=<MseLossBackward>)
# 67 tensor(30.1970, grad_fn=<MseLossBackward>)
# 68 tensor(30.1320, grad_fn=<MseLossBackward>)
# 69 tensor(30.0651, grad_fn=<MseLossBackward>)
# 70 tensor(29.9967, grad_fn=<MseLossBackward>)
# 71 tensor(29.9268, grad_fn=<MseLossBackward>)
# 72 tensor(29.8552, grad_fn=<MseLossBackward>)
# 73 tensor(29.7817, grad_fn=<MseLossBackward>)
# 74 tensor(29.7065, grad_fn=<MseLossBackward>)
# 75 tensor(29.6296, grad_fn=<MseLossBackward>)
# 76 tensor(29.5512, grad_fn=<MseLossBackward>)
# 77 tensor(29.4705, grad_fn=<MseLossBackward>)
# 78 tensor(29.3883, grad_fn=<MseLossBackward>)
# 79 tensor(29.3042, grad_fn=<MseLossBackward>)
# 80 tensor(29.2180, grad_fn=<MseLossBackward>)
# 81 tensor(29.1302, grad_fn=<MseLossBackward>)
# 82 tensor(29.0403, grad_fn=<MseLossBackward>)
# 83 tensor(28.9485, grad_fn=<MseLossBackward>)
# 84 tensor(28.8548, grad_fn=<MseLossBackward>)
# 85 tensor(28.7591, grad_fn=<MseLossBackward>)
# 86 tensor(28.6613, grad_fn=<MseLossBackward>)
# 87 tensor(28.5614, grad_fn=<MseLossBackward>)
# 88 tensor(28.4594, grad_fn=<MseLossBackward>)
# 89 tensor(28.3554, grad_fn=<MseLossBackward>)
# 90 tensor(28.2491, grad_fn=<MseLossBackward>)
# 91 tensor(28.1407, grad_fn=<MseLossBackward>)
# 92 tensor(28.0303, grad_fn=<MseLossBackward>)
# 93 tensor(27.9174, grad_fn=<MseLossBackward>)
# 94 tensor(27.8025, grad_fn=<MseLossBackward>)
# 95 tensor(27.6854, grad_fn=<MseLossBackward>)
# 96 tensor(27.5661, grad_fn=<MseLossBackward>)
# 97 tensor(27.4447, grad_fn=<MseLossBackward>)
# 98 tensor(27.3211, grad_fn=<MseLossBackward>)
# 99 tensor(27.1955, grad_fn=<MseLossBackward>)
# 100 tensor(27.0678, grad_fn=<MseLossBackward>)
# 101 tensor(26.9380, grad_fn=<MseLossBackward>)
# 102 tensor(26.8063, grad_fn=<MseLossBackward>)
# 103 tensor(26.6727, grad_fn=<MseLossBackward>)
# 104 tensor(26.5373, grad_fn=<MseLossBackward>)
# 105 tensor(26.4002, grad_fn=<MseLossBackward>)
# 106 tensor(26.2613, grad_fn=<MseLossBackward>)
# 107 tensor(26.1207, grad_fn=<MseLossBackward>)
# 108 tensor(25.9785, grad_fn=<MseLossBackward>)
# 109 tensor(25.8349, grad_fn=<MseLossBackward>)
# 110 tensor(25.6897, grad_fn=<MseLossBackward>)
# 111 tensor(25.5431, grad_fn=<MseLossBackward>)
# 112 tensor(25.3952, grad_fn=<MseLossBackward>)
# 113 tensor(25.2460, grad_fn=<MseLossBackward>)
# 114 tensor(25.0957, grad_fn=<MseLossBackward>)
# 115 tensor(24.9449, grad_fn=<MseLossBackward>)
# 116 tensor(24.7932, grad_fn=<MseLossBackward>)
# 117 tensor(24.6413, grad_fn=<MseLossBackward>)
# 118 tensor(24.4895, grad_fn=<MseLossBackward>)
# 119 tensor(24.3379, grad_fn=<MseLossBackward>)
# 120 tensor(24.1868, grad_fn=<MseLossBackward>)
# 121 tensor(24.0367, grad_fn=<MseLossBackward>)
# 122 tensor(23.8873, grad_fn=<MseLossBackward>)
# 123 tensor(23.7391, grad_fn=<MseLossBackward>)
# 124 tensor(23.5918, grad_fn=<MseLossBackward>)
# 125 tensor(23.4459, grad_fn=<MseLossBackward>)
# 126 tensor(23.3010, grad_fn=<MseLossBackward>)
# 127 tensor(23.1572, grad_fn=<MseLossBackward>)
# 128 tensor(23.0144, grad_fn=<MseLossBackward>)
# 129 tensor(22.8728, grad_fn=<MseLossBackward>)
# 130 tensor(22.7321, grad_fn=<MseLossBackward>)
# 131 tensor(22.5922, grad_fn=<MseLossBackward>)
# 132 tensor(22.4530, grad_fn=<MseLossBackward>)
# 133 tensor(22.3143, grad_fn=<MseLossBackward>)
# 134 tensor(22.1759, grad_fn=<MseLossBackward>)
# 135 tensor(22.0378, grad_fn=<MseLossBackward>)
# 136 tensor(21.8997, grad_fn=<MseLossBackward>)
# 137 tensor(21.7611, grad_fn=<MseLossBackward>)
# 138 tensor(21.6221, grad_fn=<MseLossBackward>)
# 139 tensor(21.4823, grad_fn=<MseLossBackward>)
# 140 tensor(21.3415, grad_fn=<MseLossBackward>)
# 141 tensor(21.1993, grad_fn=<MseLossBackward>)
# 142 tensor(21.0558, grad_fn=<MseLossBackward>)
# 143 tensor(20.9107, grad_fn=<MseLossBackward>)
# 144 tensor(20.7637, grad_fn=<MseLossBackward>)
# 145 tensor(20.6142, grad_fn=<MseLossBackward>)
# 146 tensor(20.4610, grad_fn=<MseLossBackward>)
# 147 tensor(20.3039, grad_fn=<MseLossBackward>)
# 148 tensor(20.1431, grad_fn=<MseLossBackward>)
# 149 tensor(19.9787, grad_fn=<MseLossBackward>)
# 150 tensor(19.8107, grad_fn=<MseLossBackward>)
# 151 tensor(19.6384, grad_fn=<MseLossBackward>)
# 152 tensor(19.4620, grad_fn=<MseLossBackward>)
# 153 tensor(19.2805, grad_fn=<MseLossBackward>)
# 154 tensor(19.0939, grad_fn=<MseLossBackward>)
# 155 tensor(18.9020, grad_fn=<MseLossBackward>)
# 156 tensor(18.7044, grad_fn=<MseLossBackward>)
# 157 tensor(18.5008, grad_fn=<MseLossBackward>)
# 158 tensor(18.2912, grad_fn=<MseLossBackward>)
# 159 tensor(18.0751, grad_fn=<MseLossBackward>)
# 160 tensor(17.8524, grad_fn=<MseLossBackward>)
# 161 tensor(17.6229, grad_fn=<MseLossBackward>)
# 162 tensor(17.3863, grad_fn=<MseLossBackward>)
# 163 tensor(17.1423, grad_fn=<MseLossBackward>)
# 164 tensor(16.8908, grad_fn=<MseLossBackward>)
# 165 tensor(16.6316, grad_fn=<MseLossBackward>)
# 166 tensor(16.3645, grad_fn=<MseLossBackward>)
# 167 tensor(16.0894, grad_fn=<MseLossBackward>)
# 168 tensor(15.8061, grad_fn=<MseLossBackward>)
# 169 tensor(15.5144, grad_fn=<MseLossBackward>)
# 170 tensor(15.2143, grad_fn=<MseLossBackward>)
# 171 tensor(14.9058, grad_fn=<MseLossBackward>)
# 172 tensor(14.5890, grad_fn=<MseLossBackward>)
# 173 tensor(14.2642, grad_fn=<MseLossBackward>)
# 174 tensor(13.9317, grad_fn=<MseLossBackward>)
# 175 tensor(13.5922, grad_fn=<MseLossBackward>)
# 176 tensor(13.2467, grad_fn=<MseLossBackward>)
# 177 tensor(12.8963, grad_fn=<MseLossBackward>)
# 178 tensor(12.5425, grad_fn=<MseLossBackward>)
# 179 tensor(12.1873, grad_fn=<MseLossBackward>)
# 180 tensor(11.8330, grad_fn=<MseLossBackward>)
# 181 tensor(11.4817, grad_fn=<MseLossBackward>)
# 182 tensor(11.1355, grad_fn=<MseLossBackward>)
# 183 tensor(10.7960, grad_fn=<MseLossBackward>)
# 184 tensor(10.4639, grad_fn=<MseLossBackward>)
# 185 tensor(10.1392, grad_fn=<MseLossBackward>)
# 186 tensor(9.8209, grad_fn=<MseLossBackward>)
# 187 tensor(9.5084, grad_fn=<MseLossBackward>)
# 188 tensor(9.2009, grad_fn=<MseLossBackward>)
# 189 tensor(8.8980, grad_fn=<MseLossBackward>)
# 190 tensor(8.5999, grad_fn=<MseLossBackward>)
# 191 tensor(8.3064, grad_fn=<MseLossBackward>)
# 192 tensor(8.0177, grad_fn=<MseLossBackward>)
# 193 tensor(7.7340, grad_fn=<MseLossBackward>)
# 194 tensor(7.4556, grad_fn=<MseLossBackward>)
# 195 tensor(7.1831, grad_fn=<MseLossBackward>)
# 196 tensor(6.9171, grad_fn=<MseLossBackward>)
# 197 tensor(6.6584, grad_fn=<MseLossBackward>)
# 198 tensor(6.4069, grad_fn=<MseLossBackward>)
# 199 tensor(6.1624, grad_fn=<MseLossBackward>)
# 200 tensor(5.9238, grad_fn=<MseLossBackward>)
# 201 tensor(5.6891, grad_fn=<MseLossBackward>)
# 202 tensor(5.4562, grad_fn=<MseLossBackward>)
# 203 tensor(5.2226, grad_fn=<MseLossBackward>)
# 204 tensor(4.9864, grad_fn=<MseLossBackward>)
# 205 tensor(4.7492, grad_fn=<MseLossBackward>)
# 206 tensor(4.5150, grad_fn=<MseLossBackward>)
# 207 tensor(4.2869, grad_fn=<MseLossBackward>)
# 208 tensor(4.0677, grad_fn=<MseLossBackward>)
# 209 tensor(3.8662, grad_fn=<MseLossBackward>)
# 210 tensor(3.6909, grad_fn=<MseLossBackward>)
# 211 tensor(3.5402, grad_fn=<MseLossBackward>)
# 212 tensor(3.4087, grad_fn=<MseLossBackward>)
# 213 tensor(3.2913, grad_fn=<MseLossBackward>)
# 214 tensor(3.1839, grad_fn=<MseLossBackward>)
# 215 tensor(3.0833, grad_fn=<MseLossBackward>)
# 216 tensor(2.9864, grad_fn=<MseLossBackward>)
# 217 tensor(2.8909, grad_fn=<MseLossBackward>)
# 218 tensor(2.7956, grad_fn=<MseLossBackward>)
# 219 tensor(2.7011, grad_fn=<MseLossBackward>)
# 220 tensor(2.6081, grad_fn=<MseLossBackward>)
# 221 tensor(2.5173, grad_fn=<MseLossBackward>)
# 222 tensor(2.4312, grad_fn=<MseLossBackward>)
# 223 tensor(2.3521, grad_fn=<MseLossBackward>)
# 224 tensor(2.2797, grad_fn=<MseLossBackward>)
# 225 tensor(2.2124, grad_fn=<MseLossBackward>)
# 226 tensor(2.1493, grad_fn=<MseLossBackward>)
# 227 tensor(2.0904, grad_fn=<MseLossBackward>)
# 228 tensor(2.0354, grad_fn=<MseLossBackward>)
# 229 tensor(1.9841, grad_fn=<MseLossBackward>)
# 230 tensor(1.9363, grad_fn=<MseLossBackward>)
# 231 tensor(1.8918, grad_fn=<MseLossBackward>)
# 232 tensor(1.8503, grad_fn=<MseLossBackward>)
# 233 tensor(1.8116, grad_fn=<MseLossBackward>)
# 234 tensor(1.7754, grad_fn=<MseLossBackward>)
# 235 tensor(1.7416, grad_fn=<MseLossBackward>)
# 236 tensor(1.7100, grad_fn=<MseLossBackward>)
# 237 tensor(1.6803, grad_fn=<MseLossBackward>)
# 238 tensor(1.6526, grad_fn=<MseLossBackward>)
# 239 tensor(1.6268, grad_fn=<MseLossBackward>)
# 240 tensor(1.6028, grad_fn=<MseLossBackward>)
# 241 tensor(1.5806, grad_fn=<MseLossBackward>)
# 242 tensor(1.5599, grad_fn=<MseLossBackward>)
# 243 tensor(1.5408, grad_fn=<MseLossBackward>)
# 244 tensor(1.5230, grad_fn=<MseLossBackward>)
# 245 tensor(1.5065, grad_fn=<MseLossBackward>)
# 246 tensor(1.4913, grad_fn=<MseLossBackward>)
# 247 tensor(1.4772, grad_fn=<MseLossBackward>)
# 248 tensor(1.4642, grad_fn=<MseLossBackward>)
# 249 tensor(1.4522, grad_fn=<MseLossBackward>)
# 250 tensor(1.4410, grad_fn=<MseLossBackward>)
# 251 tensor(1.4308, grad_fn=<MseLossBackward>)
# 252 tensor(1.4214, grad_fn=<MseLossBackward>)
# 253 tensor(1.4127, grad_fn=<MseLossBackward>)
# 254 tensor(1.4047, grad_fn=<MseLossBackward>)
# 255 tensor(1.3974, grad_fn=<MseLossBackward>)
# 256 tensor(1.3907, grad_fn=<MseLossBackward>)
# 257 tensor(1.3846, grad_fn=<MseLossBackward>)
# 258 tensor(1.3790, grad_fn=<MseLossBackward>)
# 259 tensor(1.3739, grad_fn=<MseLossBackward>)
# 260 tensor(1.3693, grad_fn=<MseLossBackward>)
# 261 tensor(1.3651, grad_fn=<MseLossBackward>)
# 262 tensor(1.3614, grad_fn=<MseLossBackward>)
# 263 tensor(1.3580, grad_fn=<MseLossBackward>)
# 264 tensor(1.3551, grad_fn=<MseLossBackward>)
# 265 tensor(1.3525, grad_fn=<MseLossBackward>)
# 266 tensor(1.3502, grad_fn=<MseLossBackward>)
# 267 tensor(1.3482, grad_fn=<MseLossBackward>)
# 268 tensor(1.3465, grad_fn=<MseLossBackward>)
# 269 tensor(1.3451, grad_fn=<MseLossBackward>)
# 270 tensor(1.3437, grad_fn=<MseLossBackward>)
# 271 tensor(1.3427, grad_fn=<MseLossBackward>)
# 272 tensor(1.3415, grad_fn=<MseLossBackward>)
# 273 tensor(1.3406, grad_fn=<MseLossBackward>)
# 274 tensor(1.3394, grad_fn=<MseLossBackward>)
# 275 tensor(1.3387, grad_fn=<MseLossBackward>)
# 276 tensor(1.3374, grad_fn=<MseLossBackward>)
# 277 tensor(1.3371, grad_fn=<MseLossBackward>)
# 278 tensor(1.3354, grad_fn=<MseLossBackward>)
# 279 tensor(1.3357, grad_fn=<MseLossBackward>)
# 280 tensor(1.3334, grad_fn=<MseLossBackward>)
# 281 tensor(1.3347, grad_fn=<MseLossBackward>)
# 282 tensor(1.3312, grad_fn=<MseLossBackward>)
# 283 tensor(1.3348, grad_fn=<MseLossBackward>)
# 284 tensor(1.3287, grad_fn=<MseLossBackward>)
# 285 tensor(1.3369, grad_fn=<MseLossBackward>)
# 286 tensor(1.3264, grad_fn=<MseLossBackward>)
# 287 tensor(1.3428, grad_fn=<MseLossBackward>)
# 288 tensor(1.3258, grad_fn=<MseLossBackward>)
# 289 tensor(1.3516, grad_fn=<MseLossBackward>)
# 290 tensor(1.3274, grad_fn=<MseLossBackward>)
# 291 tensor(1.3541, grad_fn=<MseLossBackward>)
# 292 tensor(1.3277, grad_fn=<MseLossBackward>)
# 293 tensor(1.3534, grad_fn=<MseLossBackward>)
# 294 tensor(1.3269, grad_fn=<MseLossBackward>)
# 295 tensor(1.3532, grad_fn=<MseLossBackward>)
# 296 tensor(1.3263, grad_fn=<MseLossBackward>)
# 297 tensor(1.3528, grad_fn=<MseLossBackward>)
# 298 tensor(1.3256, grad_fn=<MseLossBackward>)
# 299 tensor(1.3524, grad_fn=<MseLossBackward>)
# 300 tensor(1.3250, grad_fn=<MseLossBackward>)
# 301 tensor(1.3519, grad_fn=<MseLossBackward>)
# 302 tensor(1.3245, grad_fn=<MseLossBackward>)
# 303 tensor(1.3513, grad_fn=<MseLossBackward>)
# 304 tensor(1.3241, grad_fn=<MseLossBackward>)
# 305 tensor(1.3507, grad_fn=<MseLossBackward>)
# 306 tensor(1.3237, grad_fn=<MseLossBackward>)
# 307 tensor(1.3499, grad_fn=<MseLossBackward>)
# 308 tensor(1.3233, grad_fn=<MseLossBackward>)
# 309 tensor(1.3491, grad_fn=<MseLossBackward>)
# 310 tensor(1.3231, grad_fn=<MseLossBackward>)
# 311 tensor(1.3482, grad_fn=<MseLossBackward>)
# 312 tensor(1.3229, grad_fn=<MseLossBackward>)
# 313 tensor(1.3472, grad_fn=<MseLossBackward>)
# 314 tensor(1.3228, grad_fn=<MseLossBackward>)
# 315 tensor(1.3461, grad_fn=<MseLossBackward>)
# 316 tensor(1.3228, grad_fn=<MseLossBackward>)
# 317 tensor(1.3450, grad_fn=<MseLossBackward>)
# 318 tensor(1.3228, grad_fn=<MseLossBackward>)
# 319 tensor(1.3438, grad_fn=<MseLossBackward>)
# 320 tensor(1.3231, grad_fn=<MseLossBackward>)
# 321 tensor(1.3426, grad_fn=<MseLossBackward>)
# 322 tensor(1.3234, grad_fn=<MseLossBackward>)
# 323 tensor(1.3412, grad_fn=<MseLossBackward>)
# 324 tensor(1.3238, grad_fn=<MseLossBackward>)
# 325 tensor(1.3400, grad_fn=<MseLossBackward>)
# 326 tensor(1.3243, grad_fn=<MseLossBackward>)
# 327 tensor(1.3387, grad_fn=<MseLossBackward>)
# 328 tensor(1.3250, grad_fn=<MseLossBackward>)
# 329 tensor(1.3373, grad_fn=<MseLossBackward>)
# 330 tensor(1.3259, grad_fn=<MseLossBackward>)
# 331 tensor(1.3361, grad_fn=<MseLossBackward>)
# 332 tensor(1.3269, grad_fn=<MseLossBackward>)
# 333 tensor(1.3349, grad_fn=<MseLossBackward>)
# 334 tensor(1.3281, grad_fn=<MseLossBackward>)
# 335 tensor(1.3339, grad_fn=<MseLossBackward>)
# 336 tensor(1.3293, grad_fn=<MseLossBackward>)
# 337 tensor(1.3332, grad_fn=<MseLossBackward>)
# 338 tensor(1.3306, grad_fn=<MseLossBackward>)
# 339 tensor(1.3329, grad_fn=<MseLossBackward>)
# 340 tensor(1.3317, grad_fn=<MseLossBackward>)
# 341 tensor(1.3329, grad_fn=<MseLossBackward>)
# 342 tensor(1.3327, grad_fn=<MseLossBackward>)
# 343 tensor(1.3333, grad_fn=<MseLossBackward>)
# 344 tensor(1.3336, grad_fn=<MseLossBackward>)
# 345 tensor(1.3339, grad_fn=<MseLossBackward>)
# 346 tensor(1.3343, grad_fn=<MseLossBackward>)
# 347 tensor(1.3346, grad_fn=<MseLossBackward>)
# 348 tensor(1.3350, grad_fn=<MseLossBackward>)
# 349 tensor(1.3354, grad_fn=<MseLossBackward>)
# 350 tensor(1.3358, grad_fn=<MseLossBackward>)
# 351 tensor(1.3362, grad_fn=<MseLossBackward>)
# 352 tensor(1.3366, grad_fn=<MseLossBackward>)
# 353 tensor(1.3369, grad_fn=<MseLossBackward>)
# 354 tensor(1.3373, grad_fn=<MseLossBackward>)
# 355 tensor(1.3377, grad_fn=<MseLossBackward>)
# 356 tensor(1.3381, grad_fn=<MseLossBackward>)
# 357 tensor(1.3385, grad_fn=<MseLossBackward>)
# 358 tensor(1.3390, grad_fn=<MseLossBackward>)
# 359 tensor(1.3393, grad_fn=<MseLossBackward>)
# 360 tensor(1.3397, grad_fn=<MseLossBackward>)
# 361 tensor(1.3401, grad_fn=<MseLossBackward>)
# 362 tensor(1.3405, grad_fn=<MseLossBackward>)
# 363 tensor(1.3409, grad_fn=<MseLossBackward>)
# 364 tensor(1.3414, grad_fn=<MseLossBackward>)
# 365 tensor(1.3418, grad_fn=<MseLossBackward>)
# 366 tensor(1.3422, grad_fn=<MseLossBackward>)
# 367 tensor(1.3426, grad_fn=<MseLossBackward>)
# 368 tensor(1.3430, grad_fn=<MseLossBackward>)
# 369 tensor(1.3434, grad_fn=<MseLossBackward>)
# 370 tensor(1.3438, grad_fn=<MseLossBackward>)
# 371 tensor(1.3443, grad_fn=<MseLossBackward>)
# 372 tensor(1.3447, grad_fn=<MseLossBackward>)
# 373 tensor(1.3450, grad_fn=<MseLossBackward>)
# 374 tensor(1.3455, grad_fn=<MseLossBackward>)
# 375 tensor(1.3459, grad_fn=<MseLossBackward>)
# 376 tensor(1.3463, grad_fn=<MseLossBackward>)
# 377 tensor(1.3467, grad_fn=<MseLossBackward>)
# 378 tensor(1.3471, grad_fn=<MseLossBackward>)
# 379 tensor(1.3476, grad_fn=<MseLossBackward>)
# 380 tensor(1.3480, grad_fn=<MseLossBackward>)
# 381 tensor(1.3484, grad_fn=<MseLossBackward>)
# 382 tensor(1.3489, grad_fn=<MseLossBackward>)
# 383 tensor(1.3493, grad_fn=<MseLossBackward>)
# 384 tensor(1.3498, grad_fn=<MseLossBackward>)
# 385 tensor(1.3503, grad_fn=<MseLossBackward>)
# 386 tensor(1.3510, grad_fn=<MseLossBackward>)
# 387 tensor(1.3517, grad_fn=<MseLossBackward>)
# 388 tensor(1.3529, grad_fn=<MseLossBackward>)
# 389 tensor(1.3551, grad_fn=<MseLossBackward>)
# 390 tensor(1.3606, grad_fn=<MseLossBackward>)
# 391 tensor(1.3761, grad_fn=<MseLossBackward>)
# 392 tensor(1.3803, grad_fn=<MseLossBackward>)
# 393 tensor(1.3727, grad_fn=<MseLossBackward>)
# 394 tensor(1.3744, grad_fn=<MseLossBackward>)
# 395 tensor(1.3722, grad_fn=<MseLossBackward>)
# 396 tensor(1.3685, grad_fn=<MseLossBackward>)
# 397 tensor(1.3651, grad_fn=<MseLossBackward>)
# 398 tensor(1.3630, grad_fn=<MseLossBackward>)
# 399 tensor(1.3618, grad_fn=<MseLossBackward>)
# 400 tensor(1.3614, grad_fn=<MseLossBackward>)
# 401 tensor(1.3613, grad_fn=<MseLossBackward>)
# 402 tensor(1.3614, grad_fn=<MseLossBackward>)
# 403 tensor(1.3616, grad_fn=<MseLossBackward>)
# 404 tensor(1.3618, grad_fn=<MseLossBackward>)
# 405 tensor(1.3620, grad_fn=<MseLossBackward>)
# 406 tensor(1.3621, grad_fn=<MseLossBackward>)
# 407 tensor(1.3622, grad_fn=<MseLossBackward>)
# 408 tensor(1.3623, grad_fn=<MseLossBackward>)
# 409 tensor(1.3624, grad_fn=<MseLossBackward>)
# 410 tensor(1.3624, grad_fn=<MseLossBackward>)
# 411 tensor(1.3625, grad_fn=<MseLossBackward>)
# 412 tensor(1.3625, grad_fn=<MseLossBackward>)
# 413 tensor(1.3625, grad_fn=<MseLossBackward>)
# 414 tensor(1.3625, grad_fn=<MseLossBackward>)
# 415 tensor(1.3625, grad_fn=<MseLossBackward>)
# 416 tensor(1.3624, grad_fn=<MseLossBackward>)
# 417 tensor(1.3624, grad_fn=<MseLossBackward>)
# 418 tensor(1.3623, grad_fn=<MseLossBackward>)
# 419 tensor(1.3623, grad_fn=<MseLossBackward>)
# 420 tensor(1.3621, grad_fn=<MseLossBackward>)
# 421 tensor(1.3620, grad_fn=<MseLossBackward>)
# 422 tensor(1.3619, grad_fn=<MseLossBackward>)
# 423 tensor(1.3618, grad_fn=<MseLossBackward>)
# 424 tensor(1.3616, grad_fn=<MseLossBackward>)
# 425 tensor(1.3614, grad_fn=<MseLossBackward>)
# 426 tensor(1.3612, grad_fn=<MseLossBackward>)
# 427 tensor(1.3610, grad_fn=<MseLossBackward>)
# 428 tensor(1.3608, grad_fn=<MseLossBackward>)
# 429 tensor(1.3605, grad_fn=<MseLossBackward>)
# 430 tensor(1.3603, grad_fn=<MseLossBackward>)
# 431 tensor(1.3600, grad_fn=<MseLossBackward>)
# 432 tensor(1.3597, grad_fn=<MseLossBackward>)
# 433 tensor(1.3594, grad_fn=<MseLossBackward>)
# 434 tensor(1.3590, grad_fn=<MseLossBackward>)
# 435 tensor(1.3587, grad_fn=<MseLossBackward>)
# 436 tensor(1.3583, grad_fn=<MseLossBackward>)
# 437 tensor(1.3579, grad_fn=<MseLossBackward>)
# 438 tensor(1.3575, grad_fn=<MseLossBackward>)
# 439 tensor(1.3570, grad_fn=<MseLossBackward>)
# 440 tensor(1.3566, grad_fn=<MseLossBackward>)
# 441 tensor(1.3561, grad_fn=<MseLossBackward>)
# 442 tensor(1.3556, grad_fn=<MseLossBackward>)
# 443 tensor(1.3551, grad_fn=<MseLossBackward>)
# 444 tensor(1.3546, grad_fn=<MseLossBackward>)
# 445 tensor(1.3541, grad_fn=<MseLossBackward>)
# 446 tensor(1.3536, grad_fn=<MseLossBackward>)
# 447 tensor(1.3531, grad_fn=<MseLossBackward>)
# 448 tensor(1.3525, grad_fn=<MseLossBackward>)
# 449 tensor(1.3520, grad_fn=<MseLossBackward>)
# 450 tensor(1.3515, grad_fn=<MseLossBackward>)
# 451 tensor(1.3510, grad_fn=<MseLossBackward>)
# 452 tensor(1.3505, grad_fn=<MseLossBackward>)
# 453 tensor(1.3500, grad_fn=<MseLossBackward>)
# 454 tensor(1.3496, grad_fn=<MseLossBackward>)
# 455 tensor(1.3491, grad_fn=<MseLossBackward>)
# 456 tensor(1.3486, grad_fn=<MseLossBackward>)
# 457 tensor(1.3482, grad_fn=<MseLossBackward>)
# 458 tensor(1.3478, grad_fn=<MseLossBackward>)
# 459 tensor(1.3474, grad_fn=<MseLossBackward>)
# 460 tensor(1.3470, grad_fn=<MseLossBackward>)
# 461 tensor(1.3466, grad_fn=<MseLossBackward>)
# 462 tensor(1.3463, grad_fn=<MseLossBackward>)
# 463 tensor(1.3459, grad_fn=<MseLossBackward>)
# 464 tensor(1.3456, grad_fn=<MseLossBackward>)
# 465 tensor(1.3453, grad_fn=<MseLossBackward>)
# 466 tensor(1.3450, grad_fn=<MseLossBackward>)
# 467 tensor(1.3447, grad_fn=<MseLossBackward>)
# 468 tensor(1.3445, grad_fn=<MseLossBackward>)
# 469 tensor(1.3442, grad_fn=<MseLossBackward>)
# 470 tensor(1.3440, grad_fn=<MseLossBackward>)
# 471 tensor(1.3437, grad_fn=<MseLossBackward>)
# 472 tensor(1.3435, grad_fn=<MseLossBackward>)
# 473 tensor(1.3433, grad_fn=<MseLossBackward>)
# 474 tensor(1.3431, grad_fn=<MseLossBackward>)
# 475 tensor(1.3428, grad_fn=<MseLossBackward>)
# 476 tensor(1.3426, grad_fn=<MseLossBackward>)
# 477 tensor(1.3425, grad_fn=<MseLossBackward>)
# 478 tensor(1.3423, grad_fn=<MseLossBackward>)
# 479 tensor(1.3421, grad_fn=<MseLossBackward>)
# 480 tensor(1.3419, grad_fn=<MseLossBackward>)
# 481 tensor(1.3418, grad_fn=<MseLossBackward>)
# 482 tensor(1.3416, grad_fn=<MseLossBackward>)
# 483 tensor(1.3414, grad_fn=<MseLossBackward>)
# 484 tensor(1.3413, grad_fn=<MseLossBackward>)
# 485 tensor(1.3411, grad_fn=<MseLossBackward>)
# 486 tensor(1.3410, grad_fn=<MseLossBackward>)
# 487 tensor(1.3409, grad_fn=<MseLossBackward>)
# 488 tensor(1.3408, grad_fn=<MseLossBackward>)
# 489 tensor(1.3405, grad_fn=<MseLossBackward>)
# 490 tensor(1.3407, grad_fn=<MseLossBackward>)
# 491 tensor(1.3401, grad_fn=<MseLossBackward>)
# 492 tensor(1.3406, grad_fn=<MseLossBackward>)
# 493 tensor(1.3396, grad_fn=<MseLossBackward>)
# 494 tensor(1.3407, grad_fn=<MseLossBackward>)
# 495 tensor(1.3387, grad_fn=<MseLossBackward>)
# 496 tensor(1.3408, grad_fn=<MseLossBackward>)
# 497 tensor(1.3374, grad_fn=<MseLossBackward>)
# 498 tensor(1.3405, grad_fn=<MseLossBackward>)
# 499 tensor(1.3367, grad_fn=<MseLossBackward>)
# 500 tensor(1.3393, grad_fn=<MseLossBackward>)
# 501 tensor(1.3386, grad_fn=<MseLossBackward>)
# 502 tensor(1.3374, grad_fn=<MseLossBackward>)
# 503 tensor(1.3409, grad_fn=<MseLossBackward>)
# 504 tensor(1.3362, grad_fn=<MseLossBackward>)
# 505 tensor(1.3411, grad_fn=<MseLossBackward>)
# 506 tensor(1.3361, grad_fn=<MseLossBackward>)
# 507 tensor(1.3401, grad_fn=<MseLossBackward>)
# 508 tensor(1.3363, grad_fn=<MseLossBackward>)
# 509 tensor(1.3394, grad_fn=<MseLossBackward>)
# 510 tensor(1.3363, grad_fn=<MseLossBackward>)
# 511 tensor(1.3393, grad_fn=<MseLossBackward>)
# 512 tensor(1.3361, grad_fn=<MseLossBackward>)
# 513 tensor(1.3391, grad_fn=<MseLossBackward>)
# 514 tensor(1.3361, grad_fn=<MseLossBackward>)
# 515 tensor(1.3386, grad_fn=<MseLossBackward>)
# 516 tensor(1.3361, grad_fn=<MseLossBackward>)
# 517 tensor(1.3383, grad_fn=<MseLossBackward>)
# 518 tensor(1.3361, grad_fn=<MseLossBackward>)
# 519 tensor(1.3379, grad_fn=<MseLossBackward>)
# 520 tensor(1.3362, grad_fn=<MseLossBackward>)
# 521 tensor(1.3375, grad_fn=<MseLossBackward>)
# 522 tensor(1.3362, grad_fn=<MseLossBackward>)
# 523 tensor(1.3371, grad_fn=<MseLossBackward>)
# 524 tensor(1.3363, grad_fn=<MseLossBackward>)
# 525 tensor(1.3368, grad_fn=<MseLossBackward>)
# 526 tensor(1.3364, grad_fn=<MseLossBackward>)
# 527 tensor(1.3364, grad_fn=<MseLossBackward>)
# 528 tensor(1.3366, grad_fn=<MseLossBackward>)
# 529 tensor(1.3360, grad_fn=<MseLossBackward>)
# 530 tensor(1.3367, grad_fn=<MseLossBackward>)
# 531 tensor(1.3356, grad_fn=<MseLossBackward>)
# 532 tensor(1.3368, grad_fn=<MseLossBackward>)
# 533 tensor(1.3353, grad_fn=<MseLossBackward>)
# 534 tensor(1.3369, grad_fn=<MseLossBackward>)
# 535 tensor(1.3349, grad_fn=<MseLossBackward>)
# 536 tensor(1.3371, grad_fn=<MseLossBackward>)
# 537 tensor(1.3345, grad_fn=<MseLossBackward>)
# 538 tensor(1.3373, grad_fn=<MseLossBackward>)
# 539 tensor(1.3342, grad_fn=<MseLossBackward>)
# 540 tensor(1.3375, grad_fn=<MseLossBackward>)
# 541 tensor(1.3338, grad_fn=<MseLossBackward>)
# 542 tensor(1.3378, grad_fn=<MseLossBackward>)
# 543 tensor(1.3334, grad_fn=<MseLossBackward>)
# 544 tensor(1.3380, grad_fn=<MseLossBackward>)
# 545 tensor(1.3331, grad_fn=<MseLossBackward>)
# 546 tensor(1.3383, grad_fn=<MseLossBackward>)
# 547 tensor(1.3328, grad_fn=<MseLossBackward>)
# 548 tensor(1.3385, grad_fn=<MseLossBackward>)
# 549 tensor(1.3325, grad_fn=<MseLossBackward>)
# 550 tensor(1.3388, grad_fn=<MseLossBackward>)
# 551 tensor(1.3321, grad_fn=<MseLossBackward>)
# 552 tensor(1.3391, grad_fn=<MseLossBackward>)
# 553 tensor(1.3318, grad_fn=<MseLossBackward>)
# 554 tensor(1.3393, grad_fn=<MseLossBackward>)
# 555 tensor(1.3315, grad_fn=<MseLossBackward>)
# 556 tensor(1.3396, grad_fn=<MseLossBackward>)
# 557 tensor(1.3313, grad_fn=<MseLossBackward>)
# 558 tensor(1.3399, grad_fn=<MseLossBackward>)
# 559 tensor(1.3309, grad_fn=<MseLossBackward>)
# 560 tensor(1.3402, grad_fn=<MseLossBackward>)
# 561 tensor(1.3307, grad_fn=<MseLossBackward>)
# 562 tensor(1.3405, grad_fn=<MseLossBackward>)
# 563 tensor(1.3305, grad_fn=<MseLossBackward>)
# 564 tensor(1.3408, grad_fn=<MseLossBackward>)
# 565 tensor(1.3303, grad_fn=<MseLossBackward>)
# 566 tensor(1.3411, grad_fn=<MseLossBackward>)
# 567 tensor(1.3300, grad_fn=<MseLossBackward>)
# 568 tensor(1.3414, grad_fn=<MseLossBackward>)
# 569 tensor(1.3298, grad_fn=<MseLossBackward>)
# 570 tensor(1.3417, grad_fn=<MseLossBackward>)
# 571 tensor(1.3296, grad_fn=<MseLossBackward>)
# 572 tensor(1.3420, grad_fn=<MseLossBackward>)
# 573 tensor(1.3295, grad_fn=<MseLossBackward>)
# 574 tensor(1.3423, grad_fn=<MseLossBackward>)
# 575 tensor(1.3293, grad_fn=<MseLossBackward>)
# 576 tensor(1.3426, grad_fn=<MseLossBackward>)
# 577 tensor(1.3292, grad_fn=<MseLossBackward>)
# 578 tensor(1.3429, grad_fn=<MseLossBackward>)
# 579 tensor(1.3291, grad_fn=<MseLossBackward>)
# 580 tensor(1.3432, grad_fn=<MseLossBackward>)
# 581 tensor(1.3290, grad_fn=<MseLossBackward>)
# 582 tensor(1.3435, grad_fn=<MseLossBackward>)
# 583 tensor(1.3290, grad_fn=<MseLossBackward>)
# 584 tensor(1.3437, grad_fn=<MseLossBackward>)
# 585 tensor(1.3289, grad_fn=<MseLossBackward>)
# 586 tensor(1.3440, grad_fn=<MseLossBackward>)
# 587 tensor(1.3288, grad_fn=<MseLossBackward>)
# 588 tensor(1.3443, grad_fn=<MseLossBackward>)
# 589 tensor(1.3288, grad_fn=<MseLossBackward>)
# 590 tensor(1.3445, grad_fn=<MseLossBackward>)
# 591 tensor(1.3289, grad_fn=<MseLossBackward>)
# 592 tensor(1.3447, grad_fn=<MseLossBackward>)
# 593 tensor(1.3289, grad_fn=<MseLossBackward>)
# 594 tensor(1.3450, grad_fn=<MseLossBackward>)
# 595 tensor(1.3289, grad_fn=<MseLossBackward>)
# 596 tensor(1.3452, grad_fn=<MseLossBackward>)
# 597 tensor(1.3290, grad_fn=<MseLossBackward>)
# 598 tensor(1.3454, grad_fn=<MseLossBackward>)
# 599 tensor(1.3291, grad_fn=<MseLossBackward>)
# 600 tensor(1.3456, grad_fn=<MseLossBackward>)
# 601 tensor(1.3292, grad_fn=<MseLossBackward>)
# 602 tensor(1.3458, grad_fn=<MseLossBackward>)
# 603 tensor(1.3293, grad_fn=<MseLossBackward>)
# 604 tensor(1.3459, grad_fn=<MseLossBackward>)
# 605 tensor(1.3295, grad_fn=<MseLossBackward>)
# 606 tensor(1.3461, grad_fn=<MseLossBackward>)
# 607 tensor(1.3297, grad_fn=<MseLossBackward>)
# 608 tensor(1.3462, grad_fn=<MseLossBackward>)
# 609 tensor(1.3299, grad_fn=<MseLossBackward>)
# 610 tensor(1.3463, grad_fn=<MseLossBackward>)
# 611 tensor(1.3301, grad_fn=<MseLossBackward>)
# 612 tensor(1.3464, grad_fn=<MseLossBackward>)
# 613 tensor(1.3304, grad_fn=<MseLossBackward>)
# 614 tensor(1.3465, grad_fn=<MseLossBackward>)
# 615 tensor(1.3306, grad_fn=<MseLossBackward>)
# 616 tensor(1.3466, grad_fn=<MseLossBackward>)
# 617 tensor(1.3308, grad_fn=<MseLossBackward>)
# 618 tensor(1.3466, grad_fn=<MseLossBackward>)
# 619 tensor(1.3311, grad_fn=<MseLossBackward>)
# 620 tensor(1.3467, grad_fn=<MseLossBackward>)
# 621 tensor(1.3315, grad_fn=<MseLossBackward>)
# 622 tensor(1.3467, grad_fn=<MseLossBackward>)
# 623 tensor(1.3318, grad_fn=<MseLossBackward>)
# 624 tensor(1.3468, grad_fn=<MseLossBackward>)
# 625 tensor(1.3322, grad_fn=<MseLossBackward>)
# 626 tensor(1.3467, grad_fn=<MseLossBackward>)
# 627 tensor(1.3325, grad_fn=<MseLossBackward>)
# 628 tensor(1.3468, grad_fn=<MseLossBackward>)
# 629 tensor(1.3328, grad_fn=<MseLossBackward>)
# 630 tensor(1.3468, grad_fn=<MseLossBackward>)
# 631 tensor(1.3332, grad_fn=<MseLossBackward>)
# 632 tensor(1.3467, grad_fn=<MseLossBackward>)
# 633 tensor(1.3336, grad_fn=<MseLossBackward>)
# 634 tensor(1.3467, grad_fn=<MseLossBackward>)
# 635 tensor(1.3340, grad_fn=<MseLossBackward>)
# 636 tensor(1.3467, grad_fn=<MseLossBackward>)
# 637 tensor(1.3344, grad_fn=<MseLossBackward>)
# 638 tensor(1.3467, grad_fn=<MseLossBackward>)
# 639 tensor(1.3348, grad_fn=<MseLossBackward>)
# 640 tensor(1.3466, grad_fn=<MseLossBackward>)
# 641 tensor(1.3352, grad_fn=<MseLossBackward>)
# 642 tensor(1.3466, grad_fn=<MseLossBackward>)
# 643 tensor(1.3356, grad_fn=<MseLossBackward>)
# 644 tensor(1.3465, grad_fn=<MseLossBackward>)
# 645 tensor(1.3361, grad_fn=<MseLossBackward>)
# 646 tensor(1.3465, grad_fn=<MseLossBackward>)
# 647 tensor(1.3365, grad_fn=<MseLossBackward>)
# 648 tensor(1.3464, grad_fn=<MseLossBackward>)
# 649 tensor(1.3369, grad_fn=<MseLossBackward>)
# 650 tensor(1.3464, grad_fn=<MseLossBackward>)
# 651 tensor(1.3372, grad_fn=<MseLossBackward>)
# 652 tensor(1.3464, grad_fn=<MseLossBackward>)
# 653 tensor(1.3377, grad_fn=<MseLossBackward>)
# 654 tensor(1.3463, grad_fn=<MseLossBackward>)
# 655 tensor(1.3382, grad_fn=<MseLossBackward>)
# 656 tensor(1.3462, grad_fn=<MseLossBackward>)
# 657 tensor(1.3386, grad_fn=<MseLossBackward>)
# 658 tensor(1.3462, grad_fn=<MseLossBackward>)
# 659 tensor(1.3391, grad_fn=<MseLossBackward>)
# 660 tensor(1.3461, grad_fn=<MseLossBackward>)
# 661 tensor(1.3395, grad_fn=<MseLossBackward>)
# 662 tensor(1.3461, grad_fn=<MseLossBackward>)
# 663 tensor(1.3400, grad_fn=<MseLossBackward>)
# 664 tensor(1.3460, grad_fn=<MseLossBackward>)
# 665 tensor(1.3404, grad_fn=<MseLossBackward>)
# 666 tensor(1.3459, grad_fn=<MseLossBackward>)
# 667 tensor(1.3409, grad_fn=<MseLossBackward>)
# 668 tensor(1.3459, grad_fn=<MseLossBackward>)
# 669 tensor(1.3414, grad_fn=<MseLossBackward>)
# 670 tensor(1.3458, grad_fn=<MseLossBackward>)
# 671 tensor(1.3418, grad_fn=<MseLossBackward>)
# 672 tensor(1.3458, grad_fn=<MseLossBackward>)
# 673 tensor(1.3423, grad_fn=<MseLossBackward>)
# 674 tensor(1.3457, grad_fn=<MseLossBackward>)
# 675 tensor(1.3428, grad_fn=<MseLossBackward>)
# 676 tensor(1.3456, grad_fn=<MseLossBackward>)
# 677 tensor(1.3433, grad_fn=<MseLossBackward>)
# 678 tensor(1.3456, grad_fn=<MseLossBackward>)
# 679 tensor(1.3438, grad_fn=<MseLossBackward>)
# 680 tensor(1.3455, grad_fn=<MseLossBackward>)
# 681 tensor(1.3444, grad_fn=<MseLossBackward>)
# 682 tensor(1.3454, grad_fn=<MseLossBackward>)
# 683 tensor(1.3449, grad_fn=<MseLossBackward>)
# 684 tensor(1.3454, grad_fn=<MseLossBackward>)
# 685 tensor(1.3454, grad_fn=<MseLossBackward>)
# 686 tensor(1.3453, grad_fn=<MseLossBackward>)
# 687 tensor(1.3459, grad_fn=<MseLossBackward>)
# 688 tensor(1.3453, grad_fn=<MseLossBackward>)
# 689 tensor(1.3463, grad_fn=<MseLossBackward>)
# 690 tensor(1.3452, grad_fn=<MseLossBackward>)
# 691 tensor(1.3469, grad_fn=<MseLossBackward>)
# 692 tensor(1.3451, grad_fn=<MseLossBackward>)
# 693 tensor(1.3475, grad_fn=<MseLossBackward>)
# 694 tensor(1.3451, grad_fn=<MseLossBackward>)
# 695 tensor(1.3480, grad_fn=<MseLossBackward>)
# 696 tensor(1.3450, grad_fn=<MseLossBackward>)
# 697 tensor(1.3485, grad_fn=<MseLossBackward>)
# 698 tensor(1.3450, grad_fn=<MseLossBackward>)
# 699 tensor(1.3491, grad_fn=<MseLossBackward>)
# 700 tensor(1.3449, grad_fn=<MseLossBackward>)
# 701 tensor(1.3496, grad_fn=<MseLossBackward>)
# 702 tensor(1.3448, grad_fn=<MseLossBackward>)
# 703 tensor(1.3502, grad_fn=<MseLossBackward>)
# 704 tensor(1.3447, grad_fn=<MseLossBackward>)
# 705 tensor(1.3507, grad_fn=<MseLossBackward>)
# 706 tensor(1.3447, grad_fn=<MseLossBackward>)
# 707 tensor(1.3512, grad_fn=<MseLossBackward>)
# 708 tensor(1.3447, grad_fn=<MseLossBackward>)
# 709 tensor(1.3518, grad_fn=<MseLossBackward>)
# 710 tensor(1.3447, grad_fn=<MseLossBackward>)
# 711 tensor(1.3523, grad_fn=<MseLossBackward>)
# 712 tensor(1.3446, grad_fn=<MseLossBackward>)
# 713 tensor(1.3529, grad_fn=<MseLossBackward>)
# 714 tensor(1.3446, grad_fn=<MseLossBackward>)
# 715 tensor(1.3534, grad_fn=<MseLossBackward>)
# 716 tensor(1.3446, grad_fn=<MseLossBackward>)
# 717 tensor(1.3539, grad_fn=<MseLossBackward>)
# 718 tensor(1.3446, grad_fn=<MseLossBackward>)
# 719 tensor(1.3545, grad_fn=<MseLossBackward>)
# 720 tensor(1.3446, grad_fn=<MseLossBackward>)
# 721 tensor(1.3551, grad_fn=<MseLossBackward>)
# 722 tensor(1.3445, grad_fn=<MseLossBackward>)
# 723 tensor(1.3556, grad_fn=<MseLossBackward>)
# 724 tensor(1.3446, grad_fn=<MseLossBackward>)
# 725 tensor(1.3560, grad_fn=<MseLossBackward>)
# 726 tensor(1.3446, grad_fn=<MseLossBackward>)
# 727 tensor(1.3566, grad_fn=<MseLossBackward>)
# 728 tensor(1.3446, grad_fn=<MseLossBackward>)
# 729 tensor(1.3571, grad_fn=<MseLossBackward>)
# 730 tensor(1.3446, grad_fn=<MseLossBackward>)
# 731 tensor(1.3576, grad_fn=<MseLossBackward>)
# 732 tensor(1.3447, grad_fn=<MseLossBackward>)
# 733 tensor(1.3581, grad_fn=<MseLossBackward>)
# 734 tensor(1.3447, grad_fn=<MseLossBackward>)
# 735 tensor(1.3586, grad_fn=<MseLossBackward>)
# 736 tensor(1.3448, grad_fn=<MseLossBackward>)
# 737 tensor(1.3591, grad_fn=<MseLossBackward>)
# 738 tensor(1.3449, grad_fn=<MseLossBackward>)
# 739 tensor(1.3595, grad_fn=<MseLossBackward>)
# 740 tensor(1.3450, grad_fn=<MseLossBackward>)
# 741 tensor(1.3600, grad_fn=<MseLossBackward>)
# 742 tensor(1.3451, grad_fn=<MseLossBackward>)
# 743 tensor(1.3604, grad_fn=<MseLossBackward>)
# 744 tensor(1.3452, grad_fn=<MseLossBackward>)
# 745 tensor(1.3608, grad_fn=<MseLossBackward>)
# 746 tensor(1.3453, grad_fn=<MseLossBackward>)
# 747 tensor(1.3613, grad_fn=<MseLossBackward>)
# 748 tensor(1.3455, grad_fn=<MseLossBackward>)
# 749 tensor(1.3617, grad_fn=<MseLossBackward>)
# 750 tensor(1.3456, grad_fn=<MseLossBackward>)
# 751 tensor(1.3620, grad_fn=<MseLossBackward>)
# 752 tensor(1.3458, grad_fn=<MseLossBackward>)
# 753 tensor(1.3624, grad_fn=<MseLossBackward>)
# 754 tensor(1.3460, grad_fn=<MseLossBackward>)
# 755 tensor(1.3628, grad_fn=<MseLossBackward>)
# 756 tensor(1.3462, grad_fn=<MseLossBackward>)
# 757 tensor(1.3631, grad_fn=<MseLossBackward>)
# 758 tensor(1.3463, grad_fn=<MseLossBackward>)
# 759 tensor(1.3635, grad_fn=<MseLossBackward>)
# 760 tensor(1.3466, grad_fn=<MseLossBackward>)
# 761 tensor(1.3638, grad_fn=<MseLossBackward>)
# 762 tensor(1.3468, grad_fn=<MseLossBackward>)
# 763 tensor(1.3641, grad_fn=<MseLossBackward>)
# 764 tensor(1.3470, grad_fn=<MseLossBackward>)
# 765 tensor(1.3643, grad_fn=<MseLossBackward>)
# 766 tensor(1.3472, grad_fn=<MseLossBackward>)
# 767 tensor(1.3646, grad_fn=<MseLossBackward>)
# 768 tensor(1.3476, grad_fn=<MseLossBackward>)
# 769 tensor(1.3648, grad_fn=<MseLossBackward>)
# 770 tensor(1.3478, grad_fn=<MseLossBackward>)
# 771 tensor(1.3650, grad_fn=<MseLossBackward>)
# 772 tensor(1.3481, grad_fn=<MseLossBackward>)
# 773 tensor(1.3652, grad_fn=<MseLossBackward>)
# 774 tensor(1.3484, grad_fn=<MseLossBackward>)
# 775 tensor(1.3654, grad_fn=<MseLossBackward>)
# 776 tensor(1.3488, grad_fn=<MseLossBackward>)
# 777 tensor(1.3655, grad_fn=<MseLossBackward>)
# 778 tensor(1.3491, grad_fn=<MseLossBackward>)
# 779 tensor(1.3656, grad_fn=<MseLossBackward>)
# 780 tensor(1.3494, grad_fn=<MseLossBackward>)
# 781 tensor(1.3657, grad_fn=<MseLossBackward>)
# 782 tensor(1.3497, grad_fn=<MseLossBackward>)
# 783 tensor(1.3657, grad_fn=<MseLossBackward>)
# 784 tensor(1.3501, grad_fn=<MseLossBackward>)
# 785 tensor(1.3658, grad_fn=<MseLossBackward>)
# 786 tensor(1.3504, grad_fn=<MseLossBackward>)
# 787 tensor(1.3657, grad_fn=<MseLossBackward>)
# 788 tensor(1.3508, grad_fn=<MseLossBackward>)
# 789 tensor(1.3657, grad_fn=<MseLossBackward>)
# 790 tensor(1.3512, grad_fn=<MseLossBackward>)
# 791 tensor(1.3656, grad_fn=<MseLossBackward>)
# 792 tensor(1.3516, grad_fn=<MseLossBackward>)
# 793 tensor(1.3655, grad_fn=<MseLossBackward>)
# 794 tensor(1.3520, grad_fn=<MseLossBackward>)
# 795 tensor(1.3654, grad_fn=<MseLossBackward>)
# 796 tensor(1.3523, grad_fn=<MseLossBackward>)
# 797 tensor(1.3652, grad_fn=<MseLossBackward>)
# 798 tensor(1.3527, grad_fn=<MseLossBackward>)
# 799 tensor(1.3650, grad_fn=<MseLossBackward>)
# 800 tensor(1.3531, grad_fn=<MseLossBackward>)
# 801 tensor(1.3647, grad_fn=<MseLossBackward>)
# 802 tensor(1.3536, grad_fn=<MseLossBackward>)
# 803 tensor(1.3644, grad_fn=<MseLossBackward>)
# 804 tensor(1.3539, grad_fn=<MseLossBackward>)
# 805 tensor(1.3641, grad_fn=<MseLossBackward>)
# 806 tensor(1.3543, grad_fn=<MseLossBackward>)
# 807 tensor(1.3637, grad_fn=<MseLossBackward>)
# 808 tensor(1.3548, grad_fn=<MseLossBackward>)
# 809 tensor(1.3634, grad_fn=<MseLossBackward>)
# 810 tensor(1.3552, grad_fn=<MseLossBackward>)
# 811 tensor(1.3631, grad_fn=<MseLossBackward>)
# 812 tensor(1.3557, grad_fn=<MseLossBackward>)
# 813 tensor(1.3628, grad_fn=<MseLossBackward>)
# 814 tensor(1.3561, grad_fn=<MseLossBackward>)
# 815 tensor(1.3624, grad_fn=<MseLossBackward>)
# 816 tensor(1.3565, grad_fn=<MseLossBackward>)
# 817 tensor(1.3621, grad_fn=<MseLossBackward>)
# 818 tensor(1.3570, grad_fn=<MseLossBackward>)
# 819 tensor(1.3619, grad_fn=<MseLossBackward>)
# 820 tensor(1.3575, grad_fn=<MseLossBackward>)
# 821 tensor(1.3618, grad_fn=<MseLossBackward>)
# 822 tensor(1.3579, grad_fn=<MseLossBackward>)
# 823 tensor(1.3616, grad_fn=<MseLossBackward>)
# 824 tensor(1.3584, grad_fn=<MseLossBackward>)
# 825 tensor(1.3615, grad_fn=<MseLossBackward>)
# 826 tensor(1.3589, grad_fn=<MseLossBackward>)
# 827 tensor(1.3614, grad_fn=<MseLossBackward>)
# 828 tensor(1.3593, grad_fn=<MseLossBackward>)
# 829 tensor(1.3615, grad_fn=<MseLossBackward>)
# 830 tensor(1.3598, grad_fn=<MseLossBackward>)
# 831 tensor(1.3615, grad_fn=<MseLossBackward>)
# 832 tensor(1.3601, grad_fn=<MseLossBackward>)
# 833 tensor(1.3617, grad_fn=<MseLossBackward>)
# 834 tensor(1.3605, grad_fn=<MseLossBackward>)
# 835 tensor(1.3617, grad_fn=<MseLossBackward>)
# 836 tensor(1.3609, grad_fn=<MseLossBackward>)
# 837 tensor(1.3618, grad_fn=<MseLossBackward>)
# 838 tensor(1.3612, grad_fn=<MseLossBackward>)
# 839 tensor(1.3620, grad_fn=<MseLossBackward>)
# 840 tensor(1.3616, grad_fn=<MseLossBackward>)
# 841 tensor(1.3622, grad_fn=<MseLossBackward>)
# 842 tensor(1.3619, grad_fn=<MseLossBackward>)
# 843 tensor(1.3623, grad_fn=<MseLossBackward>)
# 844 tensor(1.3622, grad_fn=<MseLossBackward>)
# 845 tensor(1.3626, grad_fn=<MseLossBackward>)
# 846 tensor(1.3625, grad_fn=<MseLossBackward>)
# 847 tensor(1.3628, grad_fn=<MseLossBackward>)
# 848 tensor(1.3627, grad_fn=<MseLossBackward>)
# 849 tensor(1.3630, grad_fn=<MseLossBackward>)
# 850 tensor(1.3630, grad_fn=<MseLossBackward>)
# 851 tensor(1.3633, grad_fn=<MseLossBackward>)
# 852 tensor(1.3633, grad_fn=<MseLossBackward>)
# 853 tensor(1.3635, grad_fn=<MseLossBackward>)
# 854 tensor(1.3636, grad_fn=<MseLossBackward>)
# 855 tensor(1.3637, grad_fn=<MseLossBackward>)
# 856 tensor(1.3638, grad_fn=<MseLossBackward>)
# 857 tensor(1.3639, grad_fn=<MseLossBackward>)
# 858 tensor(1.3641, grad_fn=<MseLossBackward>)
# 859 tensor(1.3641, grad_fn=<MseLossBackward>)
# 860 tensor(1.3643, grad_fn=<MseLossBackward>)
# 861 tensor(1.3644, grad_fn=<MseLossBackward>)
# 862 tensor(1.3646, grad_fn=<MseLossBackward>)
# 863 tensor(1.3646, grad_fn=<MseLossBackward>)
# 864 tensor(1.3647, grad_fn=<MseLossBackward>)
# 865 tensor(1.3649, grad_fn=<MseLossBackward>)
# 866 tensor(1.3651, grad_fn=<MseLossBackward>)
# 867 tensor(1.3651, grad_fn=<MseLossBackward>)
# 868 tensor(1.3653, grad_fn=<MseLossBackward>)
# 869 tensor(1.3654, grad_fn=<MseLossBackward>)
# 870 tensor(1.3655, grad_fn=<MseLossBackward>)
# 871 tensor(1.3656, grad_fn=<MseLossBackward>)
# 872 tensor(1.3657, grad_fn=<MseLossBackward>)
# 873 tensor(1.3659, grad_fn=<MseLossBackward>)
# 874 tensor(1.3660, grad_fn=<MseLossBackward>)
# 875 tensor(1.3661, grad_fn=<MseLossBackward>)
# 876 tensor(1.3662, grad_fn=<MseLossBackward>)
# 877 tensor(1.3663, grad_fn=<MseLossBackward>)
# 878 tensor(1.3664, grad_fn=<MseLossBackward>)
# 879 tensor(1.3665, grad_fn=<MseLossBackward>)
# 880 tensor(1.3667, grad_fn=<MseLossBackward>)
# 881 tensor(1.3668, grad_fn=<MseLossBackward>)
# 882 tensor(1.3670, grad_fn=<MseLossBackward>)
# 883 tensor(1.3670, grad_fn=<MseLossBackward>)
# 884 tensor(1.3671, grad_fn=<MseLossBackward>)
# 885 tensor(1.3673, grad_fn=<MseLossBackward>)
# 886 tensor(1.3674, grad_fn=<MseLossBackward>)
# 887 tensor(1.3675, grad_fn=<MseLossBackward>)
# 888 tensor(1.3676, grad_fn=<MseLossBackward>)
# 889 tensor(1.3678, grad_fn=<MseLossBackward>)
# 890 tensor(1.3679, grad_fn=<MseLossBackward>)
# 891 tensor(1.3680, grad_fn=<MseLossBackward>)
# 892 tensor(1.3681, grad_fn=<MseLossBackward>)
# 893 tensor(1.3682, grad_fn=<MseLossBackward>)
# 894 tensor(1.3683, grad_fn=<MseLossBackward>)
# 895 tensor(1.3685, grad_fn=<MseLossBackward>)
# 896 tensor(1.3685, grad_fn=<MseLossBackward>)
# 897 tensor(1.3687, grad_fn=<MseLossBackward>)
# 898 tensor(1.3688, grad_fn=<MseLossBackward>)
# 899 tensor(1.3689, grad_fn=<MseLossBackward>)
# 900 tensor(1.3690, grad_fn=<MseLossBackward>)
# 901 tensor(1.3691, grad_fn=<MseLossBackward>)
# 902 tensor(1.3693, grad_fn=<MseLossBackward>)
# 903 tensor(1.3693, grad_fn=<MseLossBackward>)
# 904 tensor(1.3695, grad_fn=<MseLossBackward>)
# 905 tensor(1.3696, grad_fn=<MseLossBackward>)
# 906 tensor(1.3697, grad_fn=<MseLossBackward>)
# 907 tensor(1.3698, grad_fn=<MseLossBackward>)
# 908 tensor(1.3699, grad_fn=<MseLossBackward>)
# 909 tensor(1.3700, grad_fn=<MseLossBackward>)
# 910 tensor(1.3701, grad_fn=<MseLossBackward>)
# 911 tensor(1.3702, grad_fn=<MseLossBackward>)
# 912 tensor(1.3703, grad_fn=<MseLossBackward>)
# 913 tensor(1.3705, grad_fn=<MseLossBackward>)
# 914 tensor(1.3706, grad_fn=<MseLossBackward>)
# 915 tensor(1.3707, grad_fn=<MseLossBackward>)
# 916 tensor(1.3708, grad_fn=<MseLossBackward>)
# 917 tensor(1.3709, grad_fn=<MseLossBackward>)
# 918 tensor(1.3710, grad_fn=<MseLossBackward>)
# 919 tensor(1.3711, grad_fn=<MseLossBackward>)
# 920 tensor(1.3712, grad_fn=<MseLossBackward>)
# 921 tensor(1.3713, grad_fn=<MseLossBackward>)
# 922 tensor(1.3715, grad_fn=<MseLossBackward>)
# 923 tensor(1.3715, grad_fn=<MseLossBackward>)
# 924 tensor(1.3717, grad_fn=<MseLossBackward>)
# 925 tensor(1.3718, grad_fn=<MseLossBackward>)
# 926 tensor(1.3719, grad_fn=<MseLossBackward>)
# 927 tensor(1.3720, grad_fn=<MseLossBackward>)
# 928 tensor(1.3721, grad_fn=<MseLossBackward>)
# 929 tensor(1.3722, grad_fn=<MseLossBackward>)
# 930 tensor(1.3723, grad_fn=<MseLossBackward>)
# 931 tensor(1.3725, grad_fn=<MseLossBackward>)
# 932 tensor(1.3725, grad_fn=<MseLossBackward>)
# 933 tensor(1.3726, grad_fn=<MseLossBackward>)
# 934 tensor(1.3728, grad_fn=<MseLossBackward>)
# 935 tensor(1.3728, grad_fn=<MseLossBackward>)
# 936 tensor(1.3729, grad_fn=<MseLossBackward>)
# 937 tensor(1.3731, grad_fn=<MseLossBackward>)
# 938 tensor(1.3732, grad_fn=<MseLossBackward>)
# 939 tensor(1.3733, grad_fn=<MseLossBackward>)
# 940 tensor(1.3734, grad_fn=<MseLossBackward>)
# 941 tensor(1.3734, grad_fn=<MseLossBackward>)
# 942 tensor(1.3736, grad_fn=<MseLossBackward>)
# 943 tensor(1.3737, grad_fn=<MseLossBackward>)
# 944 tensor(1.3738, grad_fn=<MseLossBackward>)
# 945 tensor(1.3739, grad_fn=<MseLossBackward>)
# 946 tensor(1.3740, grad_fn=<MseLossBackward>)
# 947 tensor(1.3741, grad_fn=<MseLossBackward>)
# 948 tensor(1.3742, grad_fn=<MseLossBackward>)
# 949 tensor(1.3743, grad_fn=<MseLossBackward>)
# 950 tensor(1.3744, grad_fn=<MseLossBackward>)
# 951 tensor(1.3745, grad_fn=<MseLossBackward>)
# 952 tensor(1.3746, grad_fn=<MseLossBackward>)
# 953 tensor(1.3747, grad_fn=<MseLossBackward>)
# 954 tensor(1.3748, grad_fn=<MseLossBackward>)
# 955 tensor(1.3749, grad_fn=<MseLossBackward>)
# 956 tensor(1.3750, grad_fn=<MseLossBackward>)
# 957 tensor(1.3751, grad_fn=<MseLossBackward>)
# 958 tensor(1.3752, grad_fn=<MseLossBackward>)
# 959 tensor(1.3753, grad_fn=<MseLossBackward>)
# 960 tensor(1.3754, grad_fn=<MseLossBackward>)
# 961 tensor(1.3755, grad_fn=<MseLossBackward>)
# 962 tensor(1.3756, grad_fn=<MseLossBackward>)
# 963 tensor(1.3757, grad_fn=<MseLossBackward>)
# 964 tensor(1.3758, grad_fn=<MseLossBackward>)
# 965 tensor(1.3759, grad_fn=<MseLossBackward>)
# 966 tensor(1.3760, grad_fn=<MseLossBackward>)
# 967 tensor(1.3760, grad_fn=<MseLossBackward>)
# 968 tensor(1.3761, grad_fn=<MseLossBackward>)
# 969 tensor(1.3763, grad_fn=<MseLossBackward>)
# 970 tensor(1.3764, grad_fn=<MseLossBackward>)
# 971 tensor(1.3764, grad_fn=<MseLossBackward>)
# 972 tensor(1.3765, grad_fn=<MseLossBackward>)
# 973 tensor(1.3766, grad_fn=<MseLossBackward>)
# 974 tensor(1.3767, grad_fn=<MseLossBackward>)
# 975 tensor(1.3768, grad_fn=<MseLossBackward>)
# 976 tensor(1.3768, grad_fn=<MseLossBackward>)
# 977 tensor(1.3769, grad_fn=<MseLossBackward>)
# 978 tensor(1.3771, grad_fn=<MseLossBackward>)
# 979 tensor(1.3772, grad_fn=<MseLossBackward>)
# 980 tensor(1.3773, grad_fn=<MseLossBackward>)
# 981 tensor(1.3773, grad_fn=<MseLossBackward>)
# 982 tensor(1.3774, grad_fn=<MseLossBackward>)
# 983 tensor(1.3775, grad_fn=<MseLossBackward>)
# 984 tensor(1.3776, grad_fn=<MseLossBackward>)
# 985 tensor(1.3777, grad_fn=<MseLossBackward>)
# 986 tensor(1.3778, grad_fn=<MseLossBackward>)
# 987 tensor(1.3778, grad_fn=<MseLossBackward>)
# 988 tensor(1.3779, grad_fn=<MseLossBackward>)
# 989 tensor(1.3780, grad_fn=<MseLossBackward>)
# 990 tensor(1.3781, grad_fn=<MseLossBackward>)
# 991 tensor(1.3782, grad_fn=<MseLossBackward>)
# 992 tensor(1.3783, grad_fn=<MseLossBackward>)
# 993 tensor(1.3783, grad_fn=<MseLossBackward>)
# 994 tensor(1.3784, grad_fn=<MseLossBackward>)
# 995 tensor(1.3785, grad_fn=<MseLossBackward>)
# 996 tensor(1.3786, grad_fn=<MseLossBackward>)
# 997 tensor(1.3787, grad_fn=<MseLossBackward>)
# 998 tensor(1.3787, grad_fn=<MseLossBackward>)
# 999 tensor(1.3789, grad_fn=<MseLossBackward>)

# %%
print ('Optimizing flowmap')        
for t in range(params['ntrain'][1]):
    for b in range(x.shape[0]):
        # Forward pass: Compute predicted y by passing x to the model
        pred, grad = modelRINN(x[b,:,:],params['dt_integration'])
        # Compute and print loss
        loss = criterion(pred, y[b,:,:])
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Save models
        #torch.save(modelRINN.state_dict(), path + file_name)
    print(t,loss)
# Out:
# Optimizing flowmap
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:13: UserWarning: reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.
#   warnings.warn("reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.")
# 0 tensor(2.5281e-05, grad_fn=<MseLossBackward>)
# 1 tensor(2.3478e-05, grad_fn=<MseLossBackward>)
# 2 tensor(2.1624e-05, grad_fn=<MseLossBackward>)
# 3 tensor(1.9733e-05, grad_fn=<MseLossBackward>)
# 4 tensor(1.7822e-05, grad_fn=<MseLossBackward>)
# 5 tensor(1.5915e-05, grad_fn=<MseLossBackward>)
# 6 tensor(1.4044e-05, grad_fn=<MseLossBackward>)
# 7 tensor(1.2227e-05, grad_fn=<MseLossBackward>)
# 8 tensor(1.0499e-05, grad_fn=<MseLossBackward>)
# 9 tensor(8.8794e-06, grad_fn=<MseLossBackward>)
# 10 tensor(7.3920e-06, grad_fn=<MseLossBackward>)
# 11 tensor(6.0601e-06, grad_fn=<MseLossBackward>)
# 12 tensor(4.8939e-06, grad_fn=<MseLossBackward>)
# 13 tensor(3.8994e-06, grad_fn=<MseLossBackward>)
# 14 tensor(3.0731e-06, grad_fn=<MseLossBackward>)
# 15 tensor(2.4058e-06, grad_fn=<MseLossBackward>)
# 16 tensor(1.8849e-06, grad_fn=<MseLossBackward>)
# 17 tensor(1.4932e-06, grad_fn=<MseLossBackward>)
# 18 tensor(1.2154e-06, grad_fn=<MseLossBackward>)
# 19 tensor(1.0261e-06, grad_fn=<MseLossBackward>)
# 20 tensor(9.0387e-07, grad_fn=<MseLossBackward>)
# 21 tensor(8.3429e-07, grad_fn=<MseLossBackward>)
# 22 tensor(8.0628e-07, grad_fn=<MseLossBackward>)
# 23 tensor(8.0965e-07, grad_fn=<MseLossBackward>)
# 24 tensor(8.3438e-07, grad_fn=<MseLossBackward>)
# 25 tensor(8.7496e-07, grad_fn=<MseLossBackward>)
# 26 tensor(9.2958e-07, grad_fn=<MseLossBackward>)
# 27 tensor(9.9490e-07, grad_fn=<MseLossBackward>)
# 28 tensor(1.0676e-06, grad_fn=<MseLossBackward>)
# 29 tensor(1.1455e-06, grad_fn=<MseLossBackward>)
# 30 tensor(1.2234e-06, grad_fn=<MseLossBackward>)
# 31 tensor(1.2983e-06, grad_fn=<MseLossBackward>)
# 32 tensor(1.3686e-06, grad_fn=<MseLossBackward>)
# 33 tensor(1.4324e-06, grad_fn=<MseLossBackward>)
# 34 tensor(1.4903e-06, grad_fn=<MseLossBackward>)
# 35 tensor(1.5422e-06, grad_fn=<MseLossBackward>)
# 36 tensor(1.5893e-06, grad_fn=<MseLossBackward>)
# 37 tensor(1.6321e-06, grad_fn=<MseLossBackward>)
# 38 tensor(1.6722e-06, grad_fn=<MseLossBackward>)
# 39 tensor(1.7107e-06, grad_fn=<MseLossBackward>)
# 40 tensor(1.7493e-06, grad_fn=<MseLossBackward>)
# 41 tensor(1.7888e-06, grad_fn=<MseLossBackward>)
# 42 tensor(1.8303e-06, grad_fn=<MseLossBackward>)
# 43 tensor(1.8757e-06, grad_fn=<MseLossBackward>)
# 44 tensor(1.9227e-06, grad_fn=<MseLossBackward>)
# 45 tensor(1.9731e-06, grad_fn=<MseLossBackward>)
# 46 tensor(2.0250e-06, grad_fn=<MseLossBackward>)
# 47 tensor(2.0768e-06, grad_fn=<MseLossBackward>)
# 48 tensor(2.1276e-06, grad_fn=<MseLossBackward>)
# 49 tensor(2.1758e-06, grad_fn=<MseLossBackward>)
# 50 tensor(2.2188e-06, grad_fn=<MseLossBackward>)
# 51 tensor(2.2552e-06, grad_fn=<MseLossBackward>)
# 52 tensor(2.2831e-06, grad_fn=<MseLossBackward>)
# 53 tensor(2.3009e-06, grad_fn=<MseLossBackward>)
# 54 tensor(2.3080e-06, grad_fn=<MseLossBackward>)
# 55 tensor(2.3030e-06, grad_fn=<MseLossBackward>)
# 56 tensor(2.2861e-06, grad_fn=<MseLossBackward>)
# 57 tensor(2.2589e-06, grad_fn=<MseLossBackward>)
# 58 tensor(2.2214e-06, grad_fn=<MseLossBackward>)
# 59 tensor(2.1742e-06, grad_fn=<MseLossBackward>)
# 60 tensor(2.1186e-06, grad_fn=<MseLossBackward>)
# 61 tensor(2.0559e-06, grad_fn=<MseLossBackward>)
# 62 tensor(1.9868e-06, grad_fn=<MseLossBackward>)
# 63 tensor(1.9125e-06, grad_fn=<MseLossBackward>)
# 64 tensor(1.8334e-06, grad_fn=<MseLossBackward>)
# 65 tensor(1.7503e-06, grad_fn=<MseLossBackward>)
# 66 tensor(1.6648e-06, grad_fn=<MseLossBackward>)
# 67 tensor(1.5784e-06, grad_fn=<MseLossBackward>)
# 68 tensor(1.4926e-06, grad_fn=<MseLossBackward>)
# 69 tensor(1.4090e-06, grad_fn=<MseLossBackward>)
# 70 tensor(1.3292e-06, grad_fn=<MseLossBackward>)
# 71 tensor(1.2569e-06, grad_fn=<MseLossBackward>)
# 72 tensor(1.1936e-06, grad_fn=<MseLossBackward>)
# 73 tensor(1.1368e-06, grad_fn=<MseLossBackward>)
# 74 tensor(1.0770e-06, grad_fn=<MseLossBackward>)
# 75 tensor(1.0051e-06, grad_fn=<MseLossBackward>)
# 76 tensor(9.1965e-07, grad_fn=<MseLossBackward>)
# 77 tensor(8.2759e-07, grad_fn=<MseLossBackward>)
# 78 tensor(7.2708e-07, grad_fn=<MseLossBackward>)
# 79 tensor(7.2406e-07, grad_fn=<MseLossBackward>)
# 80 tensor(6.4834e-07, grad_fn=<MseLossBackward>)
# 81 tensor(5.5555e-07, grad_fn=<MseLossBackward>)
# 82 tensor(4.3382e-07, grad_fn=<MseLossBackward>)
# 83 tensor(3.4068e-07, grad_fn=<MseLossBackward>)
# 84 tensor(3.9322e-07, grad_fn=<MseLossBackward>)
# 85 tensor(4.9262e-07, grad_fn=<MseLossBackward>)
# 86 tensor(7.3730e-07, grad_fn=<MseLossBackward>)
# 87 tensor(2.0087e-07, grad_fn=<MseLossBackward>)
# 88 tensor(1.8581e-07, grad_fn=<MseLossBackward>)
# 89 tensor(2.2707e-06, grad_fn=<MseLossBackward>)
# 90 tensor(1.1720e-06, grad_fn=<MseLossBackward>)
# 91 tensor(1.7715e-06, grad_fn=<MseLossBackward>)
# 92 tensor(3.3354e-07, grad_fn=<MseLossBackward>)
# 93 tensor(4.1999e-07, grad_fn=<MseLossBackward>)
# 94 tensor(1.0973e-06, grad_fn=<MseLossBackward>)
# 95 tensor(6.9817e-08, grad_fn=<MseLossBackward>)
# 96 tensor(2.8801e-06, grad_fn=<MseLossBackward>)
# 97 tensor(3.3856e-07, grad_fn=<MseLossBackward>)
# 98 tensor(8.5056e-08, grad_fn=<MseLossBackward>)
# 99 tensor(6.5403e-07, grad_fn=<MseLossBackward>)
# 100 tensor(1.3410e-07, grad_fn=<MseLossBackward>)
# 101 tensor(2.7266e-07, grad_fn=<MseLossBackward>)
# 102 tensor(1.7094e-07, grad_fn=<MseLossBackward>)
# 103 tensor(5.4348e-06, grad_fn=<MseLossBackward>)
# 104 tensor(2.2553e-06, grad_fn=<MseLossBackward>)
# 105 tensor(8.5631e-07, grad_fn=<MseLossBackward>)
# 106 tensor(5.7589e-07, grad_fn=<MseLossBackward>)
# 107 tensor(6.1217e-07, grad_fn=<MseLossBackward>)
# 108 tensor(7.0547e-07, grad_fn=<MseLossBackward>)
# 109 tensor(1.1050e-06, grad_fn=<MseLossBackward>)
# 110 tensor(2.4067e-07, grad_fn=<MseLossBackward>)
# 111 tensor(3.4871e-07, grad_fn=<MseLossBackward>)
# 112 tensor(5.0818e-07, grad_fn=<MseLossBackward>)
# 113 tensor(2.0399e-07, grad_fn=<MseLossBackward>)
# 114 tensor(2.6809e-08, grad_fn=<MseLossBackward>)
# 115 tensor(6.9440e-07, grad_fn=<MseLossBackward>)
# 116 tensor(3.1780e-06, grad_fn=<MseLossBackward>)
# 117 tensor(9.6148e-07, grad_fn=<MseLossBackward>)
# 118 tensor(5.4953e-07, grad_fn=<MseLossBackward>)
# 119 tensor(7.0226e-07, grad_fn=<MseLossBackward>)
# 120 tensor(3.0428e-07, grad_fn=<MseLossBackward>)
# 121 tensor(1.6662e-07, grad_fn=<MseLossBackward>)
# 122 tensor(2.0543e-07, grad_fn=<MseLossBackward>)
# 123 tensor(4.7699e-08, grad_fn=<MseLossBackward>)
# 124 tensor(1.9083e-06, grad_fn=<MseLossBackward>)
# 125 tensor(8.5517e-07, grad_fn=<MseLossBackward>)
# 126 tensor(4.6351e-07, grad_fn=<MseLossBackward>)
# 127 tensor(1.2652e-07, grad_fn=<MseLossBackward>)
# 128 tensor(1.2126e-07, grad_fn=<MseLossBackward>)
# 129 tensor(3.4330e-07, grad_fn=<MseLossBackward>)
# 130 tensor(9.5626e-08, grad_fn=<MseLossBackward>)
# 131 tensor(2.1419e-07, grad_fn=<MseLossBackward>)
# 132 tensor(3.1936e-07, grad_fn=<MseLossBackward>)
# 133 tensor(5.0585e-07, grad_fn=<MseLossBackward>)
# 134 tensor(2.6182e-07, grad_fn=<MseLossBackward>)
# 135 tensor(2.3525e-07, grad_fn=<MseLossBackward>)
# 136 tensor(1.1967e-07, grad_fn=<MseLossBackward>)
# 137 tensor(8.0775e-07, grad_fn=<MseLossBackward>)
# 138 tensor(1.9554e-07, grad_fn=<MseLossBackward>)
# 139 tensor(4.2262e-07, grad_fn=<MseLossBackward>)
# 140 tensor(5.4656e-08, grad_fn=<MseLossBackward>)
# 141 tensor(1.5742e-06, grad_fn=<MseLossBackward>)
# 142 tensor(4.3334e-07, grad_fn=<MseLossBackward>)
# 143 tensor(2.1006e-07, grad_fn=<MseLossBackward>)
# 144 tensor(1.0377e-06, grad_fn=<MseLossBackward>)
# 145 tensor(9.5305e-08, grad_fn=<MseLossBackward>)
# 146 tensor(2.1846e-07, grad_fn=<MseLossBackward>)
# 147 tensor(1.9903e-06, grad_fn=<MseLossBackward>)
# 148 tensor(2.8442e-07, grad_fn=<MseLossBackward>)
# 149 tensor(1.2409e-08, grad_fn=<MseLossBackward>)
# 150 tensor(5.6539e-07, grad_fn=<MseLossBackward>)
# 151 tensor(7.0790e-07, grad_fn=<MseLossBackward>)
# 152 tensor(2.0718e-07, grad_fn=<MseLossBackward>)
# 153 tensor(1.2794e-07, grad_fn=<MseLossBackward>)
# 154 tensor(2.1605e-06, grad_fn=<MseLossBackward>)
# 155 tensor(2.6494e-07, grad_fn=<MseLossBackward>)
# 156 tensor(9.9919e-08, grad_fn=<MseLossBackward>)
# 157 tensor(4.6470e-07, grad_fn=<MseLossBackward>)
# 158 tensor(9.4682e-07, grad_fn=<MseLossBackward>)
# 159 tensor(9.0601e-08, grad_fn=<MseLossBackward>)
# 160 tensor(1.8416e-07, grad_fn=<MseLossBackward>)
# 161 tensor(6.5090e-07, grad_fn=<MseLossBackward>)
# 162 tensor(6.8177e-07, grad_fn=<MseLossBackward>)
# 163 tensor(2.2783e-07, grad_fn=<MseLossBackward>)
# 164 tensor(2.9102e-07, grad_fn=<MseLossBackward>)
# 165 tensor(2.8851e-07, grad_fn=<MseLossBackward>)
# 166 tensor(3.6763e-07, grad_fn=<MseLossBackward>)
# 167 tensor(1.4169e-07, grad_fn=<MseLossBackward>)
# 168 tensor(1.6238e-07, grad_fn=<MseLossBackward>)
# 169 tensor(5.8836e-07, grad_fn=<MseLossBackward>)
# 170 tensor(1.8550e-06, grad_fn=<MseLossBackward>)
# 171 tensor(1.5358e-07, grad_fn=<MseLossBackward>)
# 172 tensor(5.0343e-08, grad_fn=<MseLossBackward>)
# 173 tensor(6.5815e-07, grad_fn=<MseLossBackward>)
# 174 tensor(1.5026e-07, grad_fn=<MseLossBackward>)
# 175 tensor(3.0726e-07, grad_fn=<MseLossBackward>)
# 176 tensor(8.6059e-07, grad_fn=<MseLossBackward>)
# 177 tensor(1.2123e-06, grad_fn=<MseLossBackward>)
# 178 tensor(1.2232e-06, grad_fn=<MseLossBackward>)
# 179 tensor(1.1518e-06, grad_fn=<MseLossBackward>)
# 180 tensor(1.4939e-06, grad_fn=<MseLossBackward>)
# 181 tensor(2.2194e-06, grad_fn=<MseLossBackward>)
# 182 tensor(9.8401e-07, grad_fn=<MseLossBackward>)
# 183 tensor(7.4852e-07, grad_fn=<MseLossBackward>)
# 184 tensor(6.6084e-07, grad_fn=<MseLossBackward>)
# 185 tensor(5.4707e-07, grad_fn=<MseLossBackward>)
# 186 tensor(3.9262e-07, grad_fn=<MseLossBackward>)
# 187 tensor(1.1328e-07, grad_fn=<MseLossBackward>)
# 188 tensor(7.5976e-08, grad_fn=<MseLossBackward>)
# 189 tensor(1.8660e-07, grad_fn=<MseLossBackward>)
# 190 tensor(4.9443e-07, grad_fn=<MseLossBackward>)
# 191 tensor(4.5821e-07, grad_fn=<MseLossBackward>)
# 192 tensor(5.7643e-08, grad_fn=<MseLossBackward>)
# 193 tensor(3.4485e-07, grad_fn=<MseLossBackward>)
# 194 tensor(1.6800e-06, grad_fn=<MseLossBackward>)
# 195 tensor(1.4620e-06, grad_fn=<MseLossBackward>)
# 196 tensor(1.5191e-07, grad_fn=<MseLossBackward>)
# 197 tensor(1.7097e-07, grad_fn=<MseLossBackward>)
# 198 tensor(4.6059e-07, grad_fn=<MseLossBackward>)
# 199 tensor(5.9444e-07, grad_fn=<MseLossBackward>)

# %%
pred = [torch.from_numpy(xt.values[:1,:]).float()]
for i in range(1000):
    pred.append(modelRINN(pred[-1],params['dt_integration'])[0])

plt.plot(torch.stack(pred).data.numpy()[:1000,0,0],label = "Prediction from LQM Dynamical model")
plt.plot(xt.values[:1000,0],label = "True state")
