# %% [markdown]
# <a href="https://colab.research.google.com/github/RaniaBouchrara/Stage-Rania/blob/master/Lorenz_stochastique1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Génération des données

# %%
# !pip install sdeint
#sdeint permet la résolution de l'équation différentielle stochastique
# Out:
# Collecting sdeint
#   Downloading https://files.pythonhosted.org/packages/3d/26/69946549a57a04ff033780129f3121530565998c017f4f4f06530c2a5b88/sdeint-0.2.1.tar.gz (40kB)
#      |████████████████████████████████| 40kB 3.4MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from sdeint) (1.18.5)
# Building wheels for collected packages: sdeint
#   Building wheel for sdeint (setup.py) ... done
#   Created wheel for sdeint: filename=sdeint-0.2.1-cp36-none-any.whl size=27747 sha256=e9581180885e8bcad023663c4a78feec86ee231501be2c83937df3ab9805b0e6
#   Stored in directory: /root/.cache/pip/wheels/6d/76/bf/cd470aaeb760f7ac85bca1614606ed5760408dbf5149240ba4
# Successfully built sdeint
# Installing collected packages: sdeint
# Successfully installed sdeint-0.2.1

# %%
#importer l'ensemle des bibliothèques nécessaires
import sdeint
import sys
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import torch

# %%
'la génération des données et initialisation des paramètres du modèle ainsi que les variables d''intégration, d''apprentissage et de test'
class GD:
    model = 'Lorenz_63' 
    class parameters: 
        sigma = 10.0
        rho = 28.0
        beta = 8.0/3
        theta = 1.0
    
    dt_integration = 0.01 # integration time
    dt_states = 1 # number of integeration times between consecutive states (for xt and catalog)
    dt_obs = 8# number of integration times between consecutive observations (for yo)
    var_obs = np.array([0,1]) # indices of the observed variables
    nb_loop_train = 210.01 # size of the catalog
    nb_loop_test = 100 # size of the true state and noisy observations
    sigma2_catalog = 0.0 # variance of the model error to generate the catalog
    sigma2_obs = 0.0 # variance of the observation error to generate observation

    '''var_obs = np.array([0,1,2]) # indices of the observed variables
    nb_loop_test = 10 # size of the true state and noisy observations
    sigma2_obs = 2.0 # variance of the observation error to generate observation'''

# %%
#définition des équations différentielles stochastiques
def Stoch_Lorenz_63(S,t,sigma=GD.parameters.sigma, rho = GD.parameters.rho, beta = GD.parameters.beta, theta = GD.parameters.theta):
    """ Lorenz-63 dynamical model. """
    x_1 = sigma*(S[1]-S[0])-4*S[0]/(2*theta);
    x_2 = S[0]*(rho-S[2])-S[1] -4*S[1]/(2*theta);
    x_3 = S[0]*S[1] - beta*S[2] -8*S[2]/(2*theta);
    dS  = np.array([x_1,x_2,x_3]);
    return dS
    
#définition du mouvement brwonien 
def brownian_process(S,t,sigma=GD.parameters.sigma, rho = GD.parameters.rho, beta = GD.parameters.beta, theta = GD.parameters.theta):
    x_1 = 0.0;
    x_2 = (rho - S[2])/np.sqrt(theta);
    x_3 = (S[1])/np.sqrt(theta);
    dS  = np.array([x_1,x_2,x_3]);
    G = np.zeros((3,3))
    G[0,0] = x_1
    G[1,0] = x_2
    G[2,0] = x_3
    #np.fill_diagonal(G,dS)
    return G

# %%
#génération d'une solution des équations différentielles à partir d'un x0 donné
np.random.seed(1)
x0 = np.array([8.0,0.0,30.0]);
tspan = np.arange(0,100+0.000001,10E-5) 
S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)

# %%
#traçage du flux du modèle stochastique de lorenz
#Undersampling to dt = .01
S_u  = S[::100]
fig=plt.figure()
ax=fig.gca(projection='3d')
line1,=ax.plot(S_u[:2000,0],S_u[:2000,1],S_u[:2000,2],'k')
ax.set_xlabel('$x_1$');ax.set_ylabel('$x_2$');ax.set_zlabel('$x_3$')
plt.legend([line1], ['Stochastic Lorenz flow'])
plt.title('Stochastic Lorenz flow')
# Out:
# Text(0.5, 0.92, 'Stochastic Lorenz flow')

# %%
#simulation de la série temporelle
plt.plot(S_u[:500,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f4e5142b828>,
#  <matplotlib.lines.Line2D at 0x7f4e5142be10>,
#  <matplotlib.lines.Line2D at 0x7f4e5142b6d8>]

# %%
S_u.shape
# Out:
# (10001, 3)

# %%
tspan = np.arange(0,101+0.000001,10E-5) 

def generate_data(GD):
    """ Generate the true state, noisy observations and catalog of numerical simulations. """

    # initialization
    class xt: #xt : test (série temporelle)
        values = [];
        time = [];
    class yo: #yo : observation (assimilation des données)
        values = [];
        time = [];
    class catalog: #catalog : train (base d'apprentissage)
        analogs = [];
        successors = [];
        source = [];
        time = [];
    
    # test on parameters
    if GD.dt_states>GD.dt_obs:
        print('Error: GD.dt_obs must be bigger than GD.dt_states');
    if (np.mod(GD.dt_obs,GD.dt_states)!=0):
        print('Error: GD.dt_obs must be a multiple of GD.dt_states');

    # use this to generate the same data for different simulations
    np.random.seed(1);

    # 5 time steps (to be in the attractor space)  
    x0 = np.array([8.0,0.0,30.0]);
    #S = odeint(Lorenz_63,x0,np.arange(0,5+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)
    x0 = S[S.shape[0]-1,:];

    # generate true state (xt)
    #S = odeint(Lorenz_63,x0,np.arange(0.01,GD.nb_loop_test+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)
    T_test = S.shape[0];      
    t_xt = np.arange(0,T_test,GD.dt_states);       
    xt.time = t_xt*GD.dt_integration;
    xt.values = S[t_xt,:];
        
    # generate  partial/noisy observations (yo)
    eps = np.random.multivariate_normal(np.zeros(3),GD.sigma2_obs*np.eye(3,3),T_test);
    yo_tmp = S[t_xt,:]+eps[t_xt,:];
    t_yo = np.arange(0,T_test,GD.dt_obs);
    i_t_obs = np.where((np.in1d(t_xt,t_yo))==True)[0];
    yo.values = xt.values*np.nan;
    yo.values[np.ix_(i_t_obs,GD.var_obs)] = yo_tmp[np.ix_(i_t_obs,GD.var_obs)];
    yo.time = xt.time;
       

    #generate catalog
    #S =  odeint(Lorenz_63,S[S.shape[0]-1,:],np.arange(0.01,GD.nb_loop_train+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)
    T_train = S.shape[0];
    eta = np.random.multivariate_normal(np.zeros(3),GD.sigma2_catalog*np.eye(3,3),T_train);
    catalog_tmp = S+eta;
    catalog.analogs = catalog_tmp[0:-GD.dt_states,:];
    catalog.successors = catalog_tmp[GD.dt_states:,:]
    catalog.source = GD.parameters;
  # reinitialize random generator number    
    np.random.seed()

    return catalog, xt, yo;

# %%
#run the data generation
catalog, xt, yo = generate_data(GD)

# %%
plt.plot(catalog.analogs[::100,:])
plt.show()

# %%
tmpp = catalog.analogs[::100,:]# downsample to dt  = 0.01
catalog.analogs    =  tmpp[:-1,:][:10000,:]
catalog.successors =  tmpp[1:,:][:10000,:]
plt.plot(catalog.analogs[:1000])
# Out:
# [<matplotlib.lines.Line2D at 0x7f4e50ed06d8>,
#  <matplotlib.lines.Line2D at 0x7f4e50ed07f0>,
#  <matplotlib.lines.Line2D at 0x7f4e50ed0940>]

# %%
xt.values = xt.values[::100,:]

# %%
#training data
batch_size = 50
X_train = np.reshape(catalog.analogs,(int(catalog.analogs.shape[0]/batch_size),batch_size,catalog.analogs.shape[1]))
Grad_t  = np.gradient(X_train)[1]/GD.dt_integration #gradient de X_train
Y_train = np.reshape(catalog.successors,(int(catalog.analogs.shape[0]/batch_size),batch_size,catalog.analogs.shape[1])) #successors de catalog

# %%
plt.plot(X_train[0,:,:])
plt.show()

# %%
#initialisation des paramètres du réseau de neurones pour l'apprentissage deep learning
params = {}
params['transition_layers']=1
params['bi_linear_layers']=3
params['dim_hidden_linear'] = 3
params['dim_input']=3
params['dim_output']=3
params['dim_observations'] = 3
params['dim_hidden']=3
params['ntrain']=[1000,200]
params['dt_integration'] = GD.dt_integration
pretrained = False
path = ''# to be defined 
file_name = '' # to be defined

# %%
#classe du modèle dynamique qui permet de calculer le gradient 
np.random.seed(0)
torch.manual_seed(0)
class FC_net(torch.nn.Module):
        def __init__(self, params):
            super(FC_net, self).__init__()
            self.linearCell   = torch.nn.Linear(params['dim_input'], params['dim_hidden_linear']) 
            self.BlinearCell1 = torch.nn.ModuleList([torch.nn.Linear(params['dim_input'], 1) for i in range(params['bi_linear_layers'])])
            self.BlinearCell2 = torch.nn.ModuleList([torch.nn.Linear(params['dim_input'], 1) for i in range(params['bi_linear_layers'])])
            augmented_size    = params['bi_linear_layers'] + params['dim_hidden_linear']
            self.transLayers = torch.nn.ModuleList([torch.nn.Linear(augmented_size, params['dim_input'])])
            self.transLayers.extend([torch.nn.Linear(params['dim_input'],params['dim_input']) for i in range(1, params['transition_layers'])])
            self.outputLayer  = torch.nn.Linear(params['dim_input'], params['dim_input']) 
        def forward(self, inp, dt):
            """
            In the forward function we accept a Tensor of input data and we must return
            a Tensor of output data. We can use Modules defined in the constructor as
            well as arbitrary operators on Tensors.
            """
            aug_inp = inp
            BP_outp = (torch.zeros((aug_inp.size()[0],params['bi_linear_layers'])))
            L_outp   = self.linearCell(aug_inp)
            for i in range((params['bi_linear_layers'])):
                BP_outp[:,i]=self.BlinearCell1[i](aug_inp)[:,0]*self.BlinearCell2[i](aug_inp)[:,0]
            aug_vect = torch.cat((L_outp, BP_outp), dim=1)
            for i in range((params['transition_layers'])):
                aug_vect = (self.transLayers[i](aug_vect))
            grad = self.outputLayer(aug_vect)
            return grad
model  = FC_net(params)

# %%
#classe du modèle dynamique qui permet de calculer l'intégrale
class INT_net(torch.nn.Module):
        def __init__(self, params):
            super(INT_net, self).__init__()
#            self.add_module('Dyn_net',FC_net(params))
            self.Dyn_net = model
        def forward(self, inp,dt):
            """
            In the forward function we accept a Tensor of input data and we must return
            a Tensor of output data. We can use Modules defined in the constructor as
            well as arbitrary operators on Tensors.
            """
            k1 = self.Dyn_net(inp,dt)
            inp_k2      = inp + 0.5*params['dt_integration']*k1
            k2     = self.Dyn_net(inp_k2,dt)
            inp_k3      = inp + 0.5*params['dt_integration']*k2       
            k3     = self.Dyn_net(inp_k3,dt)
            inp_k4      = inp + params['dt_integration']*k3          
            k4     = self.Dyn_net(inp_k4,dt)            
            pred = inp +dt*(k1+2*k2+2*k3+k4)/6    
            return pred, k1
#int_net est appelée lorsqu'on lance le modèle RINN (dans train_model) elle nécessite deux variables dont une la variable dt qui 
#est une variable d'intégration et la variable inputs (train_model=model(inputs,dt)) et retourne une prédiction

# %%
#construction de x,y et z
#conversion de x,y et z d'un numpy de type tableau à un objet torch de type float (réel)
dt       = params['dt_integration']
aug_vect = []  
x = torch.from_numpy(X_train).float() 
y = torch.from_numpy(Y_train).float()
z = torch.from_numpy(Grad_t).float()

#construction du modèle RINN
#critère à minimiser (mse)
#optimizer(adam)
modelRINN = INT_net(params)
criterion = torch.nn.MSELoss(reduction='elementwise_mean')
optimizer = torch.optim.Adam(modelRINN.parameters(),lr = 0.001)

if pretrained : 
    modelRINN.load_state_dict(torch.load(path + file_name))

# %% [markdown]
# # L63 Patch data extraction

# %%
from sklearn.feature_extraction import image

time_step = 1  

# extract subsequences****77
# creation de bout de séries temporelles
dT = 2000
# time series, batch size, nb_batch 
dataTrainingNoNaN = image.extract_patches_2d(catalog.analogs[:,:],(dT,3))
dataTestNoNaN     = image.extract_patches_2d(xt.values[:,:],(dT,3))

# %%
dataTrainingNoNaN.shape
# Out:
# (8001, 2000, 3)

# %%
x_train        = np.moveaxis( dataTrainingNoNaN.reshape((dataTrainingNoNaN.shape[0],dataTrainingNoNaN.shape[1],dataTrainingNoNaN.shape[2])) , 2 , 1 )
x_test         = np.moveaxis( dataTestNoNaN.reshape((dataTestNoNaN.shape[0],dataTestNoNaN.shape[1],dataTestNoNaN.shape[2])) , 2 , 1 )

# %% [markdown]
# # Learning model

# %%
import os
import tensorflow.keras as keras
import time
import copy
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F

# %%
# Create training/test data pytorch tensors and associated   
# list of tensors (xx[n][x] to access the nth sample for the xth field)
training_dataset     = torch.utils.data.TensorDataset(torch.Tensor(x_train)) # create your dataset
test_dataset         = torch.utils.data.TensorDataset(torch.Tensor(x_test)) # create your dataset

dataloaders = {
    'train': torch.utils.data.DataLoader(training_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True),
    'val': torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True),
}
#datatloaders(entrée et sortie sont des données du RN)
#x(t) est rapprochée x(t)-x(t-dt)/dt
#x(t0) est rapprochée par x(t+dt),x(t+2dt),...
#batch_size=32 (état au temps t) inputs
dataset_sizes = {'train': len(training_dataset), 'val': len(test_dataset)}

# %%
#create an optimizer object
#Adam optimizer with learning rate 1e-3
optimizer        = optim.Adam(modelRINN.parameters(), lr=1e-3)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

#mean-squared error loss
criterion = torch.nn.MSELoss()
var_Tr    = np.var( x_train )
var_Tt    = np.var( x_test )

#training function
def train_model(model, dt, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_var  = 0.0

            # Iterate over data.
            for inputs_ in dataloaders[phase]:
                inputs = inputs_[0]
                #inputs = inputs.to(device)
                #print(inputs.size(0))

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):

                    x_init   = inputs[:,:,0].view(-1,3) # initial state
                    x_target = inputs[:,:,1].view(-1,3) # target state
                    #print(x_init.size(),flush=True)
                    outputs = model(x_init,dt)
                    #print(outputs[0].size(),flush=True)
                    #loss = criterion(outputs, inputs)
                    loss = torch.mean((outputs[0] - x_target)**2) #à remplacer par -log vraisemblance

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward() 
                        optimizer.step()

                # statistics
                running_loss   += loss.item() * inputs.size(0)
                #running_expvar += torch.sum( (outputs - inputs)**2 ) / torch.sum(
            if phase == 'train':
                scheduler.step()

            epoch_loss  = running_loss / dataset_sizes[phase]
            if phase == 'train':
              epoch_nloss = epoch_loss / var_Tr
            else:
              epoch_nloss = epoch_loss / var_Tt
            #epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4e} NLoss: {:.4e} '.format(
                phase, epoch_loss, epoch_nloss))
#            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
#                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format( 
        time_elapsed // 60, time_elapsed % 60))
    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
#training   
dt         = torch.nn.Parameter(torch.Tensor([0.01]))
num_epochs = 100
modelRINN  = train_model(modelRINN, dt, criterion, optimizer, exp_lr_scheduler, num_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.1233e+00 NLoss: 2.2423e-02
# val Loss: 1.0372e+00 NLoss: 2.1697e-02
#
# Epoch 1/99
# ----------
# train Loss: 1.0038e+00 NLoss: 2.0038e-02
# val Loss: 9.0683e-01 NLoss: 1.8970e-02
#
# Epoch 2/99
# ----------
# train Loss: 9.3558e-01 NLoss: 1.8676e-02
# val Loss: 8.9192e-01 NLoss: 1.8658e-02
#
# Epoch 3/99
# ----------
# train Loss: 9.2828e-01 NLoss: 1.8531e-02
# val Loss: 8.8934e-01 NLoss: 1.8604e-02
#
# Epoch 4/99
# ----------
# train Loss: 9.2423e-01 NLoss: 1.8450e-02
# val Loss: 8.8444e-01 NLoss: 1.8502e-02
#
# Epoch 5/99
# ----------
# train Loss: 9.2035e-01 NLoss: 1.8372e-02
# val Loss: 8.8166e-01 NLoss: 1.8443e-02
#
# Epoch 6/99
# ----------
# train Loss: 9.1859e-01 NLoss: 1.8337e-02
# val Loss: 8.8039e-01 NLoss: 1.8417e-02
#
# Epoch 7/99
# ----------
# train Loss: 9.1728e-01 NLoss: 1.8311e-02
# val Loss: 8.7918e-01 NLoss: 1.8392e-02
#
# Epoch 8/99
# ----------
# train Loss: 9.1581e-01 NLoss: 1.8282e-02
# val Loss: 8.7767e-01 NLoss: 1.8360e-02
#
# Epoch 9/99
# ----------
# train Loss: 9.1394e-01 NLoss: 1.8244e-02
# val Loss: 8.7560e-01 NLoss: 1.8317e-02
#
# Epoch 10/99
# ----------
# train Loss: 9.1140e-01 NLoss: 1.8194e-02
# val Loss: 8.7267e-01 NLoss: 1.8255e-02
#
# Epoch 11/99
# ----------
# train Loss: 9.0787e-01 NLoss: 1.8123e-02
# val Loss: 8.6844e-01 NLoss: 1.8167e-02
#
# Epoch 12/99
# ----------
# train Loss: 9.0289e-01 NLoss: 1.8024e-02
# val Loss: 8.6237e-01 NLoss: 1.8040e-02
#
# Epoch 13/99
# ----------
# train Loss: 8.9600e-01 NLoss: 1.7886e-02
# val Loss: 8.5398e-01 NLoss: 1.7864e-02
#
# Epoch 14/99
# ----------
# train Loss: 8.8688e-01 NLoss: 1.7704e-02
# val Loss: 8.4312e-01 NLoss: 1.7637e-02
#
# Epoch 15/99
# ----------
# train Loss: 8.7570e-01 NLoss: 1.7481e-02
# val Loss: 8.3041e-01 NLoss: 1.7371e-02
#
# Epoch 16/99
# ----------
# train Loss: 8.6324e-01 NLoss: 1.7232e-02
# val Loss: 8.1728e-01 NLoss: 1.7097e-02
#
# Epoch 17/99
# ----------
# train Loss: 8.5082e-01 NLoss: 1.6984e-02
# val Loss: 8.0567e-01 NLoss: 1.6854e-02
#
# Epoch 18/99
# ----------
# train Loss: 8.3999e-01 NLoss: 1.6768e-02
# val Loss: 7.9703e-01 NLoss: 1.6673e-02
#
# Epoch 19/99
# ----------
# train Loss: 8.3188e-01 NLoss: 1.6606e-02
# val Loss: 7.9163e-01 NLoss: 1.6560e-02
#
# Epoch 20/99
# ----------
# train Loss: 8.2657e-01 NLoss: 1.6500e-02
# val Loss: 7.8866e-01 NLoss: 1.6498e-02
#
# Epoch 21/99
# ----------
# train Loss: 8.2327e-01 NLoss: 1.6434e-02
# val Loss: 7.8707e-01 NLoss: 1.6465e-02
#
# Epoch 22/99
# ----------
# train Loss: 8.2115e-01 NLoss: 1.6392e-02
# val Loss: 7.8617e-01 NLoss: 1.6446e-02
#
# Epoch 23/99
# ----------
# train Loss: 8.1968e-01 NLoss: 1.6363e-02
# val Loss: 7.8560e-01 NLoss: 1.6434e-02
#
# Epoch 24/99
# ----------
# train Loss: 8.1858e-01 NLoss: 1.6341e-02
# val Loss: 7.8521e-01 NLoss: 1.6426e-02
#
# Epoch 25/99
# ----------
# train Loss: 8.1772e-01 NLoss: 1.6324e-02
# val Loss: 7.8493e-01 NLoss: 1.6420e-02
#
# Epoch 26/99
# ----------
# train Loss: 8.1706e-01 NLoss: 1.6310e-02
# val Loss: 7.8472e-01 NLoss: 1.6416e-02
#
# Epoch 27/99
# ----------
# train Loss: 8.1653e-01 NLoss: 1.6300e-02
# val Loss: 7.8456e-01 NLoss: 1.6412e-02
#
# Epoch 28/99
# ----------
# train Loss: 8.1611e-01 NLoss: 1.6291e-02
# val Loss: 7.8444e-01 NLoss: 1.6410e-02
#
# Epoch 29/99
# ----------
# train Loss: 8.1577e-01 NLoss: 1.6285e-02
# val Loss: 7.8433e-01 NLoss: 1.6407e-02
#
# Epoch 30/99
# ----------
# train Loss: 8.1410e-01 NLoss: 1.6251e-02
# val Loss: 7.8431e-01 NLoss: 1.6407e-02
#
# Epoch 31/99
# ----------
# train Loss: 8.1401e-01 NLoss: 1.6250e-02
# val Loss: 7.8431e-01 NLoss: 1.6407e-02
#
# Epoch 32/99
# ----------
# train Loss: 8.1396e-01 NLoss: 1.6249e-02
# val Loss: 7.8430e-01 NLoss: 1.6407e-02
#
# Epoch 33/99
# ----------
# train Loss: 8.1392e-01 NLoss: 1.6248e-02
# val Loss: 7.8429e-01 NLoss: 1.6407e-02
#
# Epoch 34/99
# ----------
# train Loss: 8.1389e-01 NLoss: 1.6247e-02
# val Loss: 7.8428e-01 NLoss: 1.6406e-02
#
# Epoch 35/99
# ----------
# train Loss: 8.1386e-01 NLoss: 1.6247e-02
# val Loss: 7.8427e-01 NLoss: 1.6406e-02
#
# Epoch 36/99
# ----------
# train Loss: 8.1383e-01 NLoss: 1.6246e-02
# val Loss: 7.8426e-01 NLoss: 1.6406e-02
#
# Epoch 37/99
# ----------
# train Loss: 8.1380e-01 NLoss: 1.6245e-02
# val Loss: 7.8425e-01 NLoss: 1.6406e-02
#
# Epoch 38/99
# ----------
# train Loss: 8.1377e-01 NLoss: 1.6245e-02
# val Loss: 7.8424e-01 NLoss: 1.6405e-02
#
# Epoch 39/99
# ----------
# train Loss: 8.1375e-01 NLoss: 1.6244e-02
# val Loss: 7.8423e-01 NLoss: 1.6405e-02
#
# Epoch 40/99
# ----------
# train Loss: 8.1372e-01 NLoss: 1.6244e-02
# val Loss: 7.8422e-01 NLoss: 1.6405e-02
#
# Epoch 41/99
# ----------
# train Loss: 8.1370e-01 NLoss: 1.6243e-02
# val Loss: 7.8421e-01 NLoss: 1.6405e-02
#
# Epoch 42/99
# ----------
# train Loss: 8.1367e-01 NLoss: 1.6243e-02
# val Loss: 7.8419e-01 NLoss: 1.6404e-02
#
# Epoch 43/99
# ----------
# train Loss: 8.1364e-01 NLoss: 1.6242e-02
# val Loss: 7.8418e-01 NLoss: 1.6404e-02
#
# Epoch 44/99
# ----------
# train Loss: 8.1362e-01 NLoss: 1.6242e-02
# val Loss: 7.8417e-01 NLoss: 1.6404e-02
#
# Epoch 45/99
# ----------
# train Loss: 8.1360e-01 NLoss: 1.6241e-02
# val Loss: 7.8416e-01 NLoss: 1.6404e-02
#
# Epoch 46/99
# ----------
# train Loss: 8.1357e-01 NLoss: 1.6241e-02
# val Loss: 7.8415e-01 NLoss: 1.6404e-02
#
# Epoch 47/99
# ----------
# train Loss: 8.1355e-01 NLoss: 1.6240e-02
# val Loss: 7.8414e-01 NLoss: 1.6403e-02
#
# Epoch 48/99
# ----------
# train Loss: 8.1353e-01 NLoss: 1.6240e-02
# val Loss: 7.8413e-01 NLoss: 1.6403e-02
#
# Epoch 49/99
# ----------
# train Loss: 8.1350e-01 NLoss: 1.6239e-02
# val Loss: 7.8412e-01 NLoss: 1.6403e-02
#
# Epoch 50/99
# ----------
# train Loss: 8.1348e-01 NLoss: 1.6239e-02
# val Loss: 7.8411e-01 NLoss: 1.6403e-02
#
# Epoch 51/99
# ----------
# train Loss: 8.1346e-01 NLoss: 1.6239e-02
# val Loss: 7.8409e-01 NLoss: 1.6402e-02
#
# Epoch 52/99
# ----------
# train Loss: 8.1344e-01 NLoss: 1.6238e-02
# val Loss: 7.8408e-01 NLoss: 1.6402e-02
#
# Epoch 53/99
# ----------
# train Loss: 8.1341e-01 NLoss: 1.6238e-02
# val Loss: 7.8407e-01 NLoss: 1.6402e-02
#
# Epoch 54/99
# ----------
# train Loss: 8.1339e-01 NLoss: 1.6237e-02
# val Loss: 7.8406e-01 NLoss: 1.6402e-02
#
# Epoch 55/99
# ----------
# train Loss: 8.1337e-01 NLoss: 1.6237e-02
# val Loss: 7.8405e-01 NLoss: 1.6401e-02
#
# Epoch 56/99
# ----------
# train Loss: 8.1335e-01 NLoss: 1.6236e-02
# val Loss: 7.8404e-01 NLoss: 1.6401e-02
#
# Epoch 57/99
# ----------
# train Loss: 8.1333e-01 NLoss: 1.6236e-02
# val Loss: 7.8403e-01 NLoss: 1.6401e-02
#
# Epoch 58/99
# ----------
# train Loss: 8.1331e-01 NLoss: 1.6236e-02
# val Loss: 7.8402e-01 NLoss: 1.6401e-02
#
# Epoch 59/99
# ----------
# train Loss: 8.1329e-01 NLoss: 1.6235e-02
# val Loss: 7.8401e-01 NLoss: 1.6401e-02
#
# Epoch 60/99
# ----------
# train Loss: 8.1310e-01 NLoss: 1.6231e-02
# val Loss: 7.8393e-01 NLoss: 1.6399e-02
#
# Epoch 61/99
# ----------
# train Loss: 8.1305e-01 NLoss: 1.6230e-02
# val Loss: 7.8389e-01 NLoss: 1.6398e-02
#
# Epoch 62/99
# ----------
# train Loss: 8.1304e-01 NLoss: 1.6230e-02
# val Loss: 7.8387e-01 NLoss: 1.6398e-02
#
# Epoch 63/99
# ----------
# train Loss: 8.1303e-01 NLoss: 1.6230e-02
# val Loss: 7.8386e-01 NLoss: 1.6398e-02
#
# Epoch 64/99
# ----------
# train Loss: 8.1302e-01 NLoss: 1.6230e-02
# val Loss: 7.8386e-01 NLoss: 1.6397e-02
#
# Epoch 65/99
# ----------
# train Loss: 8.1302e-01 NLoss: 1.6230e-02
# val Loss: 7.8385e-01 NLoss: 1.6397e-02
#
# Epoch 66/99
# ----------
# train Loss: 8.1301e-01 NLoss: 1.6230e-02
# val Loss: 7.8385e-01 NLoss: 1.6397e-02
#
# Epoch 67/99
# ----------
# train Loss: 8.1301e-01 NLoss: 1.6230e-02
# val Loss: 7.8385e-01 NLoss: 1.6397e-02
#
# Epoch 68/99
# ----------
# train Loss: 8.1301e-01 NLoss: 1.6230e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 69/99
# ----------
# train Loss: 8.1301e-01 NLoss: 1.6230e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 70/99
# ----------
# train Loss: 8.1300e-01 NLoss: 1.6229e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 71/99
# ----------
# train Loss: 8.1300e-01 NLoss: 1.6229e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 72/99
# ----------
# train Loss: 8.1300e-01 NLoss: 1.6229e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 73/99
# ----------
# train Loss: 8.1300e-01 NLoss: 1.6229e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 74/99
# ----------
# train Loss: 8.1300e-01 NLoss: 1.6229e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 75/99
# ----------
# train Loss: 8.1299e-01 NLoss: 1.6229e-02
# val Loss: 7.8384e-01 NLoss: 1.6397e-02
#
# Epoch 76/99
# ----------
# train Loss: 8.1299e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 77/99
# ----------
# train Loss: 8.1299e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 78/99
# ----------
# train Loss: 8.1299e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 79/99
# ----------
# train Loss: 8.1299e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 80/99
# ----------
# train Loss: 8.1298e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 81/99
# ----------
# train Loss: 8.1298e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 82/99
# ----------
# train Loss: 8.1298e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 83/99
# ----------
# train Loss: 8.1298e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 84/99
# ----------
# train Loss: 8.1298e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 85/99
# ----------
# train Loss: 8.1297e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 86/99
# ----------
# train Loss: 8.1297e-01 NLoss: 1.6229e-02
# val Loss: 7.8383e-01 NLoss: 1.6397e-02
#
# Epoch 87/99
# ----------
# train Loss: 8.1297e-01 NLoss: 1.6229e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 88/99
# ----------
# train Loss: 8.1297e-01 NLoss: 1.6229e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 89/99
# ----------
# train Loss: 8.1297e-01 NLoss: 1.6229e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 90/99
# ----------
# train Loss: 8.1294e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 91/99
# ----------
# train Loss: 8.1294e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 92/99
# ----------
# train Loss: 8.1294e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 93/99
# ----------
# train Loss: 8.1294e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 94/99
# ----------
# train Loss: 8.1294e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 95/99
# ----------
# train Loss: 8.1293e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 96/99
# ----------
# train Loss: 8.1293e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 97/99
# ----------
# train Loss: 8.1293e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 98/99
# ----------
# train Loss: 8.1293e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Epoch 99/99
# ----------
# train Loss: 8.1293e-01 NLoss: 1.6228e-02
# val Loss: 7.8382e-01 NLoss: 1.6397e-02
#
# Training complete in 6m 11s
# Best val loss: 0.783819

# %%
reel=training_dataset[:,:,1][0]

# %%
pred, K1 = modelRINN(training_dataset[:,:,1][0],dt)

# %%
plt.plot(reel[:1000,:],) 
plt.plot(pred[:1000,:].detach())
plt.show()

# %%
plt.plot(reel[:1000,0],) #x
plt.plot(pred[:1000,0].detach(),'.')
plt.show()

# %%
plt.plot(reel[:1000,1],) #y
plt.plot(pred[:1000,1].detach(),'.')
plt.show()

# %%
plt.plot(reel[:1000,2],) #z
plt.plot(pred[:1000,2].detach(),'.')
plt.show()

# %%
print ('Optimizing Dynamical model')        
for t in range(params['ntrain'][1]):
    for b in range(x.shape[0]):
        # Forward pass: Compute predicted y by passing x to the model
        pred, grad = modelRINN(x[b,:,:],params['dt_integration'])
        # Compute and print loss
        loss = criterion(grad, z[b,:,:])
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Save models
        # torch.save(modelRINN.state_dict(), path + file_name)
    print(t,loss)
# Out:
# Optimizing Dynamical model
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:13: UserWarning: reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.
#   warnings.warn("reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.")
# 0 tensor(3351.6013, grad_fn=<MseLossBackward>)
# 1 tensor(3133.5037, grad_fn=<MseLossBackward>)
# 2 tensor(3140.9900, grad_fn=<MseLossBackward>)
# 3 tensor(3137.7378, grad_fn=<MseLossBackward>)
# 4 tensor(3123.3628, grad_fn=<MseLossBackward>)
# 5 tensor(3103.7419, grad_fn=<MseLossBackward>)
# 6 tensor(3076.5566, grad_fn=<MseLossBackward>)
# 7 tensor(3037.5276, grad_fn=<MseLossBackward>)
# 8 tensor(2982.5737, grad_fn=<MseLossBackward>)
# 9 tensor(2905.8269, grad_fn=<MseLossBackward>)
# 10 tensor(2803.7363, grad_fn=<MseLossBackward>)
# 11 tensor(2692.4595, grad_fn=<MseLossBackward>)
# 12 tensor(2593.7375, grad_fn=<MseLossBackward>)
# 13 tensor(2524.7039, grad_fn=<MseLossBackward>)
# 14 tensor(2485.3572, grad_fn=<MseLossBackward>)
# 15 tensor(2463.8174, grad_fn=<MseLossBackward>)
# 16 tensor(2450.8130, grad_fn=<MseLossBackward>)
# 17 tensor(2441.6057, grad_fn=<MseLossBackward>)
# 18 tensor(2434.0588, grad_fn=<MseLossBackward>)
# 19 tensor(2427.2393, grad_fn=<MseLossBackward>)
# 20 tensor(2420.7439, grad_fn=<MseLossBackward>)
# 21 tensor(2414.4050, grad_fn=<MseLossBackward>)
# 22 tensor(2408.1587, grad_fn=<MseLossBackward>)
# 23 tensor(2401.9844, grad_fn=<MseLossBackward>)
# 24 tensor(2395.8855, grad_fn=<MseLossBackward>)
# 25 tensor(2389.8716, grad_fn=<MseLossBackward>)
# 26 tensor(2383.9595, grad_fn=<MseLossBackward>)
# 27 tensor(2378.1667, grad_fn=<MseLossBackward>)
# 28 tensor(2372.5164, grad_fn=<MseLossBackward>)
# 29 tensor(2367.0322, grad_fn=<MseLossBackward>)
# 30 tensor(2361.7437, grad_fn=<MseLossBackward>)
# 31 tensor(2356.6797, grad_fn=<MseLossBackward>)
# 32 tensor(2351.8752, grad_fn=<MseLossBackward>)
# 33 tensor(2347.3640, grad_fn=<MseLossBackward>)
# 34 tensor(2343.1709, grad_fn=<MseLossBackward>)
# 35 tensor(2339.3152, grad_fn=<MseLossBackward>)
# 36 tensor(2335.7998, grad_fn=<MseLossBackward>)
# 37 tensor(2332.6118, grad_fn=<MseLossBackward>)
# 38 tensor(2329.7241, grad_fn=<MseLossBackward>)
# 39 tensor(2327.1028, grad_fn=<MseLossBackward>)
# 40 tensor(2324.7090, grad_fn=<MseLossBackward>)
# 41 tensor(2322.5032, grad_fn=<MseLossBackward>)
# 42 tensor(2320.4539, grad_fn=<MseLossBackward>)
# 43 tensor(2318.5298, grad_fn=<MseLossBackward>)
# 44 tensor(2316.7085, grad_fn=<MseLossBackward>)
# 45 tensor(2314.9724, grad_fn=<MseLossBackward>)
# 46 tensor(2313.3069, grad_fn=<MseLossBackward>)
# 48 tensor(2310.1462, grad_fn=<MseLossBackward>)
# 49 tensor(2308.6389, grad_fn=<MseLossBackward>)
# 50 tensor(2307.1731, grad_fn=<MseLossBackward>)
# 51 tensor(2305.7446, grad_fn=<MseLossBackward>)
# 52 tensor(2304.3511, grad_fn=<MseLossBackward>)
# 53 tensor(2302.9907, grad_fn=<MseLossBackward>)
# 54 tensor(2301.6619, grad_fn=<MseLossBackward>)
# 55 tensor(2300.3643, grad_fn=<MseLossBackward>)
# 56 tensor(2299.0952, grad_fn=<MseLossBackward>)
# 57 tensor(2297.8569, grad_fn=<MseLossBackward>)
# 58 tensor(2296.6487, grad_fn=<MseLossBackward>)
# 59 tensor(2295.4714, grad_fn=<MseLossBackward>)
# 60 tensor(2294.3247, grad_fn=<MseLossBackward>)
# 61 tensor(2293.2100, grad_fn=<MseLossBackward>)
# 62 tensor(2292.1284, grad_fn=<MseLossBackward>)
# 63 tensor(2291.0808, grad_fn=<MseLossBackward>)
# 64 tensor(2290.0674, grad_fn=<MseLossBackward>)
# 65 tensor(2289.0908, grad_fn=<MseLossBackward>)
# 66 tensor(2288.1506, grad_fn=<MseLossBackward>)
# 67 tensor(2287.2488, grad_fn=<MseLossBackward>)
# 68 tensor(2286.3855, grad_fn=<MseLossBackward>)
# 69 tensor(2285.5613, grad_fn=<MseLossBackward>)
# 70 tensor(2284.7759, grad_fn=<MseLossBackward>)
# 71 tensor(2284.0303, grad_fn=<MseLossBackward>)
# 72 tensor(2283.3232, grad_fn=<MseLossBackward>)
# 73 tensor(2282.6555, grad_fn=<MseLossBackward>)
# 74 tensor(2282.0261, grad_fn=<MseLossBackward>)
# 75 tensor(2281.4343, grad_fn=<MseLossBackward>)
# 76 tensor(2280.8789, grad_fn=<MseLossBackward>)
# 77 tensor(2280.3579, grad_fn=<MseLossBackward>)
# 78 tensor(2279.8713, grad_fn=<MseLossBackward>)
# 79 tensor(2279.4167, grad_fn=<MseLossBackward>)
# 80 tensor(2278.9937, grad_fn=<MseLossBackward>)
# 81 tensor(2278.5986, grad_fn=<MseLossBackward>)
# 82 tensor(2278.2300, grad_fn=<MseLossBackward>)
# 83 tensor(2277.8872, grad_fn=<MseLossBackward>)
# 84 tensor(2277.5676, grad_fn=<MseLossBackward>)
# 85 tensor(2277.2703, grad_fn=<MseLossBackward>)
# 86 tensor(2276.9922, grad_fn=<MseLossBackward>)
# 87 tensor(2276.7319, grad_fn=<MseLossBackward>)
# 88 tensor(2276.4885, grad_fn=<MseLossBackward>)
# 89 tensor(2276.2612, grad_fn=<MseLossBackward>)
# 90 tensor(2276.0461, grad_fn=<MseLossBackward>)
# 91 tensor(2275.8442, grad_fn=<MseLossBackward>)
# 92 tensor(2275.6533, grad_fn=<MseLossBackward>)
# 93 tensor(2275.4724, grad_fn=<MseLossBackward>)
# 94 tensor(2275.3000, grad_fn=<MseLossBackward>)
# 95 tensor(2275.1355, grad_fn=<MseLossBackward>)
# 96 tensor(2274.9780, grad_fn=<MseLossBackward>)
# 97 tensor(2274.8279, grad_fn=<MseLossBackward>)
# 98 tensor(2274.6816, grad_fn=<MseLossBackward>)
# 99 tensor(2274.5415, grad_fn=<MseLossBackward>)
# 100 tensor(2274.4043, grad_fn=<MseLossBackward>)
# 101 tensor(2274.2722, grad_fn=<MseLossBackward>)
# 102 tensor(2274.1418, grad_fn=<MseLossBackward>)
# 103 tensor(2274.0156, grad_fn=<MseLossBackward>)
# 104 tensor(2273.8909, grad_fn=<MseLossBackward>)
# 105 tensor(2273.7690, grad_fn=<MseLossBackward>)
# 106 tensor(2273.6484, grad_fn=<MseLossBackward>)
# 107 tensor(2273.5303, grad_fn=<MseLossBackward>)
# 108 tensor(2273.4124, grad_fn=<MseLossBackward>)
# 109 tensor(2273.2957, grad_fn=<MseLossBackward>)
# 110 tensor(2273.1802, grad_fn=<MseLossBackward>)
# 111 tensor(2273.0664, grad_fn=<MseLossBackward>)
# 112 tensor(2272.9517, grad_fn=<MseLossBackward>)
# 113 tensor(2272.8394, grad_fn=<MseLossBackward>)
# 114 tensor(2272.7263, grad_fn=<MseLossBackward>)
# 115 tensor(2272.6162, grad_fn=<MseLossBackward>)
# 116 tensor(2272.5022, grad_fn=<MseLossBackward>)
# 117 tensor(2272.3943, grad_fn=<MseLossBackward>)
# 118 tensor(2272.2810, grad_fn=<MseLossBackward>)
# 119 tensor(2272.1755, grad_fn=<MseLossBackward>)
# 120 tensor(2272.0603, grad_fn=<MseLossBackward>)
# 121 tensor(2271.9595, grad_fn=<MseLossBackward>)
# 122 tensor(2271.8430, grad_fn=<MseLossBackward>)
# 123 tensor(2271.7466, grad_fn=<MseLossBackward>)
# 124 tensor(2271.6248, grad_fn=<MseLossBackward>)
# 125 tensor(2271.5391, grad_fn=<MseLossBackward>)
# 126 tensor(2271.4087, grad_fn=<MseLossBackward>)
# 127 tensor(2271.3386, grad_fn=<MseLossBackward>)
# 128 tensor(2271.1924, grad_fn=<MseLossBackward>)
# 129 tensor(2271.1484, grad_fn=<MseLossBackward>)
# 130 tensor(2270.9731, grad_fn=<MseLossBackward>)
# 131 tensor(2270.9729, grad_fn=<MseLossBackward>)
# 132 tensor(2270.7498, grad_fn=<MseLossBackward>)
# 133 tensor(2270.8218, grad_fn=<MseLossBackward>)
# 134 tensor(2270.5112, grad_fn=<MseLossBackward>)
# 135 tensor(2270.7124, grad_fn=<MseLossBackward>)
# 136 tensor(2270.2505, grad_fn=<MseLossBackward>)
# 137 tensor(2270.6755, grad_fn=<MseLossBackward>)
# 138 tensor(2269.9539, grad_fn=<MseLossBackward>)
# 139 tensor(2270.7805, grad_fn=<MseLossBackward>)
# 140 tensor(2269.6140, grad_fn=<MseLossBackward>)
# 141 tensor(2271.1882, grad_fn=<MseLossBackward>)
# 142 tensor(2269.2478, grad_fn=<MseLossBackward>)
# 143 tensor(2272.3047, grad_fn=<MseLossBackward>)
# 144 tensor(2268.9507, grad_fn=<MseLossBackward>)
# 145 tensor(2275.0671, grad_fn=<MseLossBackward>)
# 146 tensor(2269.0474, grad_fn=<MseLossBackward>)
# 147 tensor(2280.3647, grad_fn=<MseLossBackward>)
# 148 tensor(2270.5422, grad_fn=<MseLossBackward>)
# 149 tensor(2285.3120, grad_fn=<MseLossBackward>)
# 150 tensor(2273.6353, grad_fn=<MseLossBackward>)
# 151 tensor(2285.7231, grad_fn=<MseLossBackward>)
# 152 tensor(2275.3074, grad_fn=<MseLossBackward>)
# 153 tensor(2283.6697, grad_fn=<MseLossBackward>)
# 154 tensor(2275.1409, grad_fn=<MseLossBackward>)
# 155 tensor(2281.6238, grad_fn=<MseLossBackward>)
# 156 tensor(2274.2109, grad_fn=<MseLossBackward>)
# 157 tensor(2280.2756, grad_fn=<MseLossBackward>)
# 158 tensor(2273.1853, grad_fn=<MseLossBackward>)
# 159 tensor(2279.7649, grad_fn=<MseLossBackward>)
# 160 tensor(2272.4041, grad_fn=<MseLossBackward>)
# 161 tensor(2280.0833, grad_fn=<MseLossBackward>)
# 162 tensor(2272.0654, grad_fn=<MseLossBackward>)
# 163 tensor(2280.9980, grad_fn=<MseLossBackward>)
# 164 tensor(2272.2336, grad_fn=<MseLossBackward>)
# 165 tensor(2281.9670, grad_fn=<MseLossBackward>)
# 166 tensor(2272.7368, grad_fn=<MseLossBackward>)
# 167 tensor(2282.4458, grad_fn=<MseLossBackward>)
# 168 tensor(2273.2156, grad_fn=<MseLossBackward>)
# 169 tensor(2282.3401, grad_fn=<MseLossBackward>)
# 170 tensor(2273.4185, grad_fn=<MseLossBackward>)
# 171 tensor(2281.9263, grad_fn=<MseLossBackward>)
# 172 tensor(2273.3447, grad_fn=<MseLossBackward>)
# 173 tensor(2281.5168, grad_fn=<MseLossBackward>)
# 174 tensor(2273.1289, grad_fn=<MseLossBackward>)
# 175 tensor(2281.2935, grad_fn=<MseLossBackward>)
# 176 tensor(2272.9133, grad_fn=<MseLossBackward>)
# 177 tensor(2281.3015, grad_fn=<MseLossBackward>)
# 178 tensor(2272.7927, grad_fn=<MseLossBackward>)
# 179 tensor(2281.4783, grad_fn=<MseLossBackward>)
# 180 tensor(2272.7939, grad_fn=<MseLossBackward>)
# 181 tensor(2281.7021, grad_fn=<MseLossBackward>)
# 182 tensor(2272.8862, grad_fn=<MseLossBackward>)
# 183 tensor(2281.8589, grad_fn=<MseLossBackward>)
# 184 tensor(2272.9993, grad_fn=<MseLossBackward>)
# 185 tensor(2281.9014, grad_fn=<MseLossBackward>)
# 186 tensor(2273.0745, grad_fn=<MseLossBackward>)
# 187 tensor(2281.8525, grad_fn=<MseLossBackward>)
# 188 tensor(2273.0916, grad_fn=<MseLossBackward>)
# 189 tensor(2281.7720, grad_fn=<MseLossBackward>)
# 190 tensor(2273.0632, grad_fn=<MseLossBackward>)
# 191 tensor(2281.7153, grad_fn=<MseLossBackward>)
# 192 tensor(2273.0205, grad_fn=<MseLossBackward>)
# 193 tensor(2281.7080, grad_fn=<MseLossBackward>)
# 194 tensor(2272.9915, grad_fn=<MseLossBackward>)
# 195 tensor(2281.7449, grad_fn=<MseLossBackward>)
# 196 tensor(2272.9878, grad_fn=<MseLossBackward>)
# 197 tensor(2281.8020, grad_fn=<MseLossBackward>)
# 198 tensor(2273.0068, grad_fn=<MseLossBackward>)
# 199 tensor(2281.8542, grad_fn=<MseLossBackward>)

# %%
print ('Optimizing flowmap')        
for t in range(params['ntrain'][1]):
    for b in range(x.shape[0]):
        # Forward pass: Compute predicted y by passing x to the model
        pred, grad = modelRINN(x[b,:,:],params['dt_integration'])
        # Compute and print loss
        loss = criterion(pred, y[b,:,:])
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Save models
        #torch.save(modelRINN.state_dict(), path + file_name)
    print(t,loss)

# %%
pred = [torch.from_numpy(xt.values[:1,:]).float()] 
for i in range(5000):  
    pred.append(modelRINN(pred[-1],params['dt_integration'])[0])

# %%
plt.plot(torch.stack(pred).data.numpy()[:1000,0,0],label = "Prediction from LQM Dynamical model")
plt.plot(xt.values[:1000,0],label = "True state")

# %%
pred = torch.stack(pred)[:,0,:] #??

# %% [markdown]
# ### Test/Evaluation du modèle

# %% [markdown]
# Calcul de MSE

# %%
from sklearn.metrics import mean_squared_error 

#print('mse (sklearn): ', torch.nn.MSELoss(xt,pred))

torch.mean( (torch(reel-pred.detach())**2)) #xt.values

# %% [markdown]
# Calcul de MSE normalisée

# %%
from sklearn.metrics import r2_score 
NMSE = 1- r2_score(reel,pred.detach()) #xt.values

# %%
NMSE
# Out:
# 0.007315287390598613

# %%
pred[:,1].mean() #??
# Out:
# tensor(11.8581, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## Evaluation du modèle appris

# %%
#traçage du flux du modèle stochastique predit
#Undersampling to dt = .01
fig=plt.figure()
ax=fig.gca(projection='3d')
line1,=ax.plot(pred[:20000,0].detach(),pred[:20000,1].detach(),pred[:20000,2].detach(),'k')
ax.set_xlabel('$x_1$');ax.set_ylabel('$x_2$');ax.set_zlabel('$x_3$')
plt.legend([line1], ['Stochastic Lorenz flow'])
plt.title('Stochastic Lorenz flow')
# Out:
# Text(0.5, 0.92, 'Stochastic Lorenz flow')

# %%
#simulation de la série temporelle x
plt.plot(xt.values[:1000,0])
plt.plot(pred[:1000,0].detach())

# %%
#simulation de la série temporelle y
plt.plot(xt.values[:1000,1])
plt.plot(pred[:1000,1].detach())

# %%
#simulation de la série temporelle z
plt.plot(xt.values[:1000,2])
plt.plot(pred[:1000,2].detach())
