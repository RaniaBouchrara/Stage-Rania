# %% [markdown]
# <a href="https://colab.research.google.com/github/RaniaBouchrara/Stage-Rania/blob/master/Lorenz_stochastique10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Génération des données

# %%
# !pip install sdeint
#sdeint permet la résolution de l'équation différentielle stochastique
# Out:
# Collecting sdeint
#   Downloading https://files.pythonhosted.org/packages/3d/26/69946549a57a04ff033780129f3121530565998c017f4f4f06530c2a5b88/sdeint-0.2.1.tar.gz (40kB)
#      |████████████████████████████████| 40kB 1.7MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from sdeint) (1.18.5)
# Building wheels for collected packages: sdeint
#   Building wheel for sdeint (setup.py) ... done
#   Created wheel for sdeint: filename=sdeint-0.2.1-cp36-none-any.whl size=27747 sha256=64a47fe7e2373e8ce911ff8e4c53608f11754111d697662346a00fa85caf4b72
#   Stored in directory: /root/.cache/pip/wheels/6d/76/bf/cd470aaeb760f7ac85bca1614606ed5760408dbf5149240ba4
# Successfully built sdeint
# Installing collected packages: sdeint
# Successfully installed sdeint-0.2.1

# %%
#importer l'ensemle des bibliothèques nécessaires
import sdeint
import sys
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import torch

# %%
'la génération des données et initialisation des paramètres du modèle ainsi que les variables d''intégration, d''apprentissage et de test'
class GD:
    model = 'Lorenz_63' 
    class parameters: 
        sigma = 10.0
        rho = 28.0
        beta = 8.0/3
        theta = 10.0
    
    dt_integration = 0.01 # integration time
    dt_states = 1 # number of integeration times between consecutive states (for xt and catalog)
    dt_obs = 8# number of integration times between consecutive observations (for yo)
    var_obs = np.array([0,1]) # indices of the observed variables
    nb_loop_train = 210.01 # size of the catalog
    nb_loop_test = 100 # size of the true state and noisy observations
    sigma2_catalog = 0.0 # variance of the model error to generate the catalog
    sigma2_obs = 0.0 # variance of the observation error to generate observation

    '''var_obs = np.array([0,1,2]) # indices of the observed variables
    nb_loop_test = 10 # size of the true state and noisy observations
    sigma2_obs = 2.0 # variance of the observation error to generate observation'''

# %%
#définition des équations différentielles stochastiques
def Stoch_Lorenz_63(S,t,sigma=GD.parameters.sigma, rho = GD.parameters.rho, beta = GD.parameters.beta, theta = GD.parameters.theta):
    """ Lorenz-63 dynamical model. """
    x_1 = sigma*(S[1]-S[0])-4*S[0]/(2*theta);
    x_2 = S[0]*(rho-S[2])-S[1] -4*S[1]/(2*theta);
    x_3 = S[0]*S[1] - beta*S[2] -8*S[2]/(2*theta);
    dS  = np.array([x_1,x_2,x_3]);
    return dS
    
#définition du mouvement brwonien 
def brownian_process(S,t,sigma=GD.parameters.sigma, rho = GD.parameters.rho, beta = GD.parameters.beta, theta = GD.parameters.theta):
    x_1 = 0.0;
    x_2 = (rho - S[2])/np.sqrt(theta);
    x_3 = (S[1])/np.sqrt(theta);
    dS  = np.array([x_1,x_2,x_3]);
    G = np.zeros((3,3))
    G[0,0] = x_1
    G[1,0] = x_2
    G[2,0] = x_3
    #np.fill_diagonal(G,dS)
    return G

# %%
#génération d'une solution des équations différentielles à partir d'un x0 donné
np.random.seed(1)
x0 = np.array([8.0,0.0,30.0]);
tspan = np.arange(0,100+0.000001,10E-5) 
S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)

# %%
#traçage du flux du modèle stochastique de lorenz
#Undersampling to dt = .01
S_u  = S[::100]
fig=plt.figure()
ax=fig.gca(projection='3d')
line1,=ax.plot(S_u[:2000,0],S_u[:2000,1],S_u[:2000,2],'k')
ax.set_xlabel('$x_1$');ax.set_ylabel('$x_2$');ax.set_zlabel('$x_3$')
plt.legend([line1], ['Stochastic Lorenz flow'])
plt.title('Stochastic Lorenz flow')
# Out:
# Text(0.5, 0.92, 'Stochastic Lorenz flow')

# %%
#simulation de la série temporelle
plt.plot(S_u[:500,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7fe5ff2e9668>,
#  <matplotlib.lines.Line2D at 0x7fe5ff2e9780>,
#  <matplotlib.lines.Line2D at 0x7fe5ff2e9320>]

# %%
S_u.shape
# Out:
# (10001, 3)

# %%
tspan = np.arange(0,101+0.000001,10E-5) 

def generate_data(GD):
    """ Generate the true state, noisy observations and catalog of numerical simulations. """

    # initialization
    class xt: #xt : test (série temporelle)
        values = [];
        time = [];
    class yo: #yo : observation (assimilation des données)
        values = [];
        time = [];
    class catalog: #catalog : train (base d'apprentissage)
        analogs = [];
        successors = [];
        source = [];
        time = [];
    
    # test on parameters
    if GD.dt_states>GD.dt_obs:
        print('Error: GD.dt_obs must be bigger than GD.dt_states');
    if (np.mod(GD.dt_obs,GD.dt_states)!=0):
        print('Error: GD.dt_obs must be a multiple of GD.dt_states');

    # use this to generate the same data for different simulations
    np.random.seed(1);

    # 5 time steps (to be in the attractor space)  
    x0 = np.array([8.0,0.0,30.0]);
    #S = odeint(Lorenz_63,x0,np.arange(0,5+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)
    x0 = S[S.shape[0]-1,:];

    # generate true state (xt)
    #S = odeint(Lorenz_63,x0,np.arange(0.01,GD.nb_loop_test+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)
    T_test = S.shape[0];      
    t_xt = np.arange(0,T_test,GD.dt_states);       
    xt.time = t_xt*GD.dt_integration;
    xt.values = S[t_xt,:];
        
    # generate  partial/noisy observations (yo)
    eps = np.random.multivariate_normal(np.zeros(3),GD.sigma2_obs*np.eye(3,3),T_test);
    yo_tmp = S[t_xt,:]+eps[t_xt,:];
    t_yo = np.arange(0,T_test,GD.dt_obs);
    i_t_obs = np.where((np.in1d(t_xt,t_yo))==True)[0];
    yo.values = xt.values*np.nan;
    yo.values[np.ix_(i_t_obs,GD.var_obs)] = yo_tmp[np.ix_(i_t_obs,GD.var_obs)];
    yo.time = xt.time;
       

    #generate catalog
    #S =  odeint(Lorenz_63,S[S.shape[0]-1,:],np.arange(0.01,GD.nb_loop_train+0.000001,GD.dt_integration),args=(GD.parameters.Pra,GD.parameters.r,GD.parameters.b,GD.parameters.gamma));
    S = sdeint.itoEuler(Stoch_Lorenz_63, brownian_process, x0, tspan)
    T_train = S.shape[0];
    eta = np.random.multivariate_normal(np.zeros(3),GD.sigma2_catalog*np.eye(3,3),T_train);
    catalog_tmp = S+eta;
    catalog.analogs = catalog_tmp[0:-GD.dt_states,:];
    catalog.successors = catalog_tmp[GD.dt_states:,:]
    catalog.source = GD.parameters;
  # reinitialize random generator number    
    np.random.seed()

    return catalog, xt, yo;

# %%
#run the data generation
catalog, xt, yo = generate_data(GD)

# %%
plt.plot(catalog.analogs[::100,:])
plt.show()

# %%
tmpp = catalog.analogs[::100,:]# downsample to dt  = 0.01
catalog.analogs    =  tmpp[:-1,:][:10000,:]
catalog.successors =  tmpp[1:,:][:10000,:]
plt.plot(catalog.analogs[:1000])
# Out:
# [<matplotlib.lines.Line2D at 0x7fe5fd5145c0>,
#  <matplotlib.lines.Line2D at 0x7fe5fd5146d8>,
#  <matplotlib.lines.Line2D at 0x7fe5fd514828>]

# %%
xt.values = xt.values[::100,:]

# %%
#training data
batch_size = 50
X_train = np.reshape(catalog.analogs,(int(catalog.analogs.shape[0]/batch_size),batch_size,catalog.analogs.shape[1]))
Grad_t  = np.gradient(X_train)[1]/GD.dt_integration #gradient de X_train
Y_train = np.reshape(catalog.successors,(int(catalog.analogs.shape[0]/batch_size),batch_size,catalog.analogs.shape[1])) #successors de catalog

# %%
plt.plot(X_train[0,:,:])
plt.show()

# %%
#initialisation des paramètres du réseau de neurones pour l'apprentissage deep learning
params = {}
params['transition_layers']=1
params['bi_linear_layers']=3
params['dim_hidden_linear'] = 3
params['dim_input']=3
params['dim_output']=3
params['dim_observations'] = 3
params['dim_hidden']=3
params['ntrain']=[1000,200]
params['dt_integration'] = GD.dt_integration
pretrained = False
path = ''# to be defined 
file_name = '' # to be defined

# %%
#classe du modèle dynamique qui permet de calculer le gradient 
np.random.seed(0)
torch.manual_seed(0)
class FC_net(torch.nn.Module):
        def __init__(self, params):
            super(FC_net, self).__init__()
            self.linearCell   = torch.nn.Linear(params['dim_input'], params['dim_hidden_linear']) 
            self.BlinearCell1 = torch.nn.ModuleList([torch.nn.Linear(params['dim_input'], 1) for i in range(params['bi_linear_layers'])])
            self.BlinearCell2 = torch.nn.ModuleList([torch.nn.Linear(params['dim_input'], 1) for i in range(params['bi_linear_layers'])])
            augmented_size    = params['bi_linear_layers'] + params['dim_hidden_linear']
            self.transLayers = torch.nn.ModuleList([torch.nn.Linear(augmented_size, params['dim_input'])])
            self.transLayers.extend([torch.nn.Linear(params['dim_input'],params['dim_input']) for i in range(1, params['transition_layers'])])
            self.outputLayer  = torch.nn.Linear(params['dim_input'], params['dim_input']) 
        def forward(self, inp, dt):
            """
            In the forward function we accept a Tensor of input data and we must return
            a Tensor of output data. We can use Modules defined in the constructor as
            well as arbitrary operators on Tensors.
            """
            aug_inp = inp
            BP_outp = (torch.zeros((aug_inp.size()[0],params['bi_linear_layers'])))
            L_outp   = self.linearCell(aug_inp)
            for i in range((params['bi_linear_layers'])):
                BP_outp[:,i]=self.BlinearCell1[i](aug_inp)[:,0]*self.BlinearCell2[i](aug_inp)[:,0]
            aug_vect = torch.cat((L_outp, BP_outp), dim=1)
            for i in range((params['transition_layers'])):
                aug_vect = (self.transLayers[i](aug_vect))
            grad = self.outputLayer(aug_vect)
            return grad
model  = FC_net(params)

# %%
#classe du modèle dynamique qui permet de calculer l'intégrale
class INT_net(torch.nn.Module):
        def __init__(self, params):
            super(INT_net, self).__init__()
#            self.add_module('Dyn_net',FC_net(params))
            self.Dyn_net = model
        def forward(self, inp,dt):
            """
            In the forward function we accept a Tensor of input data and we must return
            a Tensor of output data. We can use Modules defined in the constructor as
            well as arbitrary operators on Tensors.
            """
            k1 = self.Dyn_net(inp,dt)
            inp_k2      = inp + 0.5*params['dt_integration']*k1
            k2     = self.Dyn_net(inp_k2,dt)
            inp_k3      = inp + 0.5*params['dt_integration']*k2       
            k3     = self.Dyn_net(inp_k3,dt)
            inp_k4      = inp + params['dt_integration']*k3          
            k4     = self.Dyn_net(inp_k4,dt)            
            pred = inp +dt*(k1+2*k2+2*k3+k4)/6    
            return pred, k1
#int_net est appelée lorsqu'on lance le modèle RINN (dans train_model) elle nécessite deux variables dont une la variable dt qui 
#est une variable d'intégration et la variable inputs (train_model=model(inputs,dt)) et retourne une prédiction

# %%
#construction de x,y et z
#conversion de x,y et z d'un numpy de type tableau à un objet torch de type float (réel)
dt       = params['dt_integration']
aug_vect = []  
x = torch.from_numpy(X_train).float() 
y = torch.from_numpy(Y_train).float()
z = torch.from_numpy(Grad_t).float()

#construction du modèle RINN
#critère à minimiser (mse)
#optimizer(adam)
modelRINN = INT_net(params)
criterion = torch.nn.MSELoss(reduction='elementwise_mean')
optimizer = torch.optim.Adam(modelRINN.parameters(),lr = 0.001)

if pretrained : 
    modelRINN.load_state_dict(torch.load(path + file_name))

# %% [markdown]
# # L63 Patch data extraction

# %%
from sklearn.feature_extraction import image

time_step = 1  

# extract subsequences****77
# creation de bout de séries temporelles
dT = 2000
# time series, batch size, nb_batch 
dataTrainingNoNaN = image.extract_patches_2d(catalog.analogs[:,:],(dT,3))
dataTestNoNaN     = image.extract_patches_2d(xt.values[:,:],(dT,3))

# %%
dataTrainingNoNaN.shape
# Out:
# (8001, 2000, 3)

# %%
x_train        = np.moveaxis( dataTrainingNoNaN.reshape((dataTrainingNoNaN.shape[0],dataTrainingNoNaN.shape[1],dataTrainingNoNaN.shape[2])) , 2 , 1 )
x_test         = np.moveaxis( dataTestNoNaN.reshape((dataTestNoNaN.shape[0],dataTestNoNaN.shape[1],dataTestNoNaN.shape[2])) , 2 , 1 )

# %% [markdown]
# # Learning model

# %%
import os
import tensorflow.keras as keras
import time
import copy
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.nn.functional as F

# %%
# Create training/test data pytorch tensors and associated   
# list of tensors (xx[n][x] to access the nth sample for the xth field)
training_dataset     = torch.utils.data.TensorDataset(torch.Tensor(x_train)) # create your dataset
test_dataset         = torch.utils.data.TensorDataset(torch.Tensor(x_test)) # create your dataset

dataloaders = {
    'train': torch.utils.data.DataLoader(training_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True),
    'val': torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4, pin_memory=True),
}
#datatloaders(entrée et sortie sont des données du RN)
#x(t) est rapprochée x(t)-x(t-dt)/dt
#x(t0) est rapprochée par x(t+dt),x(t+2dt),...
#batch_size=32 (état au temps t) inputs
dataset_sizes = {'train': len(training_dataset), 'val': len(test_dataset)}

# %%
#create an optimizer object
#Adam optimizer with learning rate 1e-3
optimizer        = optim.Adam(modelRINN.parameters(), lr=1e-3)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

#mean-squared error loss
criterion = torch.nn.MSELoss()
var_Tr    = np.var( x_train )
var_Tt    = np.var( x_test )

#training function
def train_model(model, dt, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_var  = 0.0

            # Iterate over data.
            for inputs_ in dataloaders[phase]:
                inputs = inputs_[0]
                #inputs = inputs.to(device)
                #print(inputs.size(0))

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):

                    x_init   = inputs[:,:,0].view(-1,3) # initial state
                    x_target = inputs[:,:,1].view(-1,3) # target state
                    #print(x_init.size(),flush=True)
                    outputs = model(x_init,dt)
                    #print(outputs[0].size(),flush=True)
                    #loss = criterion(outputs, inputs)
                    loss = torch.mean((outputs[0] - x_target)**2) #à remplacer par -log vraisemblance

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward() 
                        optimizer.step()

                # statistics
                running_loss   += loss.item() * inputs.size(0)
                #running_expvar += torch.sum( (outputs - inputs)**2 ) / torch.sum(
            if phase == 'train':
                scheduler.step()

            epoch_loss  = running_loss / dataset_sizes[phase]
            if phase == 'train':
              epoch_nloss = epoch_loss / var_Tr
            else:
              epoch_nloss = epoch_loss / var_Tt
            #epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4e} NLoss: {:.4e} '.format(
                phase, epoch_loss, epoch_nloss))
#            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
#                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_loss < best_loss:
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format( 
        time_elapsed // 60, time_elapsed % 60))
    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
#training   
dt         = torch.nn.Parameter(torch.Tensor([0.01]))
num_epochs = 100
modelRINN  = train_model(modelRINN, dt, criterion, optimizer, exp_lr_scheduler, num_epochs)
# Out:
# Epoch 0/99
# ----------
# train Loss: 5.2585e-01 NLoss: 2.4536e-03
# val Loss: 4.1447e-01 NLoss: 2.1034e-03
#
# Epoch 1/99
# ----------
# train Loss: 4.0873e-01 NLoss: 1.9071e-03
# val Loss: 3.1277e-01 NLoss: 1.5873e-03
#
# Epoch 2/99
# ----------
# train Loss: 3.1728e-01 NLoss: 1.4804e-03
# val Loss: 2.5609e-01 NLoss: 1.2997e-03
#
# Epoch 3/99
# ----------
# train Loss: 2.6870e-01 NLoss: 1.2537e-03
# val Loss: 2.1857e-01 NLoss: 1.1093e-03
#
# Epoch 4/99
# ----------
# train Loss: 2.1808e-01 NLoss: 1.0175e-03
# val Loss: 1.6902e-01 NLoss: 8.5779e-04
#
# Epoch 5/99
# ----------
# train Loss: 1.6766e-01 NLoss: 7.8227e-04
# val Loss: 1.4020e-01 NLoss: 7.1153e-04
#
# Epoch 6/99
# ----------
# train Loss: 1.4621e-01 NLoss: 6.8219e-04
# val Loss: 1.3057e-01 NLoss: 6.6264e-04
#
# Epoch 7/99
# ----------
# train Loss: 1.3725e-01 NLoss: 6.4042e-04
# val Loss: 1.2346e-01 NLoss: 6.2658e-04
#
# Epoch 8/99
# ----------
# train Loss: 1.2999e-01 NLoss: 6.0650e-04
# val Loss: 1.1695e-01 NLoss: 5.9352e-04
#
# Epoch 9/99
# ----------
# train Loss: 1.2313e-01 NLoss: 5.7452e-04
# val Loss: 1.1089e-01 NLoss: 5.6280e-04
#
# Epoch 10/99
# ----------
# train Loss: 1.1678e-01 NLoss: 5.4489e-04
# val Loss: 1.0541e-01 NLoss: 5.3497e-04
#
# Epoch 11/99
# ----------
# train Loss: 1.1110e-01 NLoss: 5.1841e-04
# val Loss: 1.0061e-01 NLoss: 5.1060e-04
#
# Epoch 12/99
# ----------
# train Loss: 1.0621e-01 NLoss: 4.9556e-04
# val Loss: 9.6537e-02 NLoss: 4.8993e-04
#
# Epoch 13/99
# ----------
# train Loss: 1.0212e-01 NLoss: 4.7650e-04
# val Loss: 9.3193e-02 NLoss: 4.7296e-04
#
# Epoch 14/99
# ----------
# train Loss: 9.8824e-02 NLoss: 4.6111e-04
# val Loss: 9.0533e-02 NLoss: 4.5946e-04
#
# Epoch 15/99
# ----------
# train Loss: 9.6247e-02 NLoss: 4.4908e-04
# val Loss: 8.8488e-02 NLoss: 4.4908e-04
#
# Epoch 16/99
# ----------
# train Loss: 9.4297e-02 NLoss: 4.3999e-04
# val Loss: 8.6965e-02 NLoss: 4.4135e-04
#
# Epoch 17/99
# ----------
# train Loss: 9.2867e-02 NLoss: 4.3331e-04
# val Loss: 8.5863e-02 NLoss: 4.3576e-04
#
# Epoch 18/99
# ----------
# train Loss: 9.1841e-02 NLoss: 4.2853e-04
# val Loss: 8.5084e-02 NLoss: 4.3181e-04
#
# Epoch 19/99
# ----------
# train Loss: 9.1118e-02 NLoss: 4.2515e-04
# val Loss: 8.4538e-02 NLoss: 4.2904e-04
#
# Epoch 20/99
# ----------
# train Loss: 9.0607e-02 NLoss: 4.2277e-04
# val Loss: 8.4154e-02 NLoss: 4.2709e-04
#
# Epoch 21/99
# ----------
# train Loss: 9.0241e-02 NLoss: 4.2106e-04
# val Loss: 8.3880e-02 NLoss: 4.2569e-04
#
# Epoch 22/99
# ----------
# train Loss: 8.9971e-02 NLoss: 4.1980e-04
# val Loss: 8.3676e-02 NLoss: 4.2466e-04
#
# Epoch 23/99
# ----------
# train Loss: 8.9764e-02 NLoss: 4.1883e-04
# val Loss: 8.3518e-02 NLoss: 4.2386e-04
#
# Epoch 24/99
# ----------
# train Loss: 8.9595e-02 NLoss: 4.1805e-04
# val Loss: 8.3389e-02 NLoss: 4.2320e-04
#
# Epoch 25/99
# ----------
# train Loss: 8.9450e-02 NLoss: 4.1737e-04
# val Loss: 8.3277e-02 NLoss: 4.2264e-04
#
# Epoch 26/99
# ----------
# train Loss: 8.9319e-02 NLoss: 4.1676e-04
# val Loss: 8.3175e-02 NLoss: 4.2212e-04
#
# Epoch 27/99
# ----------
# train Loss: 8.9193e-02 NLoss: 4.1617e-04
# val Loss: 8.3077e-02 NLoss: 4.2162e-04
#
# Epoch 28/99
# ----------
# train Loss: 8.9068e-02 NLoss: 4.1559e-04
# val Loss: 8.2977e-02 NLoss: 4.2112e-04
#
# Epoch 29/99
# ----------
# train Loss: 8.8937e-02 NLoss: 4.1498e-04
# val Loss: 8.2872e-02 NLoss: 4.2058e-04
#
# Epoch 30/99
# ----------
# train Loss: 8.8204e-02 NLoss: 4.1155e-04
# val Loss: 8.2427e-02 NLoss: 4.1832e-04
#
# Epoch 31/99
# ----------
# train Loss: 8.8122e-02 NLoss: 4.1117e-04
# val Loss: 8.2418e-02 NLoss: 4.1828e-04
#
# Epoch 32/99
# ----------
# train Loss: 8.8094e-02 NLoss: 4.1104e-04
# val Loss: 8.2417e-02 NLoss: 4.1827e-04
#
# Epoch 33/99
# ----------
# train Loss: 8.8070e-02 NLoss: 4.1093e-04
# val Loss: 8.2415e-02 NLoss: 4.1826e-04
#
# Epoch 34/99
# ----------
# train Loss: 8.8049e-02 NLoss: 4.1083e-04
# val Loss: 8.2409e-02 NLoss: 4.1823e-04
#
# Epoch 35/99
# ----------
# train Loss: 8.8029e-02 NLoss: 4.1074e-04
# val Loss: 8.2401e-02 NLoss: 4.1819e-04
#
# Epoch 36/99
# ----------
# train Loss: 8.8010e-02 NLoss: 4.1065e-04
# val Loss: 8.2390e-02 NLoss: 4.1814e-04
#
# Epoch 37/99
# ----------
# train Loss: 8.7992e-02 NLoss: 4.1057e-04
# val Loss: 8.2379e-02 NLoss: 4.1808e-04
#
# Epoch 38/99
# ----------
# train Loss: 8.7974e-02 NLoss: 4.1048e-04
# val Loss: 8.2366e-02 NLoss: 4.1801e-04
#
# Epoch 39/99
# ----------
# train Loss: 8.7955e-02 NLoss: 4.1040e-04
# val Loss: 8.2352e-02 NLoss: 4.1794e-04
#
# Epoch 40/99
# ----------
# train Loss: 8.7937e-02 NLoss: 4.1031e-04
# val Loss: 8.2338e-02 NLoss: 4.1787e-04
#
# Epoch 41/99
# ----------
# train Loss: 8.7919e-02 NLoss: 4.1023e-04
# val Loss: 8.2323e-02 NLoss: 4.1779e-04
#
# Epoch 42/99
# ----------
# train Loss: 8.7900e-02 NLoss: 4.1014e-04
# val Loss: 8.2308e-02 NLoss: 4.1772e-04
#
# Epoch 43/99
# ----------
# train Loss: 8.7882e-02 NLoss: 4.1005e-04
# val Loss: 8.2292e-02 NLoss: 4.1764e-04
#
# Epoch 44/99
# ----------
# train Loss: 8.7863e-02 NLoss: 4.0996e-04
# val Loss: 8.2276e-02 NLoss: 4.1756e-04
#
# Epoch 45/99
# ----------
# train Loss: 8.7843e-02 NLoss: 4.0987e-04
# val Loss: 8.2260e-02 NLoss: 4.1748e-04
#
# Epoch 46/99
# ----------
# train Loss: 8.7824e-02 NLoss: 4.0978e-04
# val Loss: 8.2244e-02 NLoss: 4.1739e-04
#
# Epoch 47/99
# ----------
# train Loss: 8.7805e-02 NLoss: 4.0969e-04
# val Loss: 8.2227e-02 NLoss: 4.1731e-04
#
# Epoch 48/99
# ----------
# train Loss: 8.7785e-02 NLoss: 4.0960e-04
# val Loss: 8.2211e-02 NLoss: 4.1722e-04
#
# Epoch 49/99
# ----------
# train Loss: 8.7764e-02 NLoss: 4.0950e-04
# val Loss: 8.2194e-02 NLoss: 4.1714e-04
#
# Epoch 50/99
# ----------
# train Loss: 8.7744e-02 NLoss: 4.0941e-04
# val Loss: 8.2176e-02 NLoss: 4.1705e-04
#
# Epoch 51/99
# ----------
# train Loss: 8.7723e-02 NLoss: 4.0931e-04
# val Loss: 8.2159e-02 NLoss: 4.1696e-04
#
# Epoch 52/99
# ----------
# train Loss: 8.7702e-02 NLoss: 4.0921e-04
# val Loss: 8.2141e-02 NLoss: 4.1687e-04
#
# Epoch 53/99
# ----------
# train Loss: 8.7681e-02 NLoss: 4.0911e-04
# val Loss: 8.2123e-02 NLoss: 4.1678e-04
#
# Epoch 54/99
# ----------
# train Loss: 8.7659e-02 NLoss: 4.0901e-04
# val Loss: 8.2104e-02 NLoss: 4.1668e-04
#
# Epoch 55/99
# ----------
# train Loss: 8.7637e-02 NLoss: 4.0891e-04
# val Loss: 8.2085e-02 NLoss: 4.1659e-04
#
# Epoch 56/99
# ----------
# train Loss: 8.7615e-02 NLoss: 4.0881e-04
# val Loss: 8.2066e-02 NLoss: 4.1649e-04
#
# Epoch 57/99
# ----------
# train Loss: 8.7592e-02 NLoss: 4.0870e-04
# val Loss: 8.2047e-02 NLoss: 4.1639e-04
#
# Epoch 58/99
# ----------
# train Loss: 8.7569e-02 NLoss: 4.0859e-04
# val Loss: 8.2027e-02 NLoss: 4.1629e-04
#
# Epoch 59/99
# ----------
# train Loss: 8.7545e-02 NLoss: 4.0848e-04
# val Loss: 8.2007e-02 NLoss: 4.1619e-04
#
# Epoch 60/99
# ----------
# train Loss: 8.7420e-02 NLoss: 4.0790e-04
# val Loss: 8.1993e-02 NLoss: 4.1612e-04
#
# Epoch 61/99
# ----------
# train Loss: 8.7415e-02 NLoss: 4.0787e-04
# val Loss: 8.1983e-02 NLoss: 4.1607e-04
#
# Epoch 62/99
# ----------
# train Loss: 8.7411e-02 NLoss: 4.0786e-04
# val Loss: 8.1975e-02 NLoss: 4.1603e-04
#
# Epoch 63/99
# ----------
# train Loss: 8.7408e-02 NLoss: 4.0784e-04
# val Loss: 8.1969e-02 NLoss: 4.1599e-04
#
# Epoch 64/99
# ----------
# train Loss: 8.7405e-02 NLoss: 4.0783e-04
# val Loss: 8.1963e-02 NLoss: 4.1597e-04
#
# Epoch 65/99
# ----------
# train Loss: 8.7402e-02 NLoss: 4.0781e-04
# val Loss: 8.1959e-02 NLoss: 4.1595e-04
#
# Epoch 66/99
# ----------
# train Loss: 8.7399e-02 NLoss: 4.0780e-04
# val Loss: 8.1955e-02 NLoss: 4.1593e-04
#
# Epoch 67/99
# ----------
# train Loss: 8.7396e-02 NLoss: 4.0779e-04
# val Loss: 8.1952e-02 NLoss: 4.1591e-04
#
# Epoch 68/99
# ----------
# train Loss: 8.7394e-02 NLoss: 4.0777e-04
# val Loss: 8.1949e-02 NLoss: 4.1590e-04
#
# Epoch 69/99
# ----------
# train Loss: 8.7391e-02 NLoss: 4.0776e-04
# val Loss: 8.1946e-02 NLoss: 4.1588e-04
#
# Epoch 70/99
# ----------
# train Loss: 8.7388e-02 NLoss: 4.0775e-04
# val Loss: 8.1944e-02 NLoss: 4.1587e-04
#
# Epoch 71/99
# ----------
# train Loss: 8.7386e-02 NLoss: 4.0774e-04
# val Loss: 8.1941e-02 NLoss: 4.1586e-04
#
# Epoch 72/99
# ----------
# train Loss: 8.7383e-02 NLoss: 4.0773e-04
# val Loss: 8.1939e-02 NLoss: 4.1584e-04
#
# Epoch 73/99
# ----------
# train Loss: 8.7381e-02 NLoss: 4.0771e-04
# val Loss: 8.1937e-02 NLoss: 4.1583e-04
#
# Epoch 74/99
# ----------
# train Loss: 8.7378e-02 NLoss: 4.0770e-04
# val Loss: 8.1934e-02 NLoss: 4.1582e-04
#
# Epoch 75/99
# ----------
# train Loss: 8.7376e-02 NLoss: 4.0769e-04
# val Loss: 8.1932e-02 NLoss: 4.1581e-04
#
# Epoch 76/99
# ----------
# train Loss: 8.7373e-02 NLoss: 4.0768e-04
# val Loss: 8.1930e-02 NLoss: 4.1580e-04
#
# Epoch 77/99
# ----------
# train Loss: 8.7370e-02 NLoss: 4.0767e-04
# val Loss: 8.1928e-02 NLoss: 4.1579e-04
#
# Epoch 78/99
# ----------
# train Loss: 8.7368e-02 NLoss: 4.0765e-04
# val Loss: 8.1926e-02 NLoss: 4.1578e-04
#
# Epoch 79/99
# ----------
# train Loss: 8.7365e-02 NLoss: 4.0764e-04
# val Loss: 8.1924e-02 NLoss: 4.1577e-04
#
# Epoch 80/99
# ----------
# train Loss: 8.7363e-02 NLoss: 4.0763e-04
# val Loss: 8.1922e-02 NLoss: 4.1576e-04
#
# Epoch 81/99
# ----------
# train Loss: 8.7360e-02 NLoss: 4.0762e-04
# val Loss: 8.1920e-02 NLoss: 4.1575e-04
#
# Epoch 82/99
# ----------
# train Loss: 8.7358e-02 NLoss: 4.0761e-04
# val Loss: 8.1918e-02 NLoss: 4.1574e-04
#
# Epoch 83/99
# ----------
# train Loss: 8.7355e-02 NLoss: 4.0759e-04
# val Loss: 8.1915e-02 NLoss: 4.1573e-04
#
# Epoch 84/99
# ----------
# train Loss: 8.7353e-02 NLoss: 4.0758e-04
# val Loss: 8.1913e-02 NLoss: 4.1571e-04
#
# Epoch 85/99
# ----------
# train Loss: 8.7350e-02 NLoss: 4.0757e-04
# val Loss: 8.1911e-02 NLoss: 4.1570e-04
#
# Epoch 86/99
# ----------
# train Loss: 8.7347e-02 NLoss: 4.0756e-04
# val Loss: 8.1909e-02 NLoss: 4.1569e-04
#
# Epoch 87/99
# ----------
# train Loss: 8.7345e-02 NLoss: 4.0755e-04
# val Loss: 8.1907e-02 NLoss: 4.1568e-04
#
# Epoch 88/99
# ----------
# train Loss: 8.7342e-02 NLoss: 4.0753e-04
# val Loss: 8.1905e-02 NLoss: 4.1567e-04
#
# Epoch 89/99
# ----------
# train Loss: 8.7340e-02 NLoss: 4.0752e-04
# val Loss: 8.1903e-02 NLoss: 4.1566e-04
#
# Epoch 90/99
# ----------
# train Loss: 8.7323e-02 NLoss: 4.0744e-04
# val Loss: 8.1903e-02 NLoss: 4.1566e-04
#
# Epoch 91/99
# ----------
# train Loss: 8.7323e-02 NLoss: 4.0744e-04
# val Loss: 8.1903e-02 NLoss: 4.1566e-04
#
# Epoch 92/99
# ----------
# train Loss: 8.7322e-02 NLoss: 4.0744e-04
# val Loss: 8.1902e-02 NLoss: 4.1566e-04
#
# Epoch 93/99
# ----------
# train Loss: 8.7322e-02 NLoss: 4.0744e-04
# val Loss: 8.1902e-02 NLoss: 4.1566e-04
#
# Epoch 94/99
# ----------
# train Loss: 8.7322e-02 NLoss: 4.0744e-04
# val Loss: 8.1902e-02 NLoss: 4.1566e-04
#
# Epoch 95/99
# ----------
# train Loss: 8.7321e-02 NLoss: 4.0744e-04
# val Loss: 8.1901e-02 NLoss: 4.1565e-04
#
# Epoch 96/99
# ----------
# train Loss: 8.7321e-02 NLoss: 4.0744e-04
# val Loss: 8.1901e-02 NLoss: 4.1565e-04
#
# Epoch 97/99
# ----------
# train Loss: 8.7321e-02 NLoss: 4.0743e-04
# val Loss: 8.1901e-02 NLoss: 4.1565e-04
#
# Epoch 98/99
# ----------
# train Loss: 8.7320e-02 NLoss: 4.0743e-04
# val Loss: 8.1901e-02 NLoss: 4.1565e-04
#
# Epoch 99/99
# ----------
# train Loss: 8.7320e-02 NLoss: 4.0743e-04
# val Loss: 8.1900e-02 NLoss: 4.1565e-04
#
# Training complete in 6m 54s
# Best val loss: 0.081900

# %%
reel=training_dataset[:,:,1][0]

# %%
pred, K1 = modelRINN(training_dataset[:,:,1][0],dt)

# %%
plt.plot(reel[:1000,:],) 
plt.plot(pred[:1000,:].detach())
plt.show()

# %%
plt.plot(reel[:1000,0],) #x
plt.plot(pred[:1000,0].detach(),'.')
plt.show()

# %%
plt.plot(reel[:1000,1],) #y
plt.plot(pred[:1000,1].detach(),'.')
plt.show()

# %%
plt.plot(reel[:1000,2],) #z
plt.plot(pred[:1000,2].detach(),'.')
plt.show()

# %%
print ('Optimizing Dynamical model')        
for t in range(params['ntrain'][1]):
    for b in range(x.shape[0]):
        # Forward pass: Compute predicted y by passing x to the model
        pred, grad = modelRINN(x[b,:,:],params['dt_integration'])
        # Compute and print loss
        loss = criterion(grad, z[b,:,:])
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Save models
        # torch.save(modelRINN.state_dict(), path + file_name)
    print(t,loss)
# Out:
# Optimizing Dynamical model
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:13: UserWarning: reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.
#   warnings.warn("reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.")
# 0 tensor(252.0814, grad_fn=<MseLossBackward>)
# 1 tensor(246.1897, grad_fn=<MseLossBackward>)
# 2 tensor(243.3766, grad_fn=<MseLossBackward>)
# 3 tensor(241.0591, grad_fn=<MseLossBackward>)
# 4 tensor(238.5767, grad_fn=<MseLossBackward>)
# 5 tensor(235.4965, grad_fn=<MseLossBackward>)
# 6 tensor(231.4512, grad_fn=<MseLossBackward>)
# 7 tensor(226.1589, grad_fn=<MseLossBackward>)
# 8 tensor(219.5177, grad_fn=<MseLossBackward>)
# 9 tensor(211.5196, grad_fn=<MseLossBackward>)
# 10 tensor(201.6607, grad_fn=<MseLossBackward>)
# 11 tensor(188.5701, grad_fn=<MseLossBackward>)
# 12 tensor(171.9741, grad_fn=<MseLossBackward>)
# 13 tensor(155.3108, grad_fn=<MseLossBackward>)
# 14 tensor(142.8888, grad_fn=<MseLossBackward>)
# 15 tensor(135.5156, grad_fn=<MseLossBackward>)
# 16 tensor(131.5004, grad_fn=<MseLossBackward>)
# 17 tensor(129.2440, grad_fn=<MseLossBackward>)
# 18 tensor(127.9054, grad_fn=<MseLossBackward>)
# 19 tensor(127.0902, grad_fn=<MseLossBackward>)
# 20 tensor(126.5905, grad_fn=<MseLossBackward>)
# 21 tensor(126.2828, grad_fn=<MseLossBackward>)
# 22 tensor(126.0907, grad_fn=<MseLossBackward>)
# 23 tensor(125.9654, grad_fn=<MseLossBackward>)
# 24 tensor(125.8776, grad_fn=<MseLossBackward>)
# 25 tensor(125.8092, grad_fn=<MseLossBackward>)
# 26 tensor(125.7500, grad_fn=<MseLossBackward>)
# 27 tensor(125.6941, grad_fn=<MseLossBackward>)
# 28 tensor(125.6386, grad_fn=<MseLossBackward>)
# 29 tensor(125.5816, grad_fn=<MseLossBackward>)
# 30 tensor(125.5228, grad_fn=<MseLossBackward>)
# 31 tensor(125.4622, grad_fn=<MseLossBackward>)
# 32 tensor(125.3997, grad_fn=<MseLossBackward>)
# 33 tensor(125.3356, grad_fn=<MseLossBackward>)
# 34 tensor(125.2703, grad_fn=<MseLossBackward>)
# 35 tensor(125.2040, grad_fn=<MseLossBackward>)
# 36 tensor(125.1372, grad_fn=<MseLossBackward>)
# 37 tensor(125.0700, grad_fn=<MseLossBackward>)
# 38 tensor(125.0027, grad_fn=<MseLossBackward>)
# 39 tensor(124.9356, grad_fn=<MseLossBackward>)
# 40 tensor(124.8688, grad_fn=<MseLossBackward>)
# 41 tensor(124.8023, grad_fn=<MseLossBackward>)
# 42 tensor(124.7367, grad_fn=<MseLossBackward>)
# 43 tensor(124.6717, grad_fn=<MseLossBackward>)
# 44 tensor(124.6076, grad_fn=<MseLossBackward>)
# 45 tensor(124.5443, grad_fn=<MseLossBackward>)
# 46 tensor(124.4819, grad_fn=<MseLossBackward>)
# 47 tensor(124.4206, grad_fn=<MseLossBackward>)
# 48 tensor(124.3602, grad_fn=<MseLossBackward>)
# 49 tensor(124.3009, grad_fn=<MseLossBackward>)
# 50 tensor(124.2426, grad_fn=<MseLossBackward>)
# 51 tensor(124.1854, grad_fn=<MseLossBackward>)
# 52 tensor(124.1292, grad_fn=<MseLossBackward>)
# 53 tensor(124.0740, grad_fn=<MseLossBackward>)
# 54 tensor(124.0198, grad_fn=<MseLossBackward>)
# 55 tensor(123.9667, grad_fn=<MseLossBackward>)
# 56 tensor(123.9146, grad_fn=<MseLossBackward>)
# 57 tensor(123.8634, grad_fn=<MseLossBackward>)
# 58 tensor(123.8132, grad_fn=<MseLossBackward>)
# 59 tensor(123.7640, grad_fn=<MseLossBackward>)
# 60 tensor(123.7157, grad_fn=<MseLossBackward>)
# 61 tensor(123.6684, grad_fn=<MseLossBackward>)
# 62 tensor(123.6219, grad_fn=<MseLossBackward>)
# 63 tensor(123.5763, grad_fn=<MseLossBackward>)
# 64 tensor(123.5315, grad_fn=<MseLossBackward>)
# 65 tensor(123.4876, grad_fn=<MseLossBackward>)
# 66 tensor(123.4444, grad_fn=<MseLossBackward>)
# 67 tensor(123.4021, grad_fn=<MseLossBackward>)
# 68 tensor(123.3605, grad_fn=<MseLossBackward>)
# 69 tensor(123.3195, grad_fn=<MseLossBackward>)
# 70 tensor(123.2794, grad_fn=<MseLossBackward>)
# 71 tensor(123.2400, grad_fn=<MseLossBackward>)
# 72 tensor(123.2011, grad_fn=<MseLossBackward>)
# 73 tensor(123.1629, grad_fn=<MseLossBackward>)
# 74 tensor(123.1254, grad_fn=<MseLossBackward>)
# 75 tensor(123.0885, grad_fn=<MseLossBackward>)
# 76 tensor(123.0521, grad_fn=<MseLossBackward>)
# 77 tensor(123.0163, grad_fn=<MseLossBackward>)
# 78 tensor(122.9809, grad_fn=<MseLossBackward>)
# 79 tensor(122.9461, grad_fn=<MseLossBackward>)
# 80 tensor(122.9118, grad_fn=<MseLossBackward>)
# 81 tensor(122.8780, grad_fn=<MseLossBackward>)
# 82 tensor(122.8446, grad_fn=<MseLossBackward>)
# 83 tensor(122.8116, grad_fn=<MseLossBackward>)
# 84 tensor(122.7790, grad_fn=<MseLossBackward>)
# 85 tensor(122.7468, grad_fn=<MseLossBackward>)
# 86 tensor(122.7152, grad_fn=<MseLossBackward>)
# 87 tensor(122.6837, grad_fn=<MseLossBackward>)
# 88 tensor(122.6526, grad_fn=<MseLossBackward>)
# 89 tensor(122.6220, grad_fn=<MseLossBackward>)
# 90 tensor(122.5915, grad_fn=<MseLossBackward>)
# 91 tensor(122.5615, grad_fn=<MseLossBackward>)
# 92 tensor(122.5317, grad_fn=<MseLossBackward>)
# 93 tensor(122.5023, grad_fn=<MseLossBackward>)
# 94 tensor(122.4730, grad_fn=<MseLossBackward>)
# 95 tensor(122.4441, grad_fn=<MseLossBackward>)
# 96 tensor(122.4154, grad_fn=<MseLossBackward>)
# 97 tensor(122.3871, grad_fn=<MseLossBackward>)
# 98 tensor(122.3588, grad_fn=<MseLossBackward>)
# 99 tensor(122.3309, grad_fn=<MseLossBackward>)
# 100 tensor(122.3031, grad_fn=<MseLossBackward>)
# 101 tensor(122.2756, grad_fn=<MseLossBackward>)
# 102 tensor(122.2484, grad_fn=<MseLossBackward>)
# 103 tensor(122.2212, grad_fn=<MseLossBackward>)
# 104 tensor(122.1943, grad_fn=<MseLossBackward>)
# 105 tensor(122.1677, grad_fn=<MseLossBackward>)
# 106 tensor(122.1411, grad_fn=<MseLossBackward>)
# 107 tensor(122.1148, grad_fn=<MseLossBackward>)
# 108 tensor(122.0886, grad_fn=<MseLossBackward>)
# 109 tensor(122.0626, grad_fn=<MseLossBackward>)
# 110 tensor(122.0367, grad_fn=<MseLossBackward>)
# 111 tensor(122.0110, grad_fn=<MseLossBackward>)
# 112 tensor(121.9855, grad_fn=<MseLossBackward>)
# 113 tensor(121.9601, grad_fn=<MseLossBackward>)
# 114 tensor(121.9347, grad_fn=<MseLossBackward>)
# 115 tensor(121.9096, grad_fn=<MseLossBackward>)
# 116 tensor(121.8845, grad_fn=<MseLossBackward>)
# 117 tensor(121.8595, grad_fn=<MseLossBackward>)
# 118 tensor(121.8347, grad_fn=<MseLossBackward>)
# 119 tensor(121.8100, grad_fn=<MseLossBackward>)
# 120 tensor(121.7853, grad_fn=<MseLossBackward>)
# 121 tensor(121.7608, grad_fn=<MseLossBackward>)
# 122 tensor(121.7364, grad_fn=<MseLossBackward>)
# 123 tensor(121.7121, grad_fn=<MseLossBackward>)
# 124 tensor(121.6877, grad_fn=<MseLossBackward>)
# 125 tensor(121.6635, grad_fn=<MseLossBackward>)
# 126 tensor(121.6393, grad_fn=<MseLossBackward>)
# 127 tensor(121.6152, grad_fn=<MseLossBackward>)
# 128 tensor(121.5912, grad_fn=<MseLossBackward>)
# 129 tensor(121.5672, grad_fn=<MseLossBackward>)
# 130 tensor(121.5432, grad_fn=<MseLossBackward>)
# 131 tensor(121.5192, grad_fn=<MseLossBackward>)
# 132 tensor(121.4953, grad_fn=<MseLossBackward>)
# 133 tensor(121.4715, grad_fn=<MseLossBackward>)
# 134 tensor(121.4476, grad_fn=<MseLossBackward>)
# 135 tensor(121.4238, grad_fn=<MseLossBackward>)
# 136 tensor(121.3999, grad_fn=<MseLossBackward>)
# 137 tensor(121.3761, grad_fn=<MseLossBackward>)
# 138 tensor(121.3522, grad_fn=<MseLossBackward>)
# 139 tensor(121.3284, grad_fn=<MseLossBackward>)
# 140 tensor(121.3046, grad_fn=<MseLossBackward>)
# 141 tensor(121.2807, grad_fn=<MseLossBackward>)
# 142 tensor(121.2569, grad_fn=<MseLossBackward>)
# 143 tensor(121.2330, grad_fn=<MseLossBackward>)
# 144 tensor(121.2090, grad_fn=<MseLossBackward>)
# 145 tensor(121.1850, grad_fn=<MseLossBackward>)
# 146 tensor(121.1610, grad_fn=<MseLossBackward>)
# 147 tensor(121.1370, grad_fn=<MseLossBackward>)
# 148 tensor(121.1128, grad_fn=<MseLossBackward>)
# 149 tensor(121.0886, grad_fn=<MseLossBackward>)
# 150 tensor(121.0644, grad_fn=<MseLossBackward>)
# 151 tensor(121.0402, grad_fn=<MseLossBackward>)
# 152 tensor(121.0158, grad_fn=<MseLossBackward>)
# 153 tensor(120.9914, grad_fn=<MseLossBackward>)
# 154 tensor(120.9669, grad_fn=<MseLossBackward>)
# 155 tensor(120.9423, grad_fn=<MseLossBackward>)
# 156 tensor(120.9177, grad_fn=<MseLossBackward>)
# 157 tensor(120.8929, grad_fn=<MseLossBackward>)
# 158 tensor(120.8682, grad_fn=<MseLossBackward>)
# 159 tensor(120.8433, grad_fn=<MseLossBackward>)
# 160 tensor(120.8183, grad_fn=<MseLossBackward>)
# 161 tensor(120.7932, grad_fn=<MseLossBackward>)
# 162 tensor(120.7681, grad_fn=<MseLossBackward>)
# 163 tensor(120.7429, grad_fn=<MseLossBackward>)
# 164 tensor(120.7175, grad_fn=<MseLossBackward>)
# 165 tensor(120.6921, grad_fn=<MseLossBackward>)
# 166 tensor(120.6665, grad_fn=<MseLossBackward>)
# 167 tensor(120.6409, grad_fn=<MseLossBackward>)
# 168 tensor(120.6152, grad_fn=<MseLossBackward>)
# 169 tensor(120.5894, grad_fn=<MseLossBackward>)
# 170 tensor(120.5634, grad_fn=<MseLossBackward>)
# 171 tensor(120.5373, grad_fn=<MseLossBackward>)
# 172 tensor(120.5112, grad_fn=<MseLossBackward>)
# 173 tensor(120.4850, grad_fn=<MseLossBackward>)
# 174 tensor(120.4586, grad_fn=<MseLossBackward>)
# 175 tensor(120.4322, grad_fn=<MseLossBackward>)
# 176 tensor(120.4057, grad_fn=<MseLossBackward>)
# 177 tensor(120.3789, grad_fn=<MseLossBackward>)
# 178 tensor(120.3522, grad_fn=<MseLossBackward>)
# 179 tensor(120.3253, grad_fn=<MseLossBackward>)
# 180 tensor(120.2984, grad_fn=<MseLossBackward>)
# 181 tensor(120.2713, grad_fn=<MseLossBackward>)
# 182 tensor(120.2442, grad_fn=<MseLossBackward>)
# 183 tensor(120.2169, grad_fn=<MseLossBackward>)
# 184 tensor(120.1896, grad_fn=<MseLossBackward>)
# 185 tensor(120.1621, grad_fn=<MseLossBackward>)
# 186 tensor(120.1346, grad_fn=<MseLossBackward>)
# 187 tensor(120.1070, grad_fn=<MseLossBackward>)
# 188 tensor(120.0794, grad_fn=<MseLossBackward>)
# 189 tensor(120.0516, grad_fn=<MseLossBackward>)
# 190 tensor(120.0237, grad_fn=<MseLossBackward>)
# 191 tensor(119.9958, grad_fn=<MseLossBackward>)
# 192 tensor(119.9679, grad_fn=<MseLossBackward>)
# 193 tensor(119.9398, grad_fn=<MseLossBackward>)
# 194 tensor(119.9116, grad_fn=<MseLossBackward>)
# 195 tensor(119.8835, grad_fn=<MseLossBackward>)
# 196 tensor(119.8552, grad_fn=<MseLossBackward>)
# 197 tensor(119.8269, grad_fn=<MseLossBackward>)
# 198 tensor(119.7985, grad_fn=<MseLossBackward>)
# 199 tensor(119.7701, grad_fn=<MseLossBackward>)

# %%
print ('Optimizing flowmap')        
for t in range(params['ntrain'][1]):
    for b in range(x.shape[0]):
        # Forward pass: Compute predicted y by passing x to the model
        pred, grad = modelRINN(x[b,:,:],params['dt_integration'])
        # Compute and print loss
        loss = criterion(pred, y[b,:,:])
        # Zero gradients, perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Save models
        #torch.save(modelRINN.state_dict(), path + file_name)
    print(t,loss)
# Out:
# Optimizing flowmap
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:13: UserWarning: reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.
#   warnings.warn("reduction='elementwise_mean' is deprecated, please use reduction='mean' instead.")
# 0 tensor(573.1852, grad_fn=<MseLossBackward>)
# 1 tensor(570.5160, grad_fn=<MseLossBackward>)
# 2 tensor(567.0052, grad_fn=<MseLossBackward>)
# 3 tensor(562.4335, grad_fn=<MseLossBackward>)
# 4 tensor(556.6102, grad_fn=<MseLossBackward>)
# 5 tensor(549.3994, grad_fn=<MseLossBackward>)
# 6 tensor(540.6448, grad_fn=<MseLossBackward>)
# 7 tensor(530.0040, grad_fn=<MseLossBackward>)
# 8 tensor(517.4689, grad_fn=<MseLossBackward>)
# 9 tensor(490.8246, grad_fn=<MseLossBackward>)
# 10 tensor(472.5881, grad_fn=<MseLossBackward>)
# 11 tensor(462.7190, grad_fn=<MseLossBackward>)
# 12 tensor(461.0589, grad_fn=<MseLossBackward>)
# 13 tensor(487.9277, grad_fn=<MseLossBackward>)
# 14 tensor(627.2772, grad_fn=<MseLossBackward>)
# 15 tensor(671.9416, grad_fn=<MseLossBackward>)
# 16 tensor(688.2598, grad_fn=<MseLossBackward>)
# 17 tensor(697.3205, grad_fn=<MseLossBackward>)
# 18 tensor(702.9751, grad_fn=<MseLossBackward>)
# 19 tensor(706.8322, grad_fn=<MseLossBackward>)
# 20 tensor(709.6320, grad_fn=<MseLossBackward>)
# 21 tensor(711.7420, grad_fn=<MseLossBackward>)
# 22 tensor(713.3657, grad_fn=<MseLossBackward>)
# 23 tensor(714.6224, grad_fn=<MseLossBackward>)
# 24 tensor(715.5894, grad_fn=<MseLossBackward>)
# 25 tensor(716.3234, grad_fn=<MseLossBackward>)
# 26 tensor(716.8641, grad_fn=<MseLossBackward>)
# 27 tensor(717.2416, grad_fn=<MseLossBackward>)
# 28 tensor(717.4825, grad_fn=<MseLossBackward>)
# 29 tensor(717.6046, grad_fn=<MseLossBackward>)
# 30 tensor(717.6247, grad_fn=<MseLossBackward>)
# 31 tensor(717.5537, grad_fn=<MseLossBackward>)
# 32 tensor(717.4055, grad_fn=<MseLossBackward>)
# 33 tensor(717.1845, grad_fn=<MseLossBackward>)
# 34 tensor(716.9006, grad_fn=<MseLossBackward>)
# 35 tensor(716.5592, grad_fn=<MseLossBackward>)
# 36 tensor(716.1621, grad_fn=<MseLossBackward>)
# 37 tensor(715.7160, grad_fn=<MseLossBackward>)
# 38 tensor(715.2216, grad_fn=<MseLossBackward>)
# 39 tensor(714.6808, grad_fn=<MseLossBackward>)
# 40 tensor(714.0947, grad_fn=<MseLossBackward>)
# 41 tensor(713.4647, grad_fn=<MseLossBackward>)
# 42 tensor(712.7914, grad_fn=<MseLossBackward>)
# 43 tensor(712.0745, grad_fn=<MseLossBackward>)
# 44 tensor(711.3128, grad_fn=<MseLossBackward>)
# 45 tensor(710.5041, grad_fn=<MseLossBackward>)
# 46 tensor(709.6487, grad_fn=<MseLossBackward>)
# 47 tensor(708.7465, grad_fn=<MseLossBackward>)
# 48 tensor(707.7941, grad_fn=<MseLossBackward>)
# 49 tensor(706.7885, grad_fn=<MseLossBackward>)
# 50 tensor(705.7289, grad_fn=<MseLossBackward>)
# 51 tensor(704.6121, grad_fn=<MseLossBackward>)
# 52 tensor(703.4355, grad_fn=<MseLossBackward>)
# 53 tensor(702.1969, grad_fn=<MseLossBackward>)
# 54 tensor(700.8928, grad_fn=<MseLossBackward>)
# 55 tensor(699.5188, grad_fn=<MseLossBackward>)
# 56 tensor(698.0760, grad_fn=<MseLossBackward>)
# 57 tensor(696.5546, grad_fn=<MseLossBackward>)
# 58 tensor(694.9534, grad_fn=<MseLossBackward>)
# 59 tensor(693.2684, grad_fn=<MseLossBackward>)
# 60 tensor(691.4966, grad_fn=<MseLossBackward>)
# 61 tensor(689.6284, grad_fn=<MseLossBackward>)
# 62 tensor(687.6646, grad_fn=<MseLossBackward>)
# 63 tensor(685.5936, grad_fn=<MseLossBackward>)
# 64 tensor(683.4152, grad_fn=<MseLossBackward>)
# 65 tensor(681.1179, grad_fn=<MseLossBackward>)
# 66 tensor(678.6987, grad_fn=<MseLossBackward>)
# 67 tensor(676.1487, grad_fn=<MseLossBackward>)
# 68 tensor(673.4626, grad_fn=<MseLossBackward>)
# 69 tensor(670.6295, grad_fn=<MseLossBackward>)
# 70 tensor(667.6425, grad_fn=<MseLossBackward>)
# 71 tensor(664.4906, grad_fn=<MseLossBackward>)
# 72 tensor(661.1677, grad_fn=<MseLossBackward>)
# 73 tensor(657.6600, grad_fn=<MseLossBackward>)
# 74 tensor(653.9603, grad_fn=<MseLossBackward>)
# 75 tensor(650.0536, grad_fn=<MseLossBackward>)
# 76 tensor(645.9315, grad_fn=<MseLossBackward>)
# 77 tensor(641.5831, grad_fn=<MseLossBackward>)
# 78 tensor(636.9927, grad_fn=<MseLossBackward>)
# 79 tensor(632.1500, grad_fn=<MseLossBackward>)
# 80 tensor(627.0432, grad_fn=<MseLossBackward>)
# 81 tensor(621.6602, grad_fn=<MseLossBackward>)
# 82 tensor(615.9868, grad_fn=<MseLossBackward>)
# 83 tensor(610.0162, grad_fn=<MseLossBackward>)
# 84 tensor(603.7369, grad_fn=<MseLossBackward>)
# 85 tensor(597.1419, grad_fn=<MseLossBackward>)
# 86 tensor(590.2265, grad_fn=<MseLossBackward>)
# 87 tensor(582.9886, grad_fn=<MseLossBackward>)
# 88 tensor(575.4296, grad_fn=<MseLossBackward>)
# 89 tensor(567.5563, grad_fn=<MseLossBackward>)
# 90 tensor(559.3812, grad_fn=<MseLossBackward>)
# 91 tensor(550.9202, grad_fn=<MseLossBackward>)
# 92 tensor(542.1992, grad_fn=<MseLossBackward>)
# 93 tensor(533.2488, grad_fn=<MseLossBackward>)
# 94 tensor(524.1081, grad_fn=<MseLossBackward>)
# 95 tensor(514.8214, grad_fn=<MseLossBackward>)
# 96 tensor(505.4397, grad_fn=<MseLossBackward>)
# 97 tensor(496.0177, grad_fn=<MseLossBackward>)
# 98 tensor(486.6155, grad_fn=<MseLossBackward>)
# 99 tensor(477.2889, grad_fn=<MseLossBackward>)
# 100 tensor(468.1011, grad_fn=<MseLossBackward>)
# 101 tensor(459.1158, grad_fn=<MseLossBackward>)
# 102 tensor(450.4026, grad_fn=<MseLossBackward>)
# 103 tensor(442.0417, grad_fn=<MseLossBackward>)
# 104 tensor(434.1371, grad_fn=<MseLossBackward>)
# 105 tensor(426.8270, grad_fn=<MseLossBackward>)
# 106 tensor(420.2950, grad_fn=<MseLossBackward>)
# 107 tensor(414.7728, grad_fn=<MseLossBackward>)
# 108 tensor(410.5223, grad_fn=<MseLossBackward>)
# 109 tensor(407.7870, grad_fn=<MseLossBackward>)
# 110 tensor(406.7048, grad_fn=<MseLossBackward>)
# 111 tensor(407.2245, grad_fn=<MseLossBackward>)
# 112 tensor(409.0844, grad_fn=<MseLossBackward>)
# 113 tensor(411.8802, grad_fn=<MseLossBackward>)
# 114 tensor(415.1878, grad_fn=<MseLossBackward>)
# 115 tensor(418.6662, grad_fn=<MseLossBackward>)
# 116 tensor(422.0894, grad_fn=<MseLossBackward>)
# 117 tensor(425.3327, grad_fn=<MseLossBackward>)
# 118 tensor(428.3404, grad_fn=<MseLossBackward>)
# 119 tensor(431.0988, grad_fn=<MseLossBackward>)
# 120 tensor(433.6136, grad_fn=<MseLossBackward>)
# 121 tensor(435.9001, grad_fn=<MseLossBackward>)
# 122 tensor(437.9792, grad_fn=<MseLossBackward>)
# 123 tensor(439.8728, grad_fn=<MseLossBackward>)
# 124 tensor(441.6034, grad_fn=<MseLossBackward>)
# 125 tensor(443.1902, grad_fn=<MseLossBackward>)
# 126 tensor(444.6508, grad_fn=<MseLossBackward>)
# 127 tensor(446.0036, grad_fn=<MseLossBackward>)
# 128 tensor(447.2625, grad_fn=<MseLossBackward>)
# 129 tensor(448.4420, grad_fn=<MseLossBackward>)
# 130 tensor(449.5576, grad_fn=<MseLossBackward>)
# 131 tensor(450.6211, grad_fn=<MseLossBackward>)
# 132 tensor(451.6433, grad_fn=<MseLossBackward>)
# 133 tensor(452.6375, grad_fn=<MseLossBackward>)
# 134 tensor(453.6173, grad_fn=<MseLossBackward>)
# 135 tensor(454.5900, grad_fn=<MseLossBackward>)
# 136 tensor(455.5686, grad_fn=<MseLossBackward>)
# 137 tensor(456.5646, grad_fn=<MseLossBackward>)
# 138 tensor(457.5865, grad_fn=<MseLossBackward>)
# 139 tensor(458.6478, grad_fn=<MseLossBackward>)
# 140 tensor(459.7573, grad_fn=<MseLossBackward>)
# 141 tensor(460.9251, grad_fn=<MseLossBackward>)
# 142 tensor(462.1619, grad_fn=<MseLossBackward>)
# 143 tensor(463.4777, grad_fn=<MseLossBackward>)
# 144 tensor(464.8793, grad_fn=<MseLossBackward>)
# 145 tensor(466.3783, grad_fn=<MseLossBackward>)
# 146 tensor(467.9771, grad_fn=<MseLossBackward>)
# 147 tensor(469.6833, grad_fn=<MseLossBackward>)
# 148 tensor(471.4949, grad_fn=<MseLossBackward>)
# 149 tensor(473.4068, grad_fn=<MseLossBackward>)
# 150 tensor(475.4102, grad_fn=<MseLossBackward>)
# 151 tensor(477.4828, grad_fn=<MseLossBackward>)
# 152 tensor(479.5906, grad_fn=<MseLossBackward>)
# 153 tensor(481.6797, grad_fn=<MseLossBackward>)
# 154 tensor(483.6770, grad_fn=<MseLossBackward>)
# 155 tensor(485.4739, grad_fn=<MseLossBackward>)
# 156 tensor(486.9244, grad_fn=<MseLossBackward>)
# 157 tensor(487.8332, grad_fn=<MseLossBackward>)
# 158 tensor(487.9562, grad_fn=<MseLossBackward>)
# 159 tensor(487.0269, grad_fn=<MseLossBackward>)
# 160 tensor(484.8497, grad_fn=<MseLossBackward>)
# 161 tensor(481.5671, grad_fn=<MseLossBackward>)
# 162 tensor(478.1653, grad_fn=<MseLossBackward>)
# 163 tensor(477.0172, grad_fn=<MseLossBackward>)
# 164 tensor(481.1554, grad_fn=<MseLossBackward>)
# 165 tensor(490.9173, grad_fn=<MseLossBackward>)
# 166 tensor(502.5876, grad_fn=<MseLossBackward>)
# 167 tensor(513.2436, grad_fn=<MseLossBackward>)
# 168 tensor(522.1459, grad_fn=<MseLossBackward>)
# 169 tensor(529.3250, grad_fn=<MseLossBackward>)
# 170 tensor(535.0773, grad_fn=<MseLossBackward>)
# 171 tensor(539.7169, grad_fn=<MseLossBackward>)
# 172 tensor(543.5191, grad_fn=<MseLossBackward>)
# 173 tensor(546.6944, grad_fn=<MseLossBackward>)
# 174 tensor(549.3998, grad_fn=<MseLossBackward>)
# 175 tensor(551.7439, grad_fn=<MseLossBackward>)
# 176 tensor(553.8055, grad_fn=<MseLossBackward>)
# 177 tensor(555.6336, grad_fn=<MseLossBackward>)
# 178 tensor(557.2597, grad_fn=<MseLossBackward>)
# 179 tensor(558.7051, grad_fn=<MseLossBackward>)
# 180 tensor(559.9819, grad_fn=<MseLossBackward>)
# 181 tensor(561.0934, grad_fn=<MseLossBackward>)
# 182 tensor(562.0405, grad_fn=<MseLossBackward>)
# 183 tensor(562.8254, grad_fn=<MseLossBackward>)
# 184 tensor(563.4419, grad_fn=<MseLossBackward>)
# 185 tensor(563.8924, grad_fn=<MseLossBackward>)
# 186 tensor(564.1740, grad_fn=<MseLossBackward>)
# 187 tensor(564.2819, grad_fn=<MseLossBackward>)
# 188 tensor(564.2179, grad_fn=<MseLossBackward>)
# 189 tensor(563.9803, grad_fn=<MseLossBackward>)
# 190 tensor(563.5750, grad_fn=<MseLossBackward>)
# 191 tensor(562.9970, grad_fn=<MseLossBackward>)
# 192 tensor(562.2534, grad_fn=<MseLossBackward>)
# 193 tensor(561.3472, grad_fn=<MseLossBackward>)
# 194 tensor(560.2835, grad_fn=<MseLossBackward>)
# 195 tensor(559.0668, grad_fn=<MseLossBackward>)
# 196 tensor(557.7015, grad_fn=<MseLossBackward>)
# 197 tensor(556.1949, grad_fn=<MseLossBackward>)
# 198 tensor(554.5538, grad_fn=<MseLossBackward>)
# 199 tensor(552.7841, grad_fn=<MseLossBackward>)

# %%
pred = [torch.from_numpy(xt.values[:1,:]).float()] 
for i in range(5000):  
    pred.append(modelRINN(pred[-1],params['dt_integration'])[0])

# %%
plt.plot(torch.stack(pred).data.numpy()[:1000,0,0],label = "Prediction from LQM Dynamical model")
plt.plot(xt.values[:1000,0],label = "True state")

# %%
pred = torch.stack(pred)[:,0,:] #??

# %% [markdown]
# ### Test/Evaluation du modèle

# %% [markdown]
# Calcul de MSE

# %%
from sklearn.metrics import mean_squared_error 

#print('mse (sklearn): ', torch.nn.MSELoss(xt,pred))

torch.mean( (torch(reel-pred.detach())**2)) #xt.values

# %% [markdown]
# Calcul de MSE normalisée

# %%
from sklearn.metrics import r2_score 
NMSE = 1- r2_score(reel,pred.detach()) #xt.values

# %%
NMSE
# Out:
# 0.005288681613754065

# %%
pred[:,1].mean() #??
# Out:
# tensor(-1.1216, grad_fn=<MeanBackward0>)

# %% [markdown]
# ## Evaluation du modèle appris

# %%
#traçage du flux du modèle stochastique predit
#Undersampling to dt = .01
fig=plt.figure()
ax=fig.gca(projection='3d')
line1,=ax.plot(pred[:20000,0].detach(),pred[:20000,1].detach(),pred[:20000,2].detach(),'k')
ax.set_xlabel('$x_1$');ax.set_ylabel('$x_2$');ax.set_zlabel('$x_3$')
plt.legend([line1], ['Stochastic Lorenz flow'])
plt.title('Stochastic Lorenz flow')
# Out:
# Text(0.5, 0.92, 'Stochastic Lorenz flow')

# %%
#simulation de la série temporelle x
plt.plot(xt.values[:1000,0])
plt.plot(pred[:1000,0].detach())

# %%
#simulation de la série temporelle y
plt.plot(xt.values[:1000,1])
plt.plot(pred[:1000,1].detach())

# %%
#simulation de la série temporelle z
plt.plot(xt.values[:1000,2])
plt.plot(pred[:1000,2].detach())
